# %% [markdown]
# **This is the simplified Opensantions data in csv format**

# %%
#import packages
import requests
import pandas as pd
import numpy as np
import datetime
import os
import re

# %% [markdown]
# # Retrieval of the data

# %%
#test
url = "https://data.opensanctions.org/datasets/20231224/peps/targets.simple.csv"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20230101',end='20231231',freq='D').strftime('%Y%m%d')
date_list
# Out:
# Index(['20220101', '20220102', '20220103', '20220104', '20220105', '20220106',
#        '20220107', '20220108', '20220109', '20220110',
#        ...
#        '20221222', '20221223', '20221224', '20221225', '20221226', '20221227',
#        '20221228', '20221229', '20221230', '20221231'],
#       dtype='object', length=365)

# %%
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []

for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/peps/targets.simple.csv'
    websites.append(test)
print(websites)
# Out:
# ['https://data.opensanctions.org/datasets/20220101/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220102/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220103/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220104/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220105/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220106/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220107/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220108/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220109/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220110/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220111/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220112/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220113/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220114/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220115/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220116/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220117/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220118/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220119/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220120/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220121/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220122/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220123/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220124/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220125/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220126/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220127/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220128/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220129/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220130/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220131/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220201/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220202/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220203/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220204/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220205/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220206/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220207/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220208/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220209/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220210/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220211/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220212/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220213/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220214/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220215/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220216/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220217/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220218/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220219/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220220/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/20220221/peps/targets.simple.csv', 'https://data.opensanctions.org/datasets/202202 ...

# %% [markdown]
# #first check for missing days
# for site in websites:
#     try:
#         response = requests.get(site)
#         response.raise_for_status()  # Raises an HTTPError for bad response
#     except requests.exceptions.RequestException as e:
#         print(f"Error accessing {site}: {e}")
#         continue

# %%
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
peps_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    peps_list.append(data)
res = pd.concat(peps_list)  # concatenate list of dataframes

# %%
res
# Out:
#                                                        id  schema  \
# 0                               NK-232XviNCU8o2PiPCQC3Cg2  Person
# 1                               NK-285BXbQUroosx6WdAP44YD  Person
# 2                               NK-288EBmCdPXppFYtfmcgyqg  Person
# 3                               NK-2AaUhJdZeBxnxVKVF7fTVv  Person
# 4                               NK-2Nhqi8R9tL2Hz9P9FpsR2W  Person
# ...                                                   ...     ...
# 221089             us-cia-zimbabwe-kembo-mohadi-vice-pres  Person
# 221090  us-cia-zimbabwe-kirsty-coventry-min-of-youth-s...  Person
# 221091  us-cia-zimbabwe-mthuli-ncube-min-of-finance-ec...  Person
# 221092  us-cia-zimbabwe-sekai-nzenza-min-of-industry-c...  Person
# 221093  us-cia-zimbabwe-sibusiso-moyo-lt-gen-ret-min-o...  Person
#
#                                   name             aliases  birth_date  \
# 0                  AMASSOUMOU NDIFOANE                 NaN  1951-10-24
# 1                     ZONDOL HERSSESSE                 NaN  1967-01-01
# 2                        Fethiye Özver                 NaN         NaN
# 3                    Marica Montemaggi  Montemaggi, Marica  1982-07-20
# 4                     BANLOG Polycarpe    Polycarpe BANLOG  1957-06-17
# ...                                ...                 ...         ...
# 221089                    Kembo MOHADI                 NaN         NaN
# 221090                 Kirsty COVENTRY                 NaN         NaN
# 221091                    Mthuli NCUBE                 NaN         NaN
# 221092                    Sekai NZENZA                 NaN         NaN
# 221093  Sibusiso MOYO, Lt. Gen. (Ret.)                 NaN         NaN
#
#        countries addresses identifiers  sanctions phones  \
# 0             cm       NaN         NaN        NaN    NaN
# 1             cm       NaN         NaN        NaN    NaN
# 2             tr       NaN         NaN        NaN    NaN
# 3             sm       NaN         NaN        NaN    NaN
# 4             cm       NaN         NaN        NaN    NaN
# ...          ...       ...         ...        ...    ...
# 221089        zw       NaN         NaN        NaN    NaN
# 221090        zw       NaN         NaN        NaN    NaN
# 221091        zw       NaN         NaN        NaN    NaN
# 221092        zw       NaN         NaN        NaN    NaN
# 221093        zw       NaN         NaN        NaN    NaN
#
#                            emails            dataset            last_seen  \
# 0                             NaN   Every Politician  2021-07-26 11:55:45
# 1                Zondol@assnat.cm   Every Politician  2021-07-26 11:55:45
# 2                             NaN   Every Politician  2021-07-26 11:55:45
# 3                             NaN   Every Politician  2021-07-26 11:55:45
# 4       polycarpebanlog@assnat.cm   Every Politician  2021-07-26 11:55:45
# ...                           ...                ...                  ...
# 221089                        NaN  CIA World Leaders  2022-02-01 01:29:40
# 221090                        NaN  CIA World Leaders  2022-02-01 01:29:40
# 221091                        NaN  CIA World Leaders  2022-02-01 01:29:40
# 221092                        NaN  CIA World Leaders  2022-02-01 01:29:40
# 221093                        NaN  CIA World Leaders  2022-02-01 01:29:40
#
#                  first_seen date_stamp
# 0       2022-01-01 03:04:33   20220101
# 1       2022-01-01 03:04:33   20220101
# 2       2022-01-01 03:04:33   20220101
# 3       2022-01-01 03:04:33   20220101
# 4       2022-01-01 03:04:33   20220101
# ...                     ...        ...
# 221089  2021-07-26 11:55:45   20221231
# 221090  2021-07-26 11:55:45   20221231
# 221091  2021-07-26 11:55:45   20221231
# 221092  2021-07-26 11:55:45   20221231
# 221093  2021-07-26 11:55:45   20221231
#
# [55493131 rows x 15 columns]

# %% [markdown]
# # alternatively, get the names as txt file

# %% [markdown]
# import requests
# import re
#
#
# websites = []
#
# # Construct list of URLs based on date_list
# for date in date_list:
#     test = f'https://data.opensanctions.org/datasets/{date}/peps/names.txt'
#     websites.append(test)
#
# peps_data = []  # List to store the text data and date identifier
#
# # Regex pattern to extract date from the URL
# date_pattern = r'/datasets/(\d{8})/'
#
# # Iterate over each website URL
# for site in websites:
#     response = requests.get(site)
#     if response.status_code != 200:
#         continue
#
#     data = response.text
#
#     # Extract date from the URL
#     match = re.search(date_pattern, site)
#     if match:
#         date_identifier = match.group(1)  # Extract the date from the URL
#         peps_data.append({'date': date_identifier, 'text': data})  # Append data along with the date identifier
#
# print(peps_data)  # Output the list of text data along with the corresponding date identifier

# %% [markdown]
# #url_txt = "https://data.opensanctions.org/datasets/20240411/peps/names.txt"
# websites = []
# data = []
# date = []
# for i in date_list:
#     test = 'https://data.opensanctions.org/datasets/'+(i)+'/peps/names.txt'
#     websites.append(test)
# data = []
# peps_list = []
# date_pattern = r'/datasets/(\d{8})/'
# for site in websites:
#     response = requests.get(site)
#     if response.status_code != 200:
#         continue
#     data = response.text
#     match = re.search(date_pattern, site) #extract the date from the url
#     if match:
#         date = match.Group(1)
#         date.append(data)
#         #data_full = dict(zip(date,data)) #set an individual date stamp for each dataframe matching the url date
#         #data =  data.set_index('date_stamp') #set as an index
#     peps_list.append(data)
# peps_list

# %% [markdown]
# def compress_file(input_file, output_zip):
#     with zipfile.ZipFile(output_zip, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
#         zipf.write(input_file)
#
# # Example usage:
# input_file = 'peps_list.txt'
# output_zip = 'peps_text.zip'
# compress_file(input_file, output_zip)

# %% [markdown]
# # Match the dates against each other

# %%
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows

# Reset index for the final result
res.reset_index(drop=True, inplace=True)

# %%
res
# Out:
#                                                          id  schema  \
# 0                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 1                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 2                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 3                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 4                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# ...                                                     ...     ...
# 55493126  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
# 55493127  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
# 55493128  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
# 55493129  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
# 55493130  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
#
#                        name aliases birth_date countries addresses  \
# 0         SAKAMOTO Tetsushi     NaN        NaN        jp       NaN
# 1         SAKAMOTO Tetsushi     NaN        NaN        jp       NaN
# 2         SAKAMOTO Tetsushi     NaN        NaN        jp       NaN
# 3         SAKAMOTO Tetsushi     NaN        NaN        jp       NaN
# 4         SAKAMOTO Tetsushi     NaN        NaN        jp       NaN
# ...                     ...     ...        ...       ...       ...
# 55493126   Winston CHITANDO     NaN        NaN        zw       NaN
# 55493127   Winston CHITANDO     NaN        NaN        zw       NaN
# 55493128   Winston CHITANDO     NaN        NaN        zw       NaN
# 55493129   Winston CHITANDO     NaN        NaN        zw       NaN
# 55493130   Winston CHITANDO     NaN        NaN        zw       NaN
#
#          identifiers  sanctions phones emails            dataset  \
# 0                NaN        NaN    NaN    NaN  CIA World Leaders
# 1                NaN        NaN    NaN    NaN  CIA World Leaders
# 2                NaN        NaN    NaN    NaN  CIA World Leaders
# 3                NaN        NaN    NaN    NaN  CIA World Leaders
# 4                NaN        NaN    NaN    NaN  CIA World Leaders
# ...              ...        ...    ...    ...                ...
# 55493126         NaN        NaN    NaN    NaN  CIA World Leaders
# 55493127         NaN        NaN    NaN    NaN  CIA World Leaders
# 55493128         NaN        NaN    NaN    NaN  CIA World Leaders
# 55493129         NaN        NaN    NaN    NaN  CIA World Leaders
# 55493130         NaN        NaN    NaN    NaN  CIA World Leaders
#
#                     last_seen           first_seen date_stamp  new_entry  \
# 0         2021-07-26 11:55:45  2022-01-19 01:27:13   20220119       True
# 1         2021-07-26 11:55:45  2022-01-20 01:33:01   20220120      False
# 2         2021-07-26 11:55:45  2022-01-21 01:28:08   20220121      False
# 3         2021-07-26 11:55:45  2022-01-22 01:26:45   20220122      False
# 4         2021-07-26 11:55:45  2022-01-23 01:28:03   20220123      False
# ...                       ...                  ...        ...        ...
# 55493126  2021-07-26 11:55:45  2022-01-15 08:55:59   20220115      False
# 55493127  2021-07-26 11:55:45  2022-01-17 07:40:14   20220117      False
# 55493128  2021-07-26 11:55:45  2022-01-18 01:30:55   20220118      False
# 55493129  2021-07-26 11:55:45  2022-01-19 01:27:13   20220119      False
# 55493130  2021-07-26 11:55:45  2022-01-20 01:33:01   20220120      False
#
#           deletion  unchanged
# 0            False      False
# 1            False       True
# 2            False       True
# 3            False       True
# 4            False       True
# ...            ...        ...
# 55493126     False       True
# 55493127     False       True
# 55493128     False       True
# 55493129     False       True
# 55493130      True      False
#
# [55493131 rows x 18 columns]

# %%
#test thematching function
test = res.query('new_entry == True')
test
# Out:
#                                                          id  schema  \
# 0                                 NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 347                               NK-232XviNCU8o2PiPCQC3Cg2  Person
# 440                               NK-24isa6tapAYCqtEnqbUdzv  Person
# 633                               NK-25Z3H4pijwnkYMmpybVYzQ  Person
# 665                               NK-26h6Ukv23GDmJUyhgmK5ML  Person
# ...                                                     ...     ...
# 55492105  us-cia-zimbabwe-obadiah-moyo-min-of-health-chi...  Person
# 55492186  us-cia-zimbabwe-oppah-muchinguri-kashiri-min-o...  Person
# 55492384  us-cia-zimbabwe-sekai-nzenza-min-of-industry-c...  Person
# 55492748  us-cia-zimbabwe-sibusiso-moyo-lt-gen-ret-min-o...  Person
# 55493112  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
#
#                                         name  \
# 0                          SAKAMOTO Tetsushi
# 347                      AMASSOUMOU NDIFOANE
# 440                       DEMIDOVICH VASILIJ
# 633              Мария Владимировна Пирогова
# 665       Aleksandr Aleksandrovich Zhuravlev
# ...                                      ...
# 55492105                        Obadiah MOYO
# 55492186            Oppah MUCHINGURI-KASHIRI
# 55492384                        Sekai NZENZA
# 55492748      Sibusiso MOYO, Lt. Gen. (Ret.)
# 55493112                    Winston CHITANDO
#
#                                                     aliases  birth_date  \
# 0                                                       NaN         NaN
# 347                                                     NaN  1951-10-24
# 440       Demidovich Vasili Nikolaevich;Demidovich Vasil...  1961-12-24
# 633       Mariya Vladimirovna Pirogova;Pirogova Mariia V...  1993-05-13
# 665                        Александр Александрович Журавлёв         NaN
# ...                                                     ...         ...
# 55492105                                                NaN         NaN
# 55492186                                                NaN         NaN
# 55492384                                                NaN         NaN
# 55492748                                                NaN         NaN
# 55493112                                                NaN         NaN
#
#          countries addresses identifiers  sanctions phones  \
# 0               jp       NaN         NaN        NaN    NaN
# 347             cm       NaN         NaN        NaN    NaN
# 440             by       NaN         NaN        NaN    NaN
# 633          ru;ua       NaN  3410105889        NaN    NaN
# 665            NaN       NaN         NaN        NaN    NaN
# ...            ...       ...         ...        ...    ...
# 55492105        zw       NaN         NaN        NaN    NaN
# 55492186        zw       NaN         NaN        NaN    NaN
# 55492384        zw       NaN         NaN        NaN    NaN
# 55492748        zw       NaN         NaN        NaN    NaN
# 55493112        zw       NaN         NaN        NaN    NaN
#
#                            emails  \
# 0                             NaN
# 347                           NaN
# 440       demidovich@house.gov.by
# 633                           NaN
# 665                           NaN
# ...                           ...
# 55492105                      NaN
# 55492186                      NaN
# 55492384                      NaN
# 55492748                      NaN
# 55493112                      NaN
#
#                                                     dataset  \
# 0                                         CIA World Leaders
# 347                                        Every Politician
# 440       Every Politician;RuPEP Public Database of PEPs...
# 633       RuPEP Public Database of PEPs in Russia and Be...
# 665       RuPEP Public Database of PEPs in Russia and Be...
# ...                                                     ...
# 55492105                                  CIA World Leaders
# 55492186                                  CIA World Leaders
# 55492384                                  CIA World Leaders
# 55492748                                  CIA World Leaders
# 55493112                                  CIA World Leaders
#
#                     last_seen           first_seen date_stamp  new_entry  \
# 0         2021-07-26 11:55:45  2022-01-19 01:27:13   20220119       True
# 347       2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
# 440       2022-06-22 18:15:31  2021-07-26 11:55:45   20220622       True
# 633       2022-11-13 18:15:42  2022-11-12 06:20:00   20221113       True
# 665       2022-05-21 18:14:04  2022-05-21 06:15:45   20220521       True
# ...                       ...                  ...        ...        ...
# 55492105  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
# 55492186  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
# 55492384  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
# 55492748  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
# 55493112  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101       True
#
#           deletion  unchanged
# 0            False      False
# 347          False      False
# 440          False      False
# 633          False      False
# 665          False      False
# ...            ...        ...
# 55492105     False      False
# 55492186     False      False
# 55492384     False      False
# 55492748     False      False
# 55493112     False      False
#
# [237248 rows x 18 columns]

# %%
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
#res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
#res['listing_count'] = res.groupby('month')['id'].transform('nunique')
#res

# %% [markdown]
# # Deduplicate

# %%
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)

# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')

# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)

# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
# Out:
#                                                        id  schema  \
# 0                               NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 1                               NK-232XviNCU8o2PiPCQC3Cg2  Person
# 2                               NK-24isa6tapAYCqtEnqbUdzv  Person
# 3                               NK-25Z3H4pijwnkYMmpybVYzQ  Person
# 4                               NK-26h6Ukv23GDmJUyhgmK5ML  Person
# ...                                                   ...     ...
# 237243  us-cia-zimbabwe-obadiah-moyo-min-of-health-chi...  Person
# 237244  us-cia-zimbabwe-oppah-muchinguri-kashiri-min-o...  Person
# 237245  us-cia-zimbabwe-sekai-nzenza-min-of-industry-c...  Person
# 237246  us-cia-zimbabwe-sibusiso-moyo-lt-gen-ret-min-o...  Person
# 237247  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
#
#                                       name  \
# 0                        SAKAMOTO Tetsushi
# 1                      AMASSOUMOU NDIFOANE
# 2                       DEMIDOVICH VASILIJ
# 3              Мария Владимировна Пирогова
# 4       Aleksandr Aleksandrovich Zhuravlev
# ...                                    ...
# 237243                        Obadiah MOYO
# 237244            Oppah MUCHINGURI-KASHIRI
# 237245                        Sekai NZENZA
# 237246      Sibusiso MOYO, Lt. Gen. (Ret.)
# 237247                    Winston CHITANDO
#
#                                                   aliases  birth_date  \
# 0                                                     NaN         NaN
# 1                                                     NaN  1951-10-24
# 2       Demidovich Vasili Nikolaevich;Demidovich Vasil...  1961-12-24
# 3       Mariya Vladimirovna Pirogova;Pirogova Mariia V...  1993-05-13
# 4                        Александр Александрович Журавлёв         NaN
# ...                                                   ...         ...
# 237243                                                NaN         NaN
# 237244                                                NaN         NaN
# 237245                                                NaN         NaN
# 237246                                                NaN         NaN
# 237247                                                NaN         NaN
#
#        countries addresses identifiers  sanctions phones  ...  \
# 0             jp       NaN         NaN        NaN    NaN  ...
# 1             cm       NaN         NaN        NaN    NaN  ...
# 2             by       NaN         NaN        NaN    NaN  ...
# 3          ru;ua       NaN  3410105889        NaN    NaN  ...
# 4            NaN       NaN         NaN        NaN    NaN  ...
# ...          ...       ...         ...        ...    ...  ...
# 237243        zw       NaN         NaN        NaN    NaN  ...
# 237244        zw       NaN         NaN        NaN    NaN  ...
# 237245        zw       NaN         NaN        NaN    NaN  ...
# 237246        zw       NaN         NaN        NaN    NaN  ...
# 237247        zw       NaN         NaN        NaN    NaN  ...
#
#                                                   dataset  \
# 0                                       CIA World Leaders
# 1                                        Every Politician
# 2       Every Politician;RuPEP Public Database of PEPs...
# 3       RuPEP Public Database of PEPs in Russia and Be...
# 4       RuPEP Public Database of PEPs in Russia and Be...
# ...                                                   ...
# 237243                                  CIA World Leaders
# 237244                                  CIA World Leaders
# 237245                                  CIA World Leaders
# 237246                                  CIA World Leaders
# 237247                                  CIA World Leaders
#
#                   last_seen           first_seen date_stamp new_entry  \
# 0       2021-07-26 11:55:45  2022-01-19 01:27:13   20220119      True
# 1       2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 2       2022-06-22 18:15:31  2021-07-26 11:55:45   20220622      True
# 3       2022-11-13 18:15:42  2022-11-12 06:20:00   20221113      True
# 4       2022-05-21 18:14:04  2022-05-21 06:15:45   20220521      True
# ...                     ...                  ...        ...       ...
# 237243  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237244  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237245  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237246  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237247  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
#
#         deletion  unchanged    month listing_date delisting_date
# 0          False      False  2022-01     20220119            NaN
# 1          False      False  2022-01     20220101            NaN
# 2          False      False  2022-06     20220622            NaN
# 3          False      False  2022-11     20221113            NaN
# 4          False      False  2022-05     20220521            NaN
# ...          ...        ...      ...          ...            ...
# 237243     False      False  2022-01     20220101            NaN
# 237244     False      False  2022-01     20220101            NaN
# 237245     False      False  2022-01     20220101            NaN
# 237246     False      False  2022-01     20220101            NaN
# 237247     False      False  2022-01     20220101            NaN
#
# [237248 rows x 21 columns]

# %%
res_deduplicated
# Out:
#                                                        id  schema  \
# 0                               NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 1                               NK-232XviNCU8o2PiPCQC3Cg2  Person
# 2                               NK-24isa6tapAYCqtEnqbUdzv  Person
# 3                               NK-25Z3H4pijwnkYMmpybVYzQ  Person
# 4                               NK-26h6Ukv23GDmJUyhgmK5ML  Person
# ...                                                   ...     ...
# 237243  us-cia-zimbabwe-obadiah-moyo-min-of-health-chi...  Person
# 237244  us-cia-zimbabwe-oppah-muchinguri-kashiri-min-o...  Person
# 237245  us-cia-zimbabwe-sekai-nzenza-min-of-industry-c...  Person
# 237246  us-cia-zimbabwe-sibusiso-moyo-lt-gen-ret-min-o...  Person
# 237247  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
#
#                                       name  \
# 0                        SAKAMOTO Tetsushi
# 1                      AMASSOUMOU NDIFOANE
# 2                       DEMIDOVICH VASILIJ
# 3              Мария Владимировна Пирогова
# 4       Aleksandr Aleksandrovich Zhuravlev
# ...                                    ...
# 237243                        Obadiah MOYO
# 237244            Oppah MUCHINGURI-KASHIRI
# 237245                        Sekai NZENZA
# 237246      Sibusiso MOYO, Lt. Gen. (Ret.)
# 237247                    Winston CHITANDO
#
#                                                   aliases  birth_date  \
# 0                                                     NaN         NaN
# 1                                                     NaN  1951-10-24
# 2       Demidovich Vasili Nikolaevich;Demidovich Vasil...  1961-12-24
# 3       Mariya Vladimirovna Pirogova;Pirogova Mariia V...  1993-05-13
# 4                        Александр Александрович Журавлёв         NaN
# ...                                                   ...         ...
# 237243                                                NaN         NaN
# 237244                                                NaN         NaN
# 237245                                                NaN         NaN
# 237246                                                NaN         NaN
# 237247                                                NaN         NaN
#
#        countries addresses identifiers  sanctions phones  ...  \
# 0             jp       NaN         NaN        NaN    NaN  ...
# 1             cm       NaN         NaN        NaN    NaN  ...
# 2             by       NaN         NaN        NaN    NaN  ...
# 3          ru;ua       NaN  3410105889        NaN    NaN  ...
# 4            NaN       NaN         NaN        NaN    NaN  ...
# ...          ...       ...         ...        ...    ...  ...
# 237243        zw       NaN         NaN        NaN    NaN  ...
# 237244        zw       NaN         NaN        NaN    NaN  ...
# 237245        zw       NaN         NaN        NaN    NaN  ...
# 237246        zw       NaN         NaN        NaN    NaN  ...
# 237247        zw       NaN         NaN        NaN    NaN  ...
#
#                                                   dataset  \
# 0                                       CIA World Leaders
# 1                                        Every Politician
# 2       Every Politician;RuPEP Public Database of PEPs...
# 3       RuPEP Public Database of PEPs in Russia and Be...
# 4       RuPEP Public Database of PEPs in Russia and Be...
# ...                                                   ...
# 237243                                  CIA World Leaders
# 237244                                  CIA World Leaders
# 237245                                  CIA World Leaders
# 237246                                  CIA World Leaders
# 237247                                  CIA World Leaders
#
#                   last_seen           first_seen date_stamp new_entry  \
# 0       2021-07-26 11:55:45  2022-01-19 01:27:13   20220119      True
# 1       2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 2       2022-06-22 18:15:31  2021-07-26 11:55:45   20220622      True
# 3       2022-11-13 18:15:42  2022-11-12 06:20:00   20221113      True
# 4       2022-05-21 18:14:04  2022-05-21 06:15:45   20220521      True
# ...                     ...                  ...        ...       ...
# 237243  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237244  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237245  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237246  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237247  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
#
#         deletion  unchanged    month listing_date delisting_date
# 0          False      False  2022-01     20220119            NaN
# 1          False      False  2022-01     20220101            NaN
# 2          False      False  2022-06     20220622            NaN
# 3          False      False  2022-11     20221113            NaN
# 4          False      False  2022-05     20220521            NaN
# ...          ...        ...      ...          ...            ...
# 237243     False      False  2022-01     20220101            NaN
# 237244     False      False  2022-01     20220101            NaN
# 237245     False      False  2022-01     20220101            NaN
# 237246     False      False  2022-01     20220101            NaN
# 237247     False      False  2022-01     20220101            NaN
#
# [237248 rows x 21 columns]

# %% [markdown]
# # Descriptives and clean up

# %%
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
# Out:
# ['jp' 'cm' 'by' 'ru;ua' nan 'ru' 'tr' 'sm' 'il' 'de' 'kh' 'kp' 'al' 'sy'
#  'mm' 'nz' 'be' 'bb' 'ls' 'sg' 'ir' 'bi' 'fj' 'pl' 'lk' 'me' 'bm' 'ua'
#  'ck' 'x-so' 'az;ru' 'ao' 'ht' 'ae' 'cn' 'li' 'vu' 'ge' 'tm' 'tt' 'lv'
#  've' 'xk' 'bo' 'cy' 'ni' 'bg' 'cd' 'in' 'tl' 'ws' 'de;fr;ru' 'om' 'se'
#  'mr' 'ie' 'lu' 'kz;ru' 'vc' 'tn' 'ad' 'at' 'zw' 'au' 'sa' 'ag' 'si'
#  'cy;ru' 'cv' 'az' 'hr' 'vg' 'gr' 'na' 'sc' 'cg' 'ml' 'by;de' 'to' 'ss'
#  'gg' 'fi' 'pg' 'ru;us' 'la' 'ru;uz' 'gd' 'ba' 'rs' 'dk' 'bn' 'pk' 'dj'
#  'fm' 'by;ru' 'kw' 'th' 'is' 'nu' 'nr' 'dm' 'sk' 'ly' 'uz' 'mn' 'fr' 'ne'
#  'mv' 'ki' 'mu' 'nl' 'de;ru' 'bz' 'bt' 'cy-trnc' 'hn' 'ca' 'tw' 'dz' 'gn'
#  'kr' 'jm' 'gt' 'qa' 'jo' 'ma' 'gw' 'mg' 'es' 'ro' 'ad;fr' 'bs' 'cu' 'ga'
#  'hu' 'vn' 'pw' 'cz;ru;sk' 'co' 'tv' 'by;ua' 'gq' 'ar;ru;us' 'mz' 'np'
#  'mt' 'bd' 'sn' 'sb' 'gh' 'lv;ru' 'mk' 'ci' 'mc' 'pt' 'ge;ru' 'mh' 'bf'
#  'bw' 'kg;ru' 'lt' 'dd;ru' 'sz' 'gy' 'kg' 'km' 'et;za' 'py' 'ye' 'ng' 'mx'
#  'so-som' 'md;ru' 'tg' 'pm' 'rw' 'pa' 'st' 'tz' 'sd' 'ee' 'zm' 'hu;ru'
#  'it' 'us' 'iq' 'ch' 'ug' 'ke' 'fo' 'ps' 'br' 'ar' 'my' 'ar;mx' 'de;hr'
#  'za' 'cz' 'pe' 'kz' 'tc' 'cshh;cz' 'ee;ye' 'ge;suhh' 'dk;gl' 'ph' 'gb'
#  'am' 'no' 'nl;sr' 'si;yucs' 'uy' 'ec' 'et' 'do' 'ru;suhh' 'ax;fi' 'ps;se'
#  'ps;us' 'id' 'eu' 'dd;de' 'gb;gb-sct' 'kg;lv' 'de;eu' 'gb-nir' 'by;suhh'
#  'at;ie' 'cd;zr' 'cr' 'es;eu' 'cl' 'eg' 'cn;hk' 'eu;pt' 'cshh' 'gb-sct'
#  'ao;br' 'kn' 'cshh;sk' 'ee;suhh' 'ai' 'mw' 'br;pt' 'cz;sy' 'sv' 'eu;se'
#  'td' 'eu;it' 'md;ro;suhh' 'md' 'cn;tw' 'ms' 'sl' 'md;ro' 'af' 'eu;ro'
#  'sd;ss' 'eg;lu' 'iq;lu' 'cl;fr;us' 'eu;pl' 'sr' 'lc' 'gl' 'bh' 'fr;it'
#  'ai;gb' 'ly;us' 'bj' 'hu;us' 'so' 'eu;gb' 'nl;tr' 'ma;nl' 'co;es' 'cf'
#  'au;in' 'gb;ly' 'md;suhh' 'gb;ru' 'fr;wf' 'de;ye' 'suhh;uz' 'fr;ma'
#  'au;sd' 'ru;suhh;ua' 'au;rs' 'eu;nl' 'au;gb' 'au;nl' 'au;nz' 'gb;ky'
#  'eu;fr' 'gb;gb-wls' 'gb-wls' 'im' 'de;nl' 'bg;ca' 'je' 'fr;sn' 'cn;id'
#  'cd;ch' 'aw' 'es;pe' 'hk' 'rs;xk' 'gb;ng' 'suhh;ua' 'co;us' 'cz;eu'
#  'cshh;cz;de' 'ax' 'gi' 'ru;suhh;ua;ua-dpr' 'at;eu' 'gm' 'de;tr'
#  'md-pmr;suhh' 'gb;nz' 'es;ve' 'ua-dpr' 'csxx;rs;yucs' 'lr' 'lb' 'ca;lb'
#  'bi;ca' 'ag;ch' 'fr;gn' 'suhh' 'ua-lpr' 'md-pmr' 'gb;gb-nir' 'ge-ab'
#  'ca;us' 'aw;nl' 'ky' 'ua;ua-dpr' 'gb;ie' 'tj' 'gb;tc' 'kz;suhh' 'er'
#  'pr;us' 'az-nk' 'eu;ie' 'kw;sd' 'by;ru;suhh' 'at;cl;ir' 'fr;mc' 'gb;ms'
#  'eu;hr' 'ca;ug' 'au;ie' 'ru;tm' 'ru;tj' 'gb;im' 'lt;ru' 'ch;ru' 'cz;ru'
#  'mn;ru' 'gb;vg' 'be;eu' 'id;jp' 'eu;hu' 'bd;pk' 'fr;lb' 'at;hu' 'au;my'
#  'at;ba' 'fr;pt' 'ru;ua-dpr' 'au;mu' 'az;suhh' 'eu;gr' 'am;suhh' 'nc'
#  'suhh;tm' 'at;cn' 'lv;suhh' 'at;de;eu' 'at;it' 'bm;gb' 'pt;tl' 'dk;eu'
#  'lt;pl' 'dk;fo' 'my;sr' 'eu;sk' 'ch;it' 'eu;lt' 'ca;gb;us' 'dd;de;eu'
#  'bg;eu' 'al;xk' 'ee;fm' 'cshh;cz;se' 'es;ma' 'hu;il' 'cz;de'
#  'eu;gb;gb-wls' 'eu;mt' 'cshh;hu' 'csxx;rs' 'ch;fr' 'suhh;tj' 'ua;us'
#  'ca;suhh;ua' 'il;ps' 'us;ye' 'bg;us' 'bg;gb' 'ch;xk' 'ge;suhh;x-so'
#  'ch;us' 'dk;us' 'hu;ro' 'ee;ru' 'ee;lt' 'eu;si;yucs' 'jp;kr' 'ki;tv'
#  'cn;sg' 'lt;suhh' 'gb;je' 'rs;yucs' 'bm;gb;im' 'ee;hu' 'fr;il;tr'
#  'ge;suhh;ua' 'us;vu' 'de;hu' 'ca;fr;ht' 'at;tr' 'cd;de' 'eu;lu' 'jp;pe'
#  'es;fr' 'ee;eu' 'eu;lv;suhh' 'at;de' 'ru;suhh;x-so' 'it;va' 'cshh;cz;eu'
#  'cz;eu;us' 'ge;ge-ab;suhh' 'br;it' 'ca;cshh' 'eu;fi' 'iq;ir' 'eu;lt;suhh'
#  'co;hn' 'md-pmr;ua' 'cy;eu' 'hr;us' 'hr;yucs' 'hr;nl' 'es;mx' 'gb;gi'
#  'cn;gb;hk' 'in;ke' 'rw;ug' 'am;az-nk;suhh' 'eu;lv' 'es;eu;mx' 'suhh;x-so'
#  'gr;us' 'co;fr' 'fr;tn' 'ca;gb' 'fr;tg' 'py;us' 'ge;ge-ab' 'ba;hr'
#  'cf;fr' 'ge;x-so' 'fk' 'tz;us' 'va' 'kg;suhh' 'cn;mn' 'mo' 'ba;yucs'
#  'lk;my' 'qa;us' 'au;ca' 'ad;es' 'au;vn' 'ca;ir' 'au;gr' 'in;iq' 'au;kh'
#  'de;iq' 'pr' 'ca;so' 'kn;us' 'gu;us' 'sv;us' 'gb;pk' 'hr;rs' 'ru;x-so'
#  'mf' 'az;ru;suhh' 'de;lv;suhh' 'cn;co' 'az-nk;suhh' 'me;th'
#  'ru;suhh;ua-dpr' 'jm;lc' 'suhh;ua;ua-dpr' 'cr;es' 'pf' 'wf' 'gb-sct;za'
#  'mt;us' 'cshh;de' 'rw;us' 'it;lu' 'it;us' 'cn;mo' 'tw;us' 'eu;it;us'
#  'eu;gb;ie' 'au;cy-trnc' 'cg;gb' 'cn;us' 'gu' 'il;pt;ru;suhh' 'cl;es'
#  'ar;es;eu' 'af;us' 'cy;gr' 'eu;hu;ua' 'gb-nir;ie' 'fr;pf' 'us;va'
#  'suhh;ua-dpr' 'cshh;us' 'gi;in' 'co;ec' 'ag;gb' 'az-nk;suhh;ua' 'fi;no'
#  'am;fr' 'al;fr' 'ge-ab;ru' 'gb;us' 'cz;sk' 'ng;us' 'jo;ps' 'af;lb;us'
#  'co;mx' 'suhh;ua;ua-lpr' 'gb;ir' 'fr;mg' 'ar;es' 'lt;suhh;ua' 'bo;se'
#  'rs;so' 'ch;hu' 'md-pmr;ru' 'it;mc' 'cn;cn-xz' 'cn;hk;us' 'ca;gb;ie'
#  'ar;it' 'lb;sa' 'xk;yucs' 'om;us' 'dm;gb;gb-nir' 'au;it' 'ch;tr' 'be;cd'
#  'lb;ps' 'kr;us' 'ge-ab;suhh' 'il;ru;suhh' 'at;ru;suhh' 'be;bf;eu' 'fr;md'
#  'gr;ru;suhh' 'nu;nz' 'lt;pl;suhh' 'hr;si' 'kp;kr' 'cr;pe' 'csxx;me;yucs'
#  'il;suhh' 'al;us' 'md-pmr;ru;suhh' 'md-pmr;ru;suhh;ua' 'fr;sa' 'sa;tn'
#  'am;az-nk' 'mk;yucs' 'mx;py' 'ca;nz' 'az;by' 'lt;lv' 'ir;us' 'bd;gb;pk'
#  'kg;ru;suhh' 'as' 'gb;in' 'de;ro' 'de;no' 'eu;fr;sn' 'nl;us' 'cg;de'
#  'at;pl' 'cn;hk;tw' 'mp;us' 'cw' 'er;us' 'af;ee' 'be;ir' 'ec;fr;gb'
#  'cm;fr' 'gb;sy' 'fm;id' 'ca;hk' 'bz;us' 'gb;it' 'am;us' 'cd;cg' 'mz;za'
#  'cshh;cz;ru' 'py;uy' 'gb;ro' 'md;us' 'pe;us' 'be;gn' 'eu;fr;ro'
#  'ca;fr;ru;us' 'ca;is' 'be;us' 'ru;suhh;uz' 'br;il' 'il;it' 'ck;nz' 'yucs'
#  'lv;ru;suhh' 'gb;iq;us' 'at;us' 'au;lk' 'ca;cn' 'fr;ge' 'co;ec;us'
#  'au;to' 'au;kr' 'pa;us' 'ba;eu' 'nl;se' 'au;zw' 'bl' 'me;yucs' 'mx;us'
#  'jo;pk' 'eg;sd' 'es;pr;us' 'be;ie' 'no;us' 'cl;fr' 'ci;fr' 'fr;pm'
#  'es;in' 'no;so' 'vi' 'gb;ru;suhh' 'fr;us' 'au;cn' 'eg;jo' 'fj;in' 'co;it'
#  'pt;st' 'eg;gr' 'be;fr' 'au;us' 'ca;tw' 'fr;ro' 'ar;il' 'ch;lb'
#  'de;eu;tr' 'fr;nc' 'au;gb;nz' 'ge;ge-ab;ru;suhh' 'gb;iq;lb' 'gb;pn'
#  'ca;ro' 'ca;es' 'dz;fr' 'ci;ga' 'bj;fr' 'ch;cl' 'be;tn' 'eg;us'
#  'de;eu;pl' 'be;tr' 'csxx;rs;xk;yucs' 'ar;ca' 'gb;za' 'gb;jm' 'gb;iq'
#  'gb;ge' 'ee;mm' 'fr;ru;suhh' 'be;ma' 'es;gq' 'es;eu;gb' 'ba;rs;yucs'
#  'cshh;de;eu' 'cshh;eu' 'bo;ve' 'ae;iq' 'sd;tn' 'ba;rs' 'it;ps' 'it;mt'
#  'ag;us' 'il;ma' 'ee;jo' 'ee;fi' 'lv;us' 'bo;es' 'dz;it' 'mp' 'cy;eu;it'
#  'be;eu;it' 'ru;suhh;tm' 'mc;us' 'il;us' 'it;uy' 'by;cz' 'il;lt' 'ir;se'
#  'cg;it' 'eg;tr' 'am;az-nk;ru;suhh' 'ro;ua' 'tr;us' 'jp;us' 'am;ru;suhh'
#  'hu;suhh' 'at;ba;yucs' 'ru;suhh;ua;ua-cri' 'ee;ru;suhh' 'md;md-pmr'
#  'si;us;yucs' 'ag;bs;bz;ca;gb;im;jm;kn;lc;nz;pg;sb;tv' 'ar;si' 'ru;tr'
#  'bg;ua' 'be;mr' 'ge;ua' 'eu;it;se' 'sk;suhh' 'cn;suhh' 'ar;va'
#  'il;md;suhh' 'au;za' 'fr;mf' 'my;sg' 'eg;eu;it' 'ar;nl' 'fr;no'
#  'ee;eu;suhh' 'eu;fr;no' 'de;ru;suhh' 'jp;tw' 'ba;hr;yucs' 'ee;ne' 'gb;zm'
#  'au;tr' 'iq;us' 'es;hn' 'ec;us' 'cu;us' 'fr;hu' 'it;pe' 'ca;ie' 'gb;hk'
#  'bd;gb;ky;pk' 'in;us' 'de;dk' 'fi;jp' 'au;va' 'es;va' 'va;ve' 'de;it'
#  'nz;us' 'br;pe' 'nz;to' 'fj;nr' 'fj;ki' 'at;si' 'ir;no' 'au;gb;gb-wls'
#  'au;lb' 'eu;hu;ro' 'hn;us' 'ca;eu' 'bj;ht' 'bo;ph' 'al;ee' 'id;my'
#  'ca;it' 'ee;jp' 'co;ve' 'kz;ru;suhh' 'in;za' 'hu;pl' 'es;iq' 'es;uy'
#  'de;no;us' 'ao;pt' 'bf;ci' 'ni;sv' 'ca;iq' 'dj;fr' 'cg;fr' 'at;li'
#  'it;pa' 'au;lv' 'rs;th' 'ar;cl' 'cg;ee' 'gd;us' 'gt;it' 'br;co' 'do;us'
#  'ir;pk' 'cn;pl' 'bo;cl' 'at;es' 'ar;bo' 'ca;cl' 'cr;ni' 'mz;us' 'my;ng'
#  'gb;mt' 'ch;de;eu;fr' 'eu;si' 'br;es' 'au;mt' 'cshh;eu;sk' 'at;eu;hu'
#  'es;eu;ve' 'ag;bz;gy' 'ca;gb;gb-sct' 'de;eu;gb' 'ee;us' 'eu;ie;us'
#  'au;sy' 'at;au' 'cv;fr' 'dk;tr' 'cy-trnc;gb' 'nz;ph' 'csxx' 'no;tn'
#  'es;gt' 'ch;gb;ro' 'au;yucs' 'es;sn' 'it;si' 'bz;gy;lc' 'il;ua' 'sc;us'
#  'us;vi' 'gb;il' 'eg;gb' 'gw;pt' 'ca;cn;hk' 'am;ke' 'us;ve' 'pl;sy'
#  'ga;us' 'gb;tm' 'am;lb' 'ao;cg' 'ph;us' 'cn;gb' 'in;my' 'iq;se' 'hr;mk'
#  'de;eu;fr' 'gb;il;ru;ua' 'ca;pk' 'gb;pe' 'au;nr' 'cn;hk;pt' 'ug;us'
#  'hu;yucs' 'br;de' 'au;hu' 'gb;gb-nir;ie' 'lr;ng' 'ch;li' 'pk;us' 'au;uy'
#  'af;de' 'gb-wls;zw' 'at;ee' 'ro;us' 'fr;in' 'il;pl' 'md;ru;ua' 'lu;us'
#  'ph;va' 'in;tw' 'at;ca' 'md;md-pmr;suhh' 'at;gb' 'za;zw' 'jp;tw;us'
#  'kg;kz' 'am;gb;suhh' 'pl;ua' 'pn' 'bi;ee' 'ee;zw' 'ci;it' 'ba;de'
#  'au;gb;pg' 'ag;bs;bz;ca;gb;im;jm;kn;lc;nz;sb' 'cd;cm' 'au;de'
#  'mc;suhh;ua' 'au;lt' 'ga;gb' 'de;sy' 'au;ps' 'ng;zw' 'ee;kr' 'au;ee'
#  'ca;ee' 'mx;nz' 'ee;mn' 'iq;ps' 'be;dk' 'be;de' 'gg-srk' 'sh' 'sx' 'nf'
#  'fr;ru' 'ae;ru' 'by;pl' 'by;hu' 'at;kz;ru' 'cn;ru' 'by;uz' 'pl;ru'
#  'am;ru' 'at;ru' 'gr;il;ru' 'de;md;ru' 'de;ru;ua' 'by;ru;uz' 'kz;mn;pl;ru'
#  'az;de;ru' 'il;ru' 'de;hu;ru' 'fi;gb;ke;ru' 'dk;ru' 'gr;ru' 'hr;ru']
# ['Person']
# ['20220119' '20220101' '20220622' '20221113' '20220521' '20220503'
#  '20220505' '20220512' '20220506' '20220304' '20220222' '20221212'
#  '20221110' '20220510' '20220516' '20220919' '20220226' '20220718'
#  '20220422' '20221120' '20220121' '20220614' '20220411' '20220927'
#  '20220711' '20220722' '20220920' '20220929' '20221231' '20221119'
#  '20220808' '20220517' '20221025' '20220302' '20221010' '20220416'
#  '20220312' '20220514' '20220724' '20220204' '20220225' '20221202'
#  '20220608' '20220705' '20220723' '20220223' '20220713' '20220315'
#  '20220208' '20220502' '20220612' '20220227' '20221117' '20221219'
#  '20220709' '20220418' '20221018' '20220708' '20220630' '20221026'
#  '20220703' '20220623' '20220729' '20220501' '20221204' '20220316'
#  '20220408' '20220721' '20220819' '20220305' '20221207' '20220509'
#  '20220425' '20221121' '20220715' '20221109' '20221205' '20220712'
#  '20220823' '20220317' '20221017' '20221023' '20220211' '20220314'
#  '20220701' '20221130' '20220805' '20220428' '20221222' '20220727'
#  '20221031' '20220531' '20221129' '20220115' '20220329' '20220216'
#  '20221230' '20220202' '20220105' '20220107' '20220303' '20220228'
#  '20221007' '20221229' '20221015' '20220404' '20220601' '20220326'
#  '20221114' '20220811' '20220106' '20220901' '20220218' '20220217'
#  '20220810' '20220201' '20220421' '20220219' '20220122' '20220611'
#  '20220109' '20220412' '20221211' '20220728' '20221127' '20220125'
#  '20221208' '20220526' '20220527' '20220602' '20220523' '20221022'
#  '20220913' '20221213' '20221206' '20220905' '20221014' '20220915'
#  '20220117' '20220321' '20220124' '20221218' '20220410' '20220212'
#  '20220704' '20220814' '20221118' '20220809' '20221021' '20221209'
#  '20220822' '20220110' '20220916' '20221124' '20221122' '20220626'
#  '20220414' '20221003' '20220716' '20220206' '20220309' '20220330'
#  '20220603' '20220816' '20220120' '20220802' '20221105' '20220619'
#  '20220914' '20220205' '20220817' '20220104' '20220311' '20220328'
#  '20220213' '20220426' '20221009' '20220129' '20220108' '20220126'
#  '20220401' '20220504' '20220210' '20220618' '20220413' '20220313'
#  '20220812' '20221001' '20220522' '20221020' '20221019' '20220306'
#  '20221024' '20220606' '20220528' '20220828' '20220320' '20220831'
#  '20220325' '20220628' '20221210' '20221220' '20220921' '20220912'
#  '20220123' '20220118' '20220508' '20220220' '20220624' '20220609'
#  '20221011' '20220301' '20220507' '20220429' '20221203' '20220511'
#  '20220209' '20220620' '20220804' '20221029' '20220520' '20221016'
#  '20220518' '20220909' '20221013' '20221221' '20220215' '20220610'
#  '20220830' '20221008' '20221005' '20220928' '20220604' '20220308'
#  '20221012' '20221030' '20220706' '20220930' '20220824' '20220923'
#  '20220906' '20220710' '20220319' '20220323' '20220613' '20220427'
#  '20220725' '20220615' '20220731' '20220825' '20221027' '20220529'
#  '20221102' '20220127' '20220103' '20220803' '20220221' '20220111'
#  '20220625' '20220130' '20220203' '20220420' '20221125' '20220407'
#  '20220719' '20220911' '20220720' '20221112' '20220405' '20220406'
#  '20220409' '20221215' '20220813' '20220423' '20220621' '20220714'
#  '20220530' '20221214' '20220829' '20220826' '20221002' '20221004'
#  '20221107' '20220925' '20220730' '20220806' '20221108' '20220821'
#  '20221006' '20221101' '20220904' '20220907' '20220918' '20220926'
#  '20221028' '20221106' '20221111' '20221115' '20221123' '20221228'
#  '20221227' '20220112' '20220307' '20221223' '20220324' '20220419'
#  '20220322' '20220214' '20220224' '20220702' '20220113' '20220424'
#  '20221126' '20220908' '20220807' '20220605' '20220402' '20221216'
#  '20220102' '20220403' '20220524' '20220917' '20221104' '20220318'
#  '20220331' '20220515' '20220607' '20220430' '20220707' '20220519'
#  '20220627' '20220525' '20220801' '20221103' '20221224']

# %%
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
# Out:
# id                     0
# schema                 0
# name                   0
# aliases           111668
# birth_date         90596
# countries           5812
# addresses         236623
# identifiers        67049
# sanctions         237248
# phones            232548
# emails            227548
# dataset                0
# last_seen              0
# first_seen             0
# date_stamp             0
# new_entry              0
# deletion               0
# unchanged              0
# month                  0
# listing_date           0
# delisting_date    232113
# dtype: int64

# %%
res_deduplicated.columns
# Out:
# Index(['id', 'schema', 'name', 'aliases', 'birth_date', 'countries',
#        'addresses', 'identifiers', 'sanctions', 'phones', 'emails', 'dataset',
#        'last_seen', 'first_seen', 'date_stamp', 'new_entry', 'deletion',
#        'unchanged', 'month', 'listing_date', 'delisting_date'],
#       dtype='object')

# %%
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
# Out:
#                                                        id  schema  \
# 0                               NK-22qMyyFP4bD3QhZ7BAFXs6  Person
# 1                               NK-232XviNCU8o2PiPCQC3Cg2  Person
# 2                               NK-24isa6tapAYCqtEnqbUdzv  Person
# 3                               NK-25Z3H4pijwnkYMmpybVYzQ  Person
# 4                               NK-26h6Ukv23GDmJUyhgmK5ML  Person
# ...                                                   ...     ...
# 237243  us-cia-zimbabwe-obadiah-moyo-min-of-health-chi...  Person
# 237244  us-cia-zimbabwe-oppah-muchinguri-kashiri-min-o...  Person
# 237245  us-cia-zimbabwe-sekai-nzenza-min-of-industry-c...  Person
# 237246  us-cia-zimbabwe-sibusiso-moyo-lt-gen-ret-min-o...  Person
# 237247  us-cia-zimbabwe-winston-chitando-min-of-mines-...  Person
#
#                                       name  \
# 0                        SAKAMOTO Tetsushi
# 1                      AMASSOUMOU NDIFOANE
# 2                       DEMIDOVICH VASILIJ
# 3              Мария Владимировна Пирогова
# 4       Aleksandr Aleksandrovich Zhuravlev
# ...                                    ...
# 237243                        Obadiah MOYO
# 237244            Oppah MUCHINGURI-KASHIRI
# 237245                        Sekai NZENZA
# 237246      Sibusiso MOYO, Lt. Gen. (Ret.)
# 237247                    Winston CHITANDO
#
#                                                   aliases  birth_date  \
# 0                                                     NaN         NaN
# 1                                                     NaN  1951-10-24
# 2       Demidovich Vasili Nikolaevich;Demidovich Vasil...  1961-12-24
# 3       Mariya Vladimirovna Pirogova;Pirogova Mariia V...  1993-05-13
# 4                        Александр Александрович Журавлёв         NaN
# ...                                                   ...         ...
# 237243                                                NaN         NaN
# 237244                                                NaN         NaN
# 237245                                                NaN         NaN
# 237246                                                NaN         NaN
# 237247                                                NaN         NaN
#
#        countries addresses identifiers  sanctions phones  ...  \
# 0             jp       NaN         NaN        NaN    NaN  ...
# 1             cm       NaN         NaN        NaN    NaN  ...
# 2             by       NaN         NaN        NaN    NaN  ...
# 3          ru;ua       NaN  3410105889        NaN    NaN  ...
# 4            NaN       NaN         NaN        NaN    NaN  ...
# ...          ...       ...         ...        ...    ...  ...
# 237243        zw       NaN         NaN        NaN    NaN  ...
# 237244        zw       NaN         NaN        NaN    NaN  ...
# 237245        zw       NaN         NaN        NaN    NaN  ...
# 237246        zw       NaN         NaN        NaN    NaN  ...
# 237247        zw       NaN         NaN        NaN    NaN  ...
#
#                   last_seen           first_seen date_stamp new_entry  \
# 0       2021-07-26 11:55:45  2022-01-19 01:27:13   20220119      True
# 1       2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 2       2022-06-22 18:15:31  2021-07-26 11:55:45   20220622      True
# 3       2022-11-13 18:15:42  2022-11-12 06:20:00   20221113      True
# 4       2022-05-21 18:14:04  2022-05-21 06:15:45   20220521      True
# ...                     ...                  ...        ...       ...
# 237243  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237244  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237245  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237246  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
# 237247  2021-07-26 11:55:45  2022-01-01 03:04:33   20220101      True
#
#        deletion  unchanged    month  listing_date delisting_date  \
# 0         False      False  2022-01      20220119            NaN
# 1         False      False  2022-01      20220101            NaN
# 2         False      False  2022-06      20220622            NaN
# 3         False      False  2022-11      20221113            NaN
# 4         False      False  2022-05      20220521            NaN
# ...         ...        ...      ...           ...            ...
# 237243    False      False  2022-01      20220101            NaN
# 237244    False      False  2022-01      20220101            NaN
# 237245    False      False  2022-01      20220101            NaN
# 237246    False      False  2022-01      20220101            NaN
# 237247    False      False  2022-01      20220101            NaN
#
#        new_listing_count
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 237243                 1
# 237244                 1
# 237245                 1
# 237246                 1
# 237247                 1
#
# [237248 rows x 22 columns]

# %%
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)

# %% [markdown]
# save and zip the file

# %%
import zipfile
import io
import pickle

def compress_df_to_zip(df, zip_filename, df_filename):
    # Create an in-memory binary stream
    buffer = io.BytesIO()

    # Serialize the DataFrame using pickle
    pickle.dump(df, buffer)

    # Reset the buffer position to the beginning
    buffer.seek(0)

    # Create a zip file and add the serialized DataFrame to it
    with zipfile.ZipFile(zip_filename, 'w', compression=zipfile.ZIP_DEFLATED) as zip_file:
        zip_file.writestr(df_filename, buffer.getvalue())

# Example usage:
# Assuming df is your Pandas DataFrame
df = res

# Specify the filenames
zip_filename = 'data_pep3.zip'
df_filename = 'data_pep3.pkl'

# Compress the DataFrame and save it to a zip file
compress_df_to_zip(df, zip_filename, df_filename)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 28
#      25 df_filename = 'data_pep3.pkl'
#      27 # Compress the DataFrame and save it to a zip file
# ---> 28 compress_df_to_zip(df, zip_filename, df_filename)
#
# Cell In[22], line 17, in compress_df_to_zip(df, zip_filename, df_filename)
#      15 # Create a zip file and add the serialized DataFrame to it
#      16 with zipfile.ZipFile(zip_filename, 'w', compression=zipfile.ZIP_DEFLATED) as zip_file:
# ---> 17     zip_file.writestr(df_filename, buffer.getvalue())
#
# File C:\ProgramData\anaconda3\Lib\zipfile.py:1835, in ZipFile.writestr(self, zinfo_or_arcname, data, compress_type, compresslevel)
#    1833 with self._lock:
#    1834     with self.open(zinfo, mode='w') as dest:
# -> 1835         dest.write(data)
#
# File C:\ProgramData\anaconda3\Lib\zipfile.py:1169, in _ZipWriteFile.write(self, data)
#    1167     data = self._compressor.compress(data)
#    1168     self._compress_size += len(data)
# -> 1169 self._fileobj.write(data)
#    1170 return nbytes
#
# OSError: [Errno 28] No space left on device

# %%
#res.to_pickle('pep3.zip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\pickle.py:103, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#      95 with get_handle(
#      96     filepath_or_buffer,
#      97     "wb",
#    (...)
#     101 ) as handles:
#     102     # letting pickle write directly to the buffer is more memory-efficient
# --> 103     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\internals.pyx:619, in pandas._libs.internals.SharedBlock.__reduce__()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\internals.pyx:620, in pandas._libs.internals.SharedBlock.__reduce__()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:205, in Block.mgr_locs(self)
#     203     return value
# --> 205 @property
#     206 def mgr_locs(self) -> BlockPlacement:
#     207     return self._mgr_locs
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 res.to_pickle('pep3.zip')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:2955, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    2903 """
#    2904 Pickle (serialize) object to file.
#    2905
#    (...)
#    2951 4    4    9
#    2952 """  # noqa: E501
#    2953 from pandas.io.pickle import to_pickle
# -> 2955 to_pickle(
#    2956     self,
#    2957     path,
#    2958     compression=compression,
#    2959     protocol=protocol,
#    2960     storage_options=storage_options,
#    2961 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\pickle.py:95, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#      92 if protocol < 0:
#      93     protocol = pickle.HIGHEST_PROTOCOL
# ---> 95 with get_handle(
#      96     filepath_or_buffer,
#      97     "wb",
#      98     compression=compression,
#      99     is_text=False,
#     100     storage_options=storage_options,
#     101 ) as handles:
#     102     # letting pickle write directly to the buffer is more memory-efficient
#     103     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:138, in IOHandles.__exit__(self, *args)
#     137 def __exit__(self, *args: Any) -> None:
# --> 138     self.close()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:130, in IOHandles.close(self)
#     128     self.created_handles.remove(self.handle)
#     129 for handle in self.created_handles:
# --> 130     handle.close()
#     131 self.created_handles = []
#     132 self.is_wrapped = False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:947, in _BufferedWriter.close(self)
#     945     # error: "_BufferedWriter" has no attribute "buffer"
#     946     with self.buffer:  # type: ignore[attr-defined]
# --> 947         self.write_to_buffer()
#     948 else:
#     949     # error: "_BufferedWriter" has no attribute "buffer"
#     950     self.buffer.close()  # type: ignore[attr-defined]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:1042, in _BytesZipFile.write_to_buffer(self)
#    1039 def write_to_buffer(self) -> None:
#    1040     # ZipFile needs a non-empty string
#    1041     archive_name = self.archive_name or self.infer_filename() or "zip"
# -> 1042     self.buffer.writestr(archive_name, self.getvalue())
#
# File C:\ProgramData\anaconda3\Lib\zipfile.py:1835, in ZipFile.writestr(self, zinfo_or_arcname, data, compress_type, compresslevel)
#    1833 with self._lock:
#    1834     with self.open(zinfo, mode='w') as dest:
# -> 1835         dest.write(data)
#
# File C:\ProgramData\anaconda3\Lib\zipfile.py:1169, in _ZipWriteFile.write(self, data)
#    1167     data = self._compressor.compress(data)
#    1168     self._compress_size += len(data)
# -> 1169 self._fileobj.write(data)
#    1170 return nbytes
#
# OSError: [Errno 28] No space left on device

# %%
res.to_csv("res.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:259, in CSVFormatter.save(self)
#     249 self.writer = csvlib.writer(
#     250     handles.handle,
#     251     lineterminator=self.lineterminator,
#    (...)
#     256     quotechar=self.quotechar,
#     257 )
# --> 259 self._save()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:264, in CSVFormatter._save(self)
#     263     self._save_header()
# --> 264 self._save_body()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:302, in CSVFormatter._save_body(self)
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_chunk(self, start_i, end_i)
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313 libwriters.write_csv_rows(
#     314     data,
#     315     ix,
#     316     self.nlevels,
#     317     self.cols,
#     318     self.writer,
#     319 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\writers.pyx:55, in pandas._libs.writers.write_csv_rows()
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 res.to_csv("res.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:138, in IOHandles.__exit__(self, *args)
#     137 def __exit__(self, *args: Any) -> None:
# --> 138     self.close()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:130, in IOHandles.close(self)
#     128     self.created_handles.remove(self.handle)
#     129 for handle in self.created_handles:
# --> 130     handle.close()
#     131 self.created_handles = []
#     132 self.is_wrapped = False
#
# OSError: [Errno 28] No space left on device

# %%
#import zipfile

#def compress_csv(input_csv, output_zip):
   # with zipfile.ZipFile(output_zip, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
        #zipf.write(input_csv)
#input_csv = 'res.csv'
#output_zip = 'peps_csv2.zip'
#compress_csv(input_csv, output_zip)
