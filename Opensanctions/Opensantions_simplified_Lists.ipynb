# %% [markdown]
# **This is the simplified Opensantions data in csv format**

# %%
#import packages
import requests
import pandas as pd
import numpy as np
import datetime
import os
import re

# %% [markdown]
# # Retrieval of the data

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20231231',freq='D').strftime('%Y%m%d')
date_list
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=883)

# %%
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []

for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/us_ofac_sdn/targets.simple.csv'
    websites.append(test)
print(websites)
# Out:
# ['https://data.opensanctions.org/datasets/20210801/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210915/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210916/us_ofac_sdn/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210917/us_ofac_sdn/targets.simple.csv', 'https://data.o ...

# %% [markdown]
# #first check for missing days
# for site in websites:
#     try:
#         response = requests.get(site)
#         response.raise_for_status()  # Raises an HTTPError for bad response
#     except requests.exceptions.RequestException as e:
#         print(f"Error accessing {site}: {e}")
#         continue

# %%
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes

# %%
res
# Out:
#                    id        schema  \
# 0      ofac-sdn-10000        Person
# 1      ofac-sdn-10001  Organization
# 2      ofac-sdn-10002  Organization
# 3      ofac-sdn-10003  Organization
# 4      ofac-sdn-10004  Organization
# ...               ...           ...
# 13772      ofac-47041        Vessel
# 13773      ofac-47068  Organization
# 13774      ofac-47069        Person
# 13775      ofac-47088  Organization
# 13776      ofac-47089  Organization
#
#                                                     name  \
# 0                              Jhon Eidelber CANO CORREA
# 1               INVERSIONES MACARNIC PATINO Y CIA S.C.S.
# 2      COMERCIALIZADORA DE CAFE DEL OCCIDENTE CODECAF...
# 3                                      GOMEZ MARIN LTDA.
# 4                                         GAVIOTAS LTDA.
# ...                                                  ...
# 13772                                           SANAR 15
# 13773            Nabco Money Exchange and Remittance Co.
# 13774                           Nabil Ali Ahmed Al-Hadha
# 13775      Al Rawda Exchange and Money Transfers Company
# 13776  Al Aman Kargo Ithalat Ihracat Ve Nakliyat Limi...
#
#                                                  aliases  birth_date  \
# 0         Alejandro CARDONA RIBILLAS;FLECHAS;Jhonny CANO  1963-12-13
# 1                                                    NaN         NaN
# 2                                               CODECAFE         NaN
# 3                                                    NaN         NaN
# 4       HOTEL SIN PECADOS;HOTEL SIN PK2;MOTEL CAMPO AMOR         NaN
# ...                                                  ...         ...
# 13772                                                NaN         NaN
# 13773  NABCO MONEY EXCHANGE & REMITTANCE CO.;Nabako M...         NaN
# 13774                 Nabil al-Haza';نبیل علي أحمد الحظا  1975-02-02
# 13775  Al Rawda Exchange and Transfers Co.;Al Rawdah ...         NaN
# 13776                                   Al Aman Co Kargo         NaN
#
#       countries                                          addresses  \
# 0            co  Calle 18 No. 8-16, Cartago, Valle, Colombia;Ca...
# 1            co  Calle 19 No. 9-50, Ofc. 505, Pereira, Risarald...
# 2            co  Carrera 8 No. 23-09, Ofc. 903, Pereira, Risara...
# 3            co  Calle 16 No. 1N-74, Cartago, Valle, Colombia;K...
# 4            co  Calle 4A No. 21-34 Circunvalar, Cartago, Valle...
# ...         ...                                                ...
# 13772        ru                                                NaN
# 13773        ye  Al-Khamis Street, Lebanese University Neighbor...
# 13774        ye                                                NaN
# 13775        ye  Airport Line, Al-Jumna Roundabout, Sana'a;Al-H...
# 13776        tr  11 Eylul Cd., No. 32, Yavus Selim, Bursa;Cakma...
#
#                       identifiers  \
# 0               16217170;16455750
# 1                     816005011-4
# 2                     816004106-0
# 3                     800102465-1
# 4                     800032092-7
# ...                           ...
# 13772  273375360;IMO 9777670;UALW
# 13773                         NaN
# 13774                    08928715
# 13775                         NaN
# 13776             919198;921643-0
#
#                                                sanctions phones emails  \
# 0      SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 1      SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 2      SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 3      SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 4      SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# ...                                                  ...    ...    ...
# 13772          SDN List - Executive Order 14024 (Russia)    NaN    NaN
# 13773       SDN List - Executive Order 13224 (Terrorism)    NaN    NaN
# 13774       SDN List - Executive Order 13224 (Terrorism)    NaN    NaN
# 13775       SDN List - Executive Order 13224 (Terrorism)    NaN    NaN
# 13776       SDN List - Executive Order 13224 (Terrorism)    NaN    NaN
#
#                                                  dataset            last_seen  \
# 0      US OFAC Specially Designated Nationals (SDN) List  2021-07-26 11:55:45
# 1      US OFAC Specially Designated Nationals (SDN) List  2021-07-26 11:55:45
# 2      US OFAC Specially Designated Nationals (SDN) List  2021-07-26 11:55:45
# 3      US OFAC Specially Designated Nationals (SDN) List  2021-07-26 11:55:45
# 4      US OFAC Specially Designated Nationals (SDN) List  2021-07-26 11:55:45
# ...                                                  ...                  ...
# 13772  US OFAC Specially Designated Nationals (SDN) List  2023-12-31T22:10:01
# 13773  US OFAC Specially Designated Nationals (SDN) List  2023-12-31T22:10:01
# 13774  US OFAC Specially Designated Nationals (SDN) List  2023-12-31T22:10:01
# 13775  US OFAC Specially Designated Nationals (SDN) List  2023-12-31T22:10:01
# 13776  US OFAC Specially Designated Nationals (SDN) List  2023-12-31T22:10:01
#
#                 first_seen date_stamp          last_change
# 0      2021-08-20 20:39:54   20210820                  NaN
# 1      2021-08-20 20:39:54   20210820                  NaN
# 2      2021-08-20 20:39:54   20210820                  NaN
# 3      2021-08-20 20:39:54   20210820                  NaN
# 4      2021-08-20 20:39:54   20210820                  NaN
# ...                    ...        ...                  ...
# 13772  2023-12-20T16:10:01   20231231  2023-12-20T16:10:01
# 13773  2023-12-28T16:10:01   20231231  2023-12-28T16:10:01
# 13774  2023-12-28T16:10:01   20231231  2023-12-28T16:10:01
# 13775  2023-12-28T16:10:01   20231231  2023-12-28T16:10:01
# 13776  2023-12-28T16:10:01   20231231  2023-12-28T16:10:01
#
# [9487484 rows x 16 columns]

# %% [markdown]
# # Match the dates against each other

# %%
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows

# Reset index for the final result
res.reset_index(drop=True, inplace=True)

# %%
res
# Out:
#                                 id        schema                         name  \
# 0        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 1        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 2        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 3        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 4        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# ...                            ...           ...                          ...
# 9487479              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487480              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487481              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487482              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487483              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
#
#                        aliases  birth_date countries  \
# 0        BANNA PROPERTIES;BENA         NaN        sy
# 1        BANNA PROPERTIES;BENA         NaN        sy
# 2        BANNA PROPERTIES;BENA         NaN        sy
# 3        BANNA PROPERTIES;BENA         NaN        sy
# 4        BANNA PROPERTIES;BENA         NaN        sy
# ...                        ...         ...       ...
# 9487479                 MECHAS  1950-07-24        co
# 9487480                 MECHAS  1950-07-24        co
# 9487481                 MECHAS  1950-07-24        co
# 9487482                 MECHAS  1950-07-24        co
# 9487483                 MECHAS  1950-07-24        co
#
#                                                  addresses identifiers  \
# 0        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 1        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 2        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 3        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 4        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# ...                                                    ...         ...
# 9487479  Carrera 13 No. 18-50, Cartago, Valle, Colombia...    16202349
# 9487480  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487481  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487482  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487483  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
#
#                                                  sanctions phones emails  \
# 0        Block - Program - SDN List - Executive Order 1...    NaN    NaN
# 1        Program - SDN List - Block - Executive Order 1...    NaN    NaN
# 2        Program - SDN List - Block - Executive Order 1...    NaN    NaN
# 3        Block - SDN List - Program - Executive Order 1...    NaN    NaN
# 4        Program - Block - SDN List - Executive Order 1...    NaN    NaN
# ...                                                    ...    ...    ...
# 9487479  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 9487480  Program - SDN List - Block - Unknown - 2006-10-25    NaN    NaN
# 9487481  Block - SDN List - Program - Unknown - 2006-10-25    NaN    NaN
# 9487482  Program - Block - SDN List - Unknown - 2006-10-25    NaN    NaN
# 9487483  Block - SDN List - Program - Unknown - 2006-10-25    NaN    NaN
#
#                                                    dataset  \
# 0        US OFAC Specially Designated Nationals (SDN) List
# 1        US OFAC Specially Designated Nationals (SDN) List
# 2        US OFAC Specially Designated Nationals (SDN) List
# 3        US OFAC Specially Designated Nationals (SDN) List
# 4        US OFAC Specially Designated Nationals (SDN) List
# ...                                                    ...
# 9487479  US OFAC Specially Designated Nationals (SDN) List
# 9487480  US OFAC Specially Designated Nationals (SDN) List
# 9487481  US OFAC Specially Designated Nationals (SDN) List
# 9487482  US OFAC Specially Designated Nationals (SDN) List
# 9487483  US OFAC Specially Designated Nationals (SDN) List
#
#                    last_seen           first_seen date_stamp last_change  \
# 0        2021-09-30 11:39:21  2021-09-30 11:39:21   20210930         NaN
# 1        2021-09-30 11:39:21  2021-10-01 03:02:43   20211001         NaN
# 2        2021-09-30 11:39:21  2021-10-02 03:03:02   20211002         NaN
# 3        2021-09-30 11:39:21  2021-10-03 08:46:36   20211003         NaN
# 4        2021-09-30 11:39:21  2021-10-04 03:02:58   20211004         NaN
# ...                      ...                  ...        ...         ...
# 9487479  2021-07-26 11:55:45  2021-09-24 03:02:55   20210925         NaN
# 9487480  2021-09-26 14:52:11  2021-09-26 14:52:11   20210926         NaN
# 9487481  2021-09-26 14:52:11  2021-09-27 09:09:30   20210927         NaN
# 9487482  2021-09-26 14:52:11  2021-09-28 03:03:19   20210928         NaN
# 9487483  2021-09-26 14:52:11  2021-09-29 03:02:51   20210929         NaN
#
#          new_entry  deletion  unchanged
# 0             True     False      False
# 1            False     False       True
# 2            False     False       True
# 3            False     False       True
# 4            False      True      False
# ...            ...       ...        ...
# 9487479      False     False       True
# 9487480      False     False       True
# 9487481      False     False       True
# 9487482      False     False       True
# 9487483      False      True      False
#
# [9487484 rows x 19 columns]

# %%
#test thematching function
test = res.query('new_entry == True')
test
# Out:
#                                 id        schema  \
# 0        NK-226JTDehVMSXex35EbKPmi  Organization
# 5        NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 827      NK-22iRdVwQHXiYMCAASM93qH  Organization
# 844      NK-22jYwFUGYJxd6bKdMnxb22  Organization
# 856      NK-22oMG6jqPQknWaMjzTn4hK       Company
# ...                            ...           ...
# 9487281              ofac-sdn-9993        Person
# 9487320              ofac-sdn-9994        Person
# 9487361              ofac-sdn-9995        Person
# 9487402              ofac-sdn-9996        Person
# 9487443              ofac-sdn-9999        Person
#
#                                         name  \
# 0                            BENA PROPERTIES
# 5                            Michael Kuajien
# 827                          AL RASHID TRUST
# 844                       NEGIN PARTO KHAVAR
# 856      Limited Liability Company Garantiya
# ...                                      ...
# 9487281            Yolanda Sofia CANO ALZATE
# 9487320                Davinson GOMEZ OCAMPO
# 9487361        Carlos Arturo PATINO RESTREPO
# 9487402        Luis Alfonso GOMEZ BUSTAMANTE
# 9487443          Jose Aldemar RENDON RAMIREZ
#
#                                                    aliases  birth_date  \
# 0                                    BANNA PROPERTIES;BENA         NaN
# 5               Michael Kuajian;Michael Kuajien Duer Mayok  1979-01-01
# 827      AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# 844      ERTEBATE EGHTESSADE MONIR;NEGIN PARTO;NEGIN PA...         NaN
# 856                                          Garantiya OOO         NaN
# ...                                                    ...         ...
# 9487281                                                NaN  1957-04-25
# 9487320                                              GORDO  1960-07-10
# 9487361                                 PATE MURO;PATEMURO  1964-04-27
# 9487402                                                NaN  1953-11-01
# 9487443                                             MECHAS  1950-07-24
#
#         countries                                          addresses  \
# 0              sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 5           ke;ss                                Nairobi;South Sudan
# 827            pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# 844            ir  Tehran, Fatmi Gharabi Street, between Sindokht...
# 856            ru              bulvar Tverskoi, d. 15 str. 2, Moscow
# ...           ...                                                ...
# 9487281        co                       c/o GAVIOTAS LTDA., Colombia
# 9487320        co  Calle 16 No. 1-58, Cartago, Valle, Colombia;c/...
# 9487361        co  Calle 20 No. 6-30, Ofc. 1304, Pereira, Risaral...
# 9487402        co  Calle 1B No. 1-26, Barrio El Prado, Cartago, V...
# 9487443        co  Carrera 13 No. 18-50, Cartago, Valle, Colombia...
#
#                       identifiers  \
# 0                             NaN
# 5                             NaN
# 827                           NaN
# 844                           NaN
# 856      5067746901426;7703610362
# ...                           ...
# 9487281                  31399608
# 9487320                   2470433
# 9487361                   9991679
# 9487402                   4451571
# 9487443                  16202349
#
#                                                  sanctions phones emails  \
# 0        Block - Program - SDN List - Executive Order 1...    NaN    NaN
# 5        Program - Block - SDN List - Executive Order 1...    NaN    NaN
# 827      Block - Program - SDN List - Unknown - 2001-09-24    NaN    NaN
# 844      Block - Program - SDN List - Executive Order 1...    NaN    NaN
# 856      Block - SDN List - Program - Executive Order 1...    NaN    NaN
# ...                                                    ...    ...    ...
# 9487281  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 9487320  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 9487361  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 9487402  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
# 9487443  SDN List - Block - Program - Unknown - 2006-10-25    NaN    NaN
#
#                                                    dataset  \
# 0        US OFAC Specially Designated Nationals (SDN) List
# 5        US OFAC Specially Designated Nationals (SDN) List
# 827      US OFAC Specially Designated Nationals (SDN) List
# 844      US OFAC Specially Designated Nationals (SDN) List
# 856      US OFAC Specially Designated Nationals (SDN) List
# ...                                                    ...
# 9487281  US OFAC Specially Designated Nationals (SDN) List
# 9487320  US OFAC Specially Designated Nationals (SDN) List
# 9487361  US OFAC Specially Designated Nationals (SDN) List
# 9487402  US OFAC Specially Designated Nationals (SDN) List
# 9487443  US OFAC Specially Designated Nationals (SDN) List
#
#                    last_seen           first_seen date_stamp last_change  \
# 0        2021-09-30 11:39:21  2021-09-30 11:39:21   20210930         NaN
# 5        2021-09-26 14:52:11  2021-09-28 03:03:19   20210928         NaN
# 827      2021-07-26 11:55:45  2021-09-18 12:23:43   20210918         NaN
# 844      2021-07-26 11:55:45  2021-09-18 12:23:43   20210918         NaN
# 856      2023-02-26 18:35:08  2023-02-24 18:37:06   20230226         NaN
# ...                      ...                  ...        ...         ...
# 9487281  2021-07-26 11:55:45  2021-08-20 20:39:54   20210820         NaN
# 9487320  2021-07-26 11:55:45  2021-08-20 20:39:54   20210820         NaN
# 9487361  2021-07-26 11:55:45  2021-08-20 20:39:54   20210820         NaN
# 9487402  2021-07-26 11:55:45  2021-08-20 20:39:54   20210820         NaN
# 9487443  2021-07-26 11:55:45  2021-08-20 20:39:54   20210820         NaN
#
#          new_entry  deletion  unchanged
# 0             True     False      False
# 5             True     False      False
# 827           True     False      False
# 844           True     False      False
# 856           True     False      False
# ...            ...       ...        ...
# 9487281       True     False      False
# 9487320       True     False      False
# 9487361       True     False      False
# 9487402       True     False      False
# 9487443       True     False      False
#
# [29653 rows x 19 columns]

# %%
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
res
# Out:
#                                 id        schema                         name  \
# 0        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 1        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 2        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 3        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# 4        NK-226JTDehVMSXex35EbKPmi  Organization              BENA PROPERTIES
# ...                            ...           ...                          ...
# 9487479              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487480              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487481              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487482              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
# 9487483              ofac-sdn-9999        Person  Jose Aldemar RENDON RAMIREZ
#
#                        aliases  birth_date countries  \
# 0        BANNA PROPERTIES;BENA         NaN        sy
# 1        BANNA PROPERTIES;BENA         NaN        sy
# 2        BANNA PROPERTIES;BENA         NaN        sy
# 3        BANNA PROPERTIES;BENA         NaN        sy
# 4        BANNA PROPERTIES;BENA         NaN        sy
# ...                        ...         ...       ...
# 9487479                 MECHAS  1950-07-24        co
# 9487480                 MECHAS  1950-07-24        co
# 9487481                 MECHAS  1950-07-24        co
# 9487482                 MECHAS  1950-07-24        co
# 9487483                 MECHAS  1950-07-24        co
#
#                                                  addresses identifiers  \
# 0        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 1        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 2        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 3        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# 4        Cham Holding Building, Daraa Highway, Sahnaya ...         NaN
# ...                                                    ...         ...
# 9487479  Carrera 13 No. 18-50, Cartago, Valle, Colombia...    16202349
# 9487480  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487481  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487482  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
# 9487483  Carrera 13 No. 18-50, Cartago, Valle;Carrera 2...    16202349
#
#                                                  sanctions phones  ...  \
# 0        Block - Program - SDN List - Executive Order 1...    NaN  ...
# 1        Program - SDN List - Block - Executive Order 1...    NaN  ...
# 2        Program - SDN List - Block - Executive Order 1...    NaN  ...
# 3        Block - SDN List - Program - Executive Order 1...    NaN  ...
# 4        Program - Block - SDN List - Executive Order 1...    NaN  ...
# ...                                                    ...    ...  ...
# 9487479  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 9487480  Program - SDN List - Block - Unknown - 2006-10-25    NaN  ...
# 9487481  Block - SDN List - Program - Unknown - 2006-10-25    NaN  ...
# 9487482  Program - Block - SDN List - Unknown - 2006-10-25    NaN  ...
# 9487483  Block - SDN List - Program - Unknown - 2006-10-25    NaN  ...
#
#                                                    dataset  \
# 0        US OFAC Specially Designated Nationals (SDN) List
# 1        US OFAC Specially Designated Nationals (SDN) List
# 2        US OFAC Specially Designated Nationals (SDN) List
# 3        US OFAC Specially Designated Nationals (SDN) List
# 4        US OFAC Specially Designated Nationals (SDN) List
# ...                                                    ...
# 9487479  US OFAC Specially Designated Nationals (SDN) List
# 9487480  US OFAC Specially Designated Nationals (SDN) List
# 9487481  US OFAC Specially Designated Nationals (SDN) List
# 9487482  US OFAC Specially Designated Nationals (SDN) List
# 9487483  US OFAC Specially Designated Nationals (SDN) List
#
#                    last_seen           first_seen date_stamp last_change  \
# 0        2021-09-30 11:39:21  2021-09-30 11:39:21   20210930         NaN
# 1        2021-09-30 11:39:21  2021-10-01 03:02:43   20211001         NaN
# 2        2021-09-30 11:39:21  2021-10-02 03:03:02   20211002         NaN
# 3        2021-09-30 11:39:21  2021-10-03 08:46:36   20211003         NaN
# 4        2021-09-30 11:39:21  2021-10-04 03:02:58   20211004         NaN
# ...                      ...                  ...        ...         ...
# 9487479  2021-07-26 11:55:45  2021-09-24 03:02:55   20210925         NaN
# 9487480  2021-09-26 14:52:11  2021-09-26 14:52:11   20210926         NaN
# 9487481  2021-09-26 14:52:11  2021-09-27 09:09:30   20210927         NaN
# 9487482  2021-09-26 14:52:11  2021-09-28 03:03:19   20210928         NaN
# 9487483  2021-09-26 14:52:11  2021-09-29 03:02:51   20210929         NaN
#
#         new_entry  deletion  unchanged    month listing_count
# 0            True     False      False  2021-09         18450
# 1           False     False       True  2021-10          9410
# 2           False     False       True  2021-10          9410
# 3           False     False       True  2021-10          9410
# 4           False      True      False  2021-10          9410
# ...           ...       ...        ...      ...           ...
# 9487479     False     False       True  2021-09         18450
# 9487480     False     False       True  2021-09         18450
# 9487481     False     False       True  2021-09         18450
# 9487482     False     False       True  2021-09         18450
# 9487483     False      True      False  2021-09         18450
#
# [9487484 rows x 21 columns]

# %% [markdown]
# # Deduplicate

# %%
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)

# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')

# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)

# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
# Out:
#                               id        schema  \
# 0      NK-226JTDehVMSXex35EbKPmi  Organization
# 1      NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 2      NK-22iRdVwQHXiYMCAASM93qH  Organization
# 3      NK-22jYwFUGYJxd6bKdMnxb22  Organization
# 4      NK-22oMG6jqPQknWaMjzTn4hK       Company
# ...                          ...           ...
# 29648              ofac-sdn-9993        Person
# 29649              ofac-sdn-9994        Person
# 29650              ofac-sdn-9995        Person
# 29651              ofac-sdn-9996        Person
# 29652              ofac-sdn-9999        Person
#
#                                       name  \
# 0                          BENA PROPERTIES
# 1                          Michael Kuajien
# 2                          AL RASHID TRUST
# 3                       NEGIN PARTO KHAVAR
# 4      Limited Liability Company Garantiya
# ...                                    ...
# 29648            Yolanda Sofia CANO ALZATE
# 29649                Davinson GOMEZ OCAMPO
# 29650        Carlos Arturo PATINO RESTREPO
# 29651        Luis Alfonso GOMEZ BUSTAMANTE
# 29652          Jose Aldemar RENDON RAMIREZ
#
#                                                  aliases  birth_date  \
# 0                                  BANNA PROPERTIES;BENA         NaN
# 1             Michael Kuajian;Michael Kuajien Duer Mayok  1979-01-01
# 2      AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# 3      ERTEBATE EGHTESSADE MONIR;NEGIN PARTO;NEGIN PA...         NaN
# 4                                          Garantiya OOO         NaN
# ...                                                  ...         ...
# 29648                                                NaN  1957-04-25
# 29649                                              GORDO  1960-07-10
# 29650                                 PATE MURO;PATEMURO  1964-04-27
# 29651                                                NaN  1953-11-01
# 29652                                             MECHAS  1950-07-24
#
#       countries                                          addresses  \
# 0            sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1         ke;ss                                Nairobi;South Sudan
# 2            pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# 3            ir  Tehran, Fatmi Gharabi Street, between Sindokht...
# 4            ru              bulvar Tverskoi, d. 15 str. 2, Moscow
# ...         ...                                                ...
# 29648        co                       c/o GAVIOTAS LTDA., Colombia
# 29649        co  Calle 16 No. 1-58, Cartago, Valle, Colombia;c/...
# 29650        co  Calle 20 No. 6-30, Ofc. 1304, Pereira, Risaral...
# 29651        co  Calle 1B No. 1-26, Barrio El Prado, Cartago, V...
# 29652        co  Carrera 13 No. 18-50, Cartago, Valle, Colombia...
#
#                     identifiers  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4      5067746901426;7703610362
# ...                         ...
# 29648                  31399608
# 29649                   2470433
# 29650                   9991679
# 29651                   4451571
# 29652                  16202349
#
#                                                sanctions phones  ...  \
# 0      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 1      Program - Block - SDN List - Executive Order 1...    NaN  ...
# 2      Block - Program - SDN List - Unknown - 2001-09-24    NaN  ...
# 3      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 4      Block - SDN List - Program - Executive Order 1...    NaN  ...
# ...                                                  ...    ...  ...
# 29648  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29649  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29650  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29651  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29652  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
#
#                 first_seen date_stamp last_change new_entry deletion  \
# 0      2021-09-30 11:39:21   20210930         NaN      True    False
# 1      2021-09-28 03:03:19   20210928         NaN      True    False
# 2      2021-09-18 12:23:43   20210918         NaN      True    False
# 3      2021-09-18 12:23:43   20210918         NaN      True    False
# 4      2023-02-24 18:37:06   20230226         NaN      True    False
# ...                    ...        ...         ...       ...      ...
# 29648  2021-08-20 20:39:54   20210820         NaN      True    False
# 29649  2021-08-20 20:39:54   20210820         NaN      True    False
# 29650  2021-08-20 20:39:54   20210820         NaN      True    False
# 29651  2021-08-20 20:39:54   20210820         NaN      True    False
# 29652  2021-08-20 20:39:54   20210820         NaN      True    False
#
#       unchanged    month  listing_count  listing_date delisting_date
# 0         False  2021-09          18450      20210930            NaN
# 1         False  2021-09          18450      20210928            NaN
# 2         False  2021-09          18450      20210918            NaN
# 3         False  2021-09          18450      20210918            NaN
# 4         False  2023-02          12137      20230226            NaN
# ...         ...      ...            ...           ...            ...
# 29648     False  2021-08           9124      20210820            NaN
# 29649     False  2021-08           9124      20210820            NaN
# 29650     False  2021-08           9124      20210820            NaN
# 29651     False  2021-08           9124      20210820            NaN
# 29652     False  2021-08           9124      20210820            NaN
#
# [29653 rows x 23 columns]

# %%
res_deduplicated
# Out:
#                               id        schema  \
# 0      NK-226JTDehVMSXex35EbKPmi  Organization
# 1      NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 2      NK-22iRdVwQHXiYMCAASM93qH  Organization
# 3      NK-22jYwFUGYJxd6bKdMnxb22  Organization
# 4      NK-22oMG6jqPQknWaMjzTn4hK       Company
# ...                          ...           ...
# 29648              ofac-sdn-9993        Person
# 29649              ofac-sdn-9994        Person
# 29650              ofac-sdn-9995        Person
# 29651              ofac-sdn-9996        Person
# 29652              ofac-sdn-9999        Person
#
#                                       name  \
# 0                          BENA PROPERTIES
# 1                          Michael Kuajien
# 2                          AL RASHID TRUST
# 3                       NEGIN PARTO KHAVAR
# 4      Limited Liability Company Garantiya
# ...                                    ...
# 29648            Yolanda Sofia CANO ALZATE
# 29649                Davinson GOMEZ OCAMPO
# 29650        Carlos Arturo PATINO RESTREPO
# 29651        Luis Alfonso GOMEZ BUSTAMANTE
# 29652          Jose Aldemar RENDON RAMIREZ
#
#                                                  aliases  birth_date  \
# 0                                  BANNA PROPERTIES;BENA         NaN
# 1             Michael Kuajian;Michael Kuajien Duer Mayok  1979-01-01
# 2      AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# 3      ERTEBATE EGHTESSADE MONIR;NEGIN PARTO;NEGIN PA...         NaN
# 4                                          Garantiya OOO         NaN
# ...                                                  ...         ...
# 29648                                                NaN  1957-04-25
# 29649                                              GORDO  1960-07-10
# 29650                                 PATE MURO;PATEMURO  1964-04-27
# 29651                                                NaN  1953-11-01
# 29652                                             MECHAS  1950-07-24
#
#       countries                                          addresses  \
# 0            sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1         ke;ss                                Nairobi;South Sudan
# 2            pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# 3            ir  Tehran, Fatmi Gharabi Street, between Sindokht...
# 4            ru              bulvar Tverskoi, d. 15 str. 2, Moscow
# ...         ...                                                ...
# 29648        co                       c/o GAVIOTAS LTDA., Colombia
# 29649        co  Calle 16 No. 1-58, Cartago, Valle, Colombia;c/...
# 29650        co  Calle 20 No. 6-30, Ofc. 1304, Pereira, Risaral...
# 29651        co  Calle 1B No. 1-26, Barrio El Prado, Cartago, V...
# 29652        co  Carrera 13 No. 18-50, Cartago, Valle, Colombia...
#
#                     identifiers  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4      5067746901426;7703610362
# ...                         ...
# 29648                  31399608
# 29649                   2470433
# 29650                   9991679
# 29651                   4451571
# 29652                  16202349
#
#                                                sanctions phones  ...  \
# 0      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 1      Program - Block - SDN List - Executive Order 1...    NaN  ...
# 2      Block - Program - SDN List - Unknown - 2001-09-24    NaN  ...
# 3      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 4      Block - SDN List - Program - Executive Order 1...    NaN  ...
# ...                                                  ...    ...  ...
# 29648  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29649  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29650  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29651  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29652  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
#
#                 first_seen date_stamp last_change new_entry deletion  \
# 0      2021-09-30 11:39:21   20210930         NaN      True    False
# 1      2021-09-28 03:03:19   20210928         NaN      True    False
# 2      2021-09-18 12:23:43   20210918         NaN      True    False
# 3      2021-09-18 12:23:43   20210918         NaN      True    False
# 4      2023-02-24 18:37:06   20230226         NaN      True    False
# ...                    ...        ...         ...       ...      ...
# 29648  2021-08-20 20:39:54   20210820         NaN      True    False
# 29649  2021-08-20 20:39:54   20210820         NaN      True    False
# 29650  2021-08-20 20:39:54   20210820         NaN      True    False
# 29651  2021-08-20 20:39:54   20210820         NaN      True    False
# 29652  2021-08-20 20:39:54   20210820         NaN      True    False
#
#       unchanged    month  listing_count  listing_date delisting_date
# 0         False  2021-09          18450      20210930            NaN
# 1         False  2021-09          18450      20210928            NaN
# 2         False  2021-09          18450      20210918            NaN
# 3         False  2021-09          18450      20210918            NaN
# 4         False  2023-02          12137      20230226            NaN
# ...         ...      ...            ...           ...            ...
# 29648     False  2021-08           9124      20210820            NaN
# 29649     False  2021-08           9124      20210820            NaN
# 29650     False  2021-08           9124      20210820            NaN
# 29651     False  2021-08           9124      20210820            NaN
# 29652     False  2021-08           9124      20210820            NaN
#
# [29653 rows x 23 columns]

# %% [markdown]
# # Descriptives and clean up

# %%
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
# Out:
# ['sy' 'ke;ss' 'pk' 'ir' 'ru' 'cd;rw' 'de' 'by' 'kp' 'co' 'ae' 'mx' 'be'
#  'il;md;ru' 'iq' 'gr' 'gb;ir' nan 'zw' 'ch;fr' 'cn' 've' 'tw' 'li'
#  'co;es;pa' 'cf' 'ru;ua' 'cy' 'ao' 'gb' 'mt' 'lb;ps' 'vc' 'gm' 'ni'
#  'mx;us' 'ch;co' 'ir;sy' 'lb' 'cz;ru' 'ch' 'my' 'jp' 'ye' 'tn' 'us'
#  'cy;gb;gh;gr;sy' 'sa' 'km' 'ae;ru;uz' 'eg' 'pk;sa' 'sk;ve' 'au' 'iq;sy'
#  'tr' 'fr;ml' 'af;ir;pk' 'mh' 'mm' 'lb;ng;sl' 'cn;hk' 'sg' 'cd;kp' 'cr'
#  'jo' 'ar' 'fr' 'lv;tr' 'ca' 'rs' 'nl' 'cn;kp' 'it;tn' 'bg' 'it' 'sv' 'at'
#  'pa' 'lv;ru' 'uz' 'ae;in' 'sd' 'cy;it;mc' 'aw;co;ve'
#  'ar;bg;ca;de;es;it;kp;mx;nl;pl;ru' 'gb;sd' 'iq;tr' 'id' 'er;et' 'bi'
#  'co;ve' 'ae;sy' 'ht' 'af;pk' 'fi;ru' 'ec' 'ly' 'ph' 'pa;sl;tr' 'ae;lr'
#  'za' 'ng' 'de;jo' 'af' 'es' 'de;iq' 'cd' 'bh' 'iq;ir' 'er;ke' 'tj' 'ke'
#  'gb;ru' 'il;it;ru' 'gb;sy' 'gt;pa;sv' 'co;lb' 'ch;iq' 'bj;cf' 'ps'
#  'ae;kg' 'vn' 'ch;it' 'ir;ve' 'cn;vg' 'do' 'gt' 'ae;cn;hk' 'ch;it;mt' 'je'
#  'vg' 'il' 'cn;gb' 'cz;sc' 'kh' 'th' 'si' 'kg' 'in' 'jo;qa' 'gb;jo'
#  'ao;ar;bb;ca;cz;de;es;fr;gb;gy;ht;jm;mx;pa;pe;ru' 'ua' 'ch;es' 'iq;it'
#  'hu;ru' 'br;cn;eg;kp;pe;ru;th' 'mh;tr' 'kz' 'tz;za' 'co;pa' 'hn'
#  'es;gr;ru;ua;us' 'tg' 'ae;md' 'bd;sg' 'sk' 'tz' 'me;rs' 'fi' 'cd;ug'
#  'mm;th' 'bj' 'iq;no' 'co;mx' 'de;ma' 'ws' 'pe' 'me' 'kr' 'dz' 'lv' 'bs'
#  'ae;so' 'ss' 'by;ru' 'om;so' 'lr' 'cn;hk;pk' 'cn;hk;th' 'ch;ir'
#  'gb;jo;us' 'se' 'kp;ru' 'so' 'hk' 'mt;tt;tz' 'qa' 'eg;iq;jo' 'lu' 'ae;gb'
#  'ae;sc' 'mk' 'dz;jo;tr' 'ae;br;co;gt;lb;mx;pa;sy;tr;ve' 'cy;ky' 'gr;ru'
#  'fr;lb' 'cn;mh' 'ky' 'bz;us' 'ml' 'gb;hk;ir' 'eg;sd;tr' 'mn' 'xk' 'cu;pa'
#  'cn;hk;mm' 'ke;sd;ss' 'cy;il;ru' 'im' 'hk;th' 'cn;tw' 'fr;rw' 'co;cr'
#  'in;sg' 'co;lb;ve' 'lb;us' 'cf;sd;ug' 'ir;my' 'ae;ru' 'es;ve' 'am' 'mv'
#  'ca;cn;ru' 'br;lb;py' 'us;ye' 'cy;vg' 'by;kp' 'af;pk;uz' 'ch;ru'
#  'cn;de;kp;kw;my;ru;th' 'gb;sa' 'ro' 'dm' 'ch;fi' 'ug' 'ae;ir' 'cu'
#  'cf;cm;td' 'by;cn;de;lv;ru;ua' 'sd;ss' 'md;tr' 'ps;tr' 'sy;tr' 'kp;sy'
#  'il;pa' 'ae;al;ch;cy;qa' 'be;ma;sy' 'cn;hk;lb' 'gm;lb;sl' 'cm' 'mm;sg'
#  'ae;ru;tm' 'ch;co;es' 'iq;sy;tr' 'de;sa;ye' 'mr' 'gm;gq' 'kn' 'cn;gb;hk'
#  'om' 'ba' 'sy;tj' 'eg;pk' 'cy;gb' 'ae;kn;sy;tr' 'pt' 'ch;us' 'pa;sg;vg'
#  'ae;kp;kw;om;qa' 'af;lb' 'ch;de;ru' 'hu' 'ae;ng' 'eg;ps' 'cn;ky'
#  'ae;gh;gr;ru' 'ir;lb' 'cy;fr;il;ru' 'af;qa;sa' 'ae;iq;jo' 'gb;je' 'kw'
#  'ga' 'eg;iq;jo;qa' 'be;gb;gm;lb;sl' 'ae;gb;pk' 'jm' 'cn;sg' 'uy' 'sa;sd'
#  'mz' 'ae;cn;sg;tw' 'cy;ru' 'ae;de;es;pk' 'ee' 'ch;ly' 'pl' 'lb;vg'
#  'cn;th' 'bz' 'pw' 'gi' 'pa;pe;vg' 'sm' 'af;kw' 'ae;af;pk' 'gw' 'na' 'sc'
#  'bg;gb;ru' 'be;ma' 'am;ch;fi;ru' 'ae;ir;sg;tw' 'iq;sy;ye' 'sl' 'ca;lb'
#  'gt;hn;mx;sv;us' 'ae;uz' 'br;eg;tr' 'md;ru' 'bb;ca' 'ge' 'gb;tr' 'dj'
#  'au;la;th' 'ir;ps' 'cd;gi;nl' 'ma' 'cz;il;nl' 'cn;hk;nz' 'ae;gb;ir;sg'
#  'cv;gw' 'in;pk' 'ee;fi' 'it;ma' 'ru;sy' 'gb;pk' 'ae;fr;sy' 'mx;pa'
#  'ae;cn;de;in;kp;sy' 'ae;cn;fr;ir;tj' 'al;jo' 'de;tr' 'ae;mh' 'iq;lb'
#  'mt;ru' 'af;de' 'py' 'by;ir;sy;ua' 'eg;fr;lb;sy' 'do;ve' 'gb;ke;lr' 'vu'
#  'ae;cy;rs' 'ru;sd' 'gb;pk;sy' 'ke;so' 'ar;it;ve' 'lu;ru' 'af;kw;pk'
#  'eg;ly' 'ir;us' 'cy;gb;ru' 'jo;lb;ps' 'cn;lb' 'ar;co' 'bd;in' 'ca;mx'
#  'cy;mt' 'bo;mx' 'ps;us' 'gb;qa' 'eg;sy;us' 'br;cl;py' 'dz;pk'
#  'ar;cu;pa;us' 'bf;ml' 'ae;ch;in' 'lb;ve' 'cy;fr;ru' 'ae;bg' 'cn;gb;hk;kh'
#  'lb;py' 'gq;ma' 'sa;ye' 'de;ua' 'ae;ie' 'it;mx;ve' 'af;tr' 'ae;sy;tr'
#  'lb;sy' 'ec;es' 'tt;us' 'eg;us' 'cn;mo' 'jo;tr' 'ua;ua-cri' 'es;qa'
#  'co;il' 'ml;ne' 'af;az;ba;bd;ca;cn;gb;ge;hr;nl;pk;ru;sa;sd;tj;us;ye'
#  'cn;lb;sy' 'hr' 'md' 'ci;gb;lb;ng' 'ae;es;mt;sy' 'ir;pk;sa' 'kp;mn'
#  'ge;ru' 'hk;kp' 'kp;vn' 'au;br;ve' 'dk' 'ae;om;ru' 'cn;my' 'ca;sy'
#  'lb;sl' 'bg;ru' 'be;bj;ci;gm;sl' 'kw;sa' 'gb;za' 'tt' 'au;cl' 'cd;ss'
#  'de;sy;tr' 'bd' 'no' 'fr;sy' 'ae;cy' 'ca;pa' 'ae;ye' 'bj;cg;lb' 'gi;tr'
#  'se;so' 'ie' 'cn;ir' 'ae;lb' 'ph;sa' 'bf;ml;ne' 'ag;co;ve' 'co;us'
#  'ae;in;pk' 'cl;pe' 'ru;ua-dpr' 'be;nl' 'fr;sd' 'rs;xk' 'bh;ir' 'lb;ph'
#  'cn;la;mm;th' 'et;za' 'ae;ir;je;tm' 'cd;cg' 'eg;ye' 'co;hn;pa' 'td'
#  'ae;ch' 'cn;hk;ru' 'co;mx;ve' 'cn;mm;th' 'ae;iq;om' 'ae;be;tr' 'co;ec'
#  'lb;sn' 'mz;tz' 'gm;lb' 'cd;cf' 'gb;ly' 'ua;ua-dpr' 'bm;ch' 'rw' 'gn;lb'
#  'ae;pk' 'je;ru' 'ch;pa;us' 'ru;ua;ua-cri' 'ae;iq' 'fr;ua' 'at;be;de;gb'
#  'il;ru' 'bn;cn' 'af;pk;sa' 'cz' 'ro;tr' 'al;ba;bd;be;fr;in;pk;rs;ru;tr'
#  'al' 'ba;it;tn' 'ae;za' 'bo;it' 'co;gt' 'au;eg' 'ae;gb;sy' 'ly;om'
#  'co;ky;vu' 'ae;cy;ru' 'af;ru' 'ca;de;es;fr;it;jp;ru' 'ir;je' 'eg;sd'
#  'ir;tr' 'gt;mx' 'dz;fr;ir' 'ae;af' 'co;es' 'my;sy' 'bs;cy' 'us;ve'
#  'ae;ch;kn' 'iq;lb;sy' 'ly;za' 'az' 'nz' 'ae;in;pk;ye' 'dz;it' 'ae;iq;sy'
#  'fr;ru' 'ae;se' 'ch;es;jp;pa' 'ch;co;ve' 'ml;ru' 'de;ir' 'il;ua' 'ly;ni'
#  'ca;lb;sy' 'gt;mx;pa' 'ch;uz' 'cy;il' 'be;ir' 'il;ps' 'cn;hk;mo'
#  'ae;kz;ru;uz' 'ae;cn;de;hk;ir' 'ru;uz' 'kg;ru' 'ae;mh;mt' 'eg;jo;om;sy'
#  'ca;so;sy' 'ir;ve;vg' 'ba;tn' 'de;dz' 'bm' 'be;kz;ru' 'af;in;pk' 'tm'
#  'co;fr' 'ee;ru' 'lb;tr' 'ae;af;ir;pk' 'ch;de' 'cd;il' 'br;co' 'ps;sy'
#  'cn;ve' 'co;ec;pa' 'co;it' 'ae;er' 'hk;ir;za' 'cn;hk;my'
#  'al;ba;bd;gh;kh;kw;lb;so;xk' 'pl;ru' 'ae;cn;sa;sy' 'sa;sy' 'tw;ws'
#  'jo;ye' 'ae;om' 'at;ch' 'by;de;kz;pl;ru' 'cn;ir;kp;ru;sy' 'co;ec;mx'
#  'fi;fr' 'je;mc;ru' 'be;lb' 'iq;jo' 'mh;tw' 'ir;pk' 'ly;sd' 'ge;gr'
#  'iq;jo;sy;tr' 'am;ru' 'br;py' 'at;sc' 'pe;vg' 'il;uz' 'ar;pa'
#  'de;fr;ir;it' 'ae;kp' 'de;us' 'ci' 'au;lb' 'ae;nl' 'cn;in;ir;kr;tr'
#  'ba;so' 'eg;tr' 'au;be;ca;ch;de;dk;fi;fr;gb;it;lk;my;nl;no;nz;se;us;za'
#  'ae;az;de;fr;gb;hk;iq;ir;om;us' 'se;sy' 'iq;ru;sy' 'dz;ml' 'er;sd;ss'
#  'co;ec;ve' 'by;de;pl' 'ae;lv' 'ae;lr;pa' 'ir;tm' 'ae;pa' 'mt;no' 'bb'
#  'er;so' 'nz;sy' 'ar;co;km;ve' 'gn' 'se;tn' 'et' 'cf;sd' 'af;de;ma;pk'
#  'br;lb' 'hk;tw' 'ml;mr' 'ru;sg' 'pa;vg' 'cn;hk;sc' 'dz;kw' 'id;sy'
#  'ae;mx' 'it;so' 'ch;cy;ru;uz' 'af;bd;pk' 'ly;pk' 'mh;mt' 'ps;qa' 'cu;gb'
#  'ae;ch;ru;sg' 'ae;bh;ir;om;sa' 'es;mh' 'et;ke;sd;ss;ug' 'co;lb;pa'
#  'ae;af;de;fr;gb;gr;ir;lb;om;qa;tm' 'er;et;ly;sd' 'ae;mt' 'lb;ng;sl;us'
#  'ae;ir;je' 'gh' 'cf;ne;td' 'pa;ve' 'eg;it' 'co;it;mx' 'ae;dj' 'bh;iq;ir'
#  'ci;lb' 'az;ba;bd;ca;cn;ge;hr;nl;pk;ru;sa;sd;tj;us' 'by;ua' 'ba;gb;rs'
#  'ae;pl' 'es;ru' 'co;gt;lb' 'cn;eg;hk;kp;pe;ru;th' 'jo;sy' 'bo' 'jo;ps;sa'
#  'ch;gb;li' 'ca;ps' 'ee;es;ru' 'ca;sd' 'sd;sy' 'af;sy' 'cn;kn;ru;th'
#  'jo;qa;sy' 'cn;kp;pl;ru' 'cy;uz' 'kp;th' 'za;zw' 'gb;ve' 'ae;cn' 'ge;kp'
#  'es;us;ve' 'ch;vg' 'cl' 'de;sy' 'eg;sy;tr' 'gb;kn' 'eg;mt' 'me;xk'
#  'ke;km' 'cr;mx' 'it;ru;sk' 'cg;td' 'co;cr;ve' 'ae;ir;kn' 'es;gb'
#  'ae;gh;ru' 'at;gi' 'jo;lb;sa' 'at;ch;li' 'ae;ca;cn;ir;ru' 'ly;mt' 'ae;tr'
#  'cf;ru' 'gb;iq' 'ba;sy' 'ae;th' 'ao;cn;gb' 'iq;us' 'ir;ye' 'br' 'it;tr'
#  'ch;ee' 'jo;sd' 'be;tr' 'eg;ke' 'fr;sy;tn' 'fi;ro;ru' 'de;lv;ru'
#  'ar;cl;co;do;ec;mx;pe;us;ve' 'lr;us' 'ae;by' 'no;ru;ua' 'ae;kn;sy'
#  'ir;ma' 'ir;jo' 'tz;zw' 'ir;ps;qa;tr' 'am;ch;fi' 'fr;tn' 'ua;ua-lpr'
#  'ci;ml' 'gb;lu;lv;ru' 'fi;gb' 'cu;id' 'cf;fr' 'cu;kw' 'cu;eg;ps'
#  'md;ru;ua' 'az;ru' 'az;cy;ru' 'md;ro' 'rs;ru' 'il;md' 'be;fr;ru'
#  'cu;sa;ye' 'gb;il;ru' 'mo;pt' 'cw;ve' 'ae;es;gb;ie' 'er' 'mo' 'br;eg'
#  'br;eg;sy' 'br;eg;lb' 'de;lb' 'lb;zm' 'zm' 'fr;gn;lb' 'gb;gn;lb'
#  'ae;in;sg' 'ae;es;ie' 'es;ie' 'ck' 'kr;tr' 'in;mh' 'id;tr' 'ir;kp'
#  'ae;gb;ir;kn' 'lk' 'dj;so' 'gb;nl' 'ch;ua' 'ir;kn' 'gt;ru' 'fr;kp'
#  'ae;et' 'ae;ba;nl' 'st' 'tv' 'ch;li' 'be;lb;us;za' 'be;ci;fr' 'bg;lb'
#  'be;gb;in;lb' 'ae;ph' 'lb;za' 'ca;cn;hk;lb' 'cd;fr;sn' 'ae;dj;so'
#  'cd;gb;lb' 'ae;fr' 'ae;be' 'ae;af;be;bg;cy;hu;kn' 'af;mv' 'lk;mv'
#  'fr;gb;lb' 'af;cy;kn;tr' 'cd;tz' 'ba;me;ru' 'sa;tr' 'ae;tm' 'ae;cd;sa;sd'
#  'gb;kn;lb;ru;sy;tr' 'cd;cf;sd;ug' 'anhh;ve' 'ae;lr;mh'
#  'br;cn;eg;kp;pe;ru;sg;th' 'dz;sy' 'kp;mm' 'ng;sl' 'ae;au;ca;gb;pk;us'
#  'gb;jo;sa' 'eg;gb' 'fr;ye' 'ru;tr' 'bo;bz;co;cr;gt;hn;mx;ni;pa;sv;uy'
#  'ru;sy;tr' 'eg;kp' 'af;bd;in;pk' 'eg;ir' 'ir;sa' 'bb;pa' 'sy;ye' 'mk;sy'
#  'au;iq;sy' 'sy;tt' 'cu;kp' 'ca;sy;tr' 'ru;za' 'cf;ug' 'gi;ky' 'gb;iq;sy'
#  'cz;il;nl;ru' 'lb;sy;tr' 'ph;sy' 'sy;tt;us' 'jo;lb;ps;sd;tr' 'sg;za'
#  'do;es;ve' 'ma;ml' 'cd;fr;lb' 'cy;ly;mt' 'iq;ir;sy' 'iq;ir;om'
#  'au;br;qa;tr;ve' 'af;ir;lb' 'ht;us' 'af;ir;sa' 'ae;gb;tr' 'tr;ye'
#  'gr;se;sy' 'cn;hk;tw' 'es;mx' 'af;eg' 'at;be;de;gb;tn' 'jo;us'
#  'af;al;az;ba;bd;be;cn;er;et;fr;ge;in;iq;jo;lb;pk;ps;rs;ru;sl;so;sy;tr'
#  'gb;iq;jo;us' 'ae;iq;th' 'ae;al;jo' 'ae;ir;pk' 'anhh;cu']
# ['Organization' 'Person' 'Company' 'Airplane' 'Vessel']
# ['20210930' '20210928' '20210918' '20230226' '20220804' '20230314'
#  '20210922' '20210923' '20230916' '20231121' '20231106' '20231214'
#  '20221118' '20210927' '20230522' '20220421' '20230921' '20230525'
#  '20220406' '20230915' '20221213' '20230418' '20231019' '20230722'
#  '20220803' '20220705' '20220919' '20221120' '20230223' '20231020'
#  '20231206' '20231120' '20221110' '20210929' '20220630' '20231213'
#  '20230520' '20230830' '20221001' '20230710' '20220403' '20221007'
#  '20231212' '20230302' '20220416' '20221029' '20231112' '20220512'
#  '20231217' '20220422' '20230914' '20220408' '20230326' '20220702'
#  '20211205' '20230713' '20230127' '20221004' '20230721' '20230331'
#  '20220704' '20220401' '20220425' '20230414' '20220823' '20221112'
#  '20221219' '20230219' '20220608' '20220204' '20221117' '20220628'
#  '20230201' '20230630' '20221107' '20230216' '20221028' '20211118'
#  '20231221' '20220417' '20220510' '20220312' '20230801' '20211022'
#  '20220509' '20221019' '20231211' '20220309' '20230313' '20220413'
#  '20231118' '20220207' '20230125' '20211014' '20230227' '20230419'
#  '20220505' '20211117' '20231119' '20220825' '20220225' '20220316'
#  '20220223' '20220304' '20220427' '20231210' '20231220' '20220226'
#  '20221215' '20231031' '20230917' '20211102' '20231222' '20221021'
#  '20230519' '20231116' '20220324' '20220203' '20230530' '20230809'
#  '20231208' '20220701' '20230918' '20211115' '20230825' '20220424'
#  '20220529' '20220306' '20221228' '20220601' '20221222' '20230425'
#  '20230908' '20230703' '20220706' '20230210' '20221014' '20220222'
#  '20211109' '20220621' '20220205' '20230604' '20221210' '20220303'
#  '20220208' '20230901' '20230304' '20230318' '20230305' '20220517'
#  '20230113' '20220930' '20211005' '20220307' '20220301' '20230427'
#  '20230217' '20221119' '20211004' '20220302' '20230818' '20230428'
#  '20230108' '20231007' '20230215' '20230501' '20220531' '20220411'
#  '20231022' '20231204' '20220305' '20231004' '20230824' '20221102'
#  '20220327' '20220909' '20221031' '20220816' '20230129' '20211030'
#  '20230502' '20220604' '20221212' '20221115' '20220308' '20230929'
#  '20210926' '20230403' '20231215' '20220530' '20211112' '20211003'
#  '20221220' '20230203' '20230531' '20230322' '20211001' '20231207'
#  '20220227' '20221109' '20211123' '20220418' '20220718' '20230224'
#  '20230725' '20220722' '20230919' '20220903' '20230810' '20220119'
#  '20231114' '20220520' '20230301' '20221006' '20231127' '20231201'
#  '20220712' '20231218' '20211229' '20230120' '20211214' '20230605'
#  '20221204' '20230902' '20211023' '20211113' '20211121' '20230622'
#  '20220502' '20221010' '20220620' '20211216' '20220206' '20221018'
#  '20231108' '20231113' '20220410' '20220724' '20230406' '20211103'
#  '20220314' '20211019' '20221231' '20220626' '20231026' '20231202'
#  '20230729' '20220614' '20211208' '20211201' '20221202' '20210924'
#  '20220501' '20220609' '20230421' '20221214' '20220709' '20220708'
#  '20230228' '20211207' '20230209' '20230117' '20220624' '20230709'
#  '20231117' '20230323' '20220721' '20220602' '20211228' '20220404'
#  '20230505' '20220217' '20220405' '20230506' '20220121' '20220428'
#  '20220211' '20231227' '20220716' '20231021' '20221015' '20220102'
#  '20220623' '20230521' '20231006' '20221122' '20220228' '20230309'
#  '20221207' '20230411' '20231230' '20230402' '20230523' '20231125'
#  '20230514' '20220719' '20230603' '20230601' '20231219' '20230615'
#  '20220103' '20221123' '20220913' '20230723' '20221128' '20230814'
#  '20211224' '20230205' '20231013' '20230220' '20220802' '20230602'
#  '20220310' '20230507' '20220315' '20230623' '20230513' '20220419'
#  '20220521' '20220516' '20220715' '20220224' '20230212' '20220317'
#  '20220925' '20220527' '20220611' '20221208' '20230423' '20220610'
#  '20220612' '20220824' '20220414' '20220911' '20211220' '20230516'
#  '20220827' '20230121' '20230303' '20220730' '20220323' '20230307'
#  '20220819' '20221130' '20231003' '20220927' '20230124' '20230131'
#  '20230206' '20230213' '20230214' '20230306' '20231115' '20220603'
#  '20220503' '20220811' '20211221' '20220703' '20220905' '20221230'
#  '20220725' '20230412' '20220726' '20220615' '20220727' '20220129'
#  '20220728' '20230207' '20220908' '20230110' '20220613' '20220904'
#  '20231228' '20220920' '20221027' '20220809' '20220713' '20220519'
#  '20220729' '20220330' '20220817' '20230310' '20220113' '20230831'
#  '20211218' '20211211' '20220319' '20211027' '20211119' '20220915'
#  '20211007' '20211203' '20211210' '20220201' '20211116' '20220318'
#  '20221024' '20211209' '20230616' '20211028' '20221209' '20211111'
#  '20211124' '20220218' '20211202' '20220616' '20220111' '20220105'
#  '20211223' '20220122' '20220420' '20220331' '20230325' '20220412'
#  '20220321' '20221114' '20220325' '20230126' '20220525' '20220407'
#  '20221026' '20220508' '20220506' '20231107' '20220606' '20221003'
#  '20220524' '20220617' '20230606' '20220711' '20231130' '20230404'
#  '20220914' '20220801' '20220929' '20230130' '20220808' '20220922'
#  '20230106' '20220926' '20221017' '20230208' '20221020' '20221101'
#  '20221104' '20221103' '20221116' '20221124' '20230524' '20221221'
#  '20230222' '20230105' '20230123' '20230315' '20230509' '20230308'
#  '20230328' '20230330' '20230720' '20230627' '20230424' '20230719'
#  '20230724' '20230621' '20230712' '20230926' '20230620' '20230608'
#  '20230711' '20230727' '20230811' '20230731' '20231129' '20230912'
#  '20230816' '20230817' '20230823' '20230927' '20230906' '20230907'
#  '20231103' '20230928' '20231012' '20231018' '20231102' '20231205'
#  '20231027' '20210820' '20210825' '20210823' '20210917' '20210904']

# %%
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
# Out:
# id                    0
# schema                0
# name                  0
# aliases           11639
# birth_date        14956
# countries          4581
# addresses          6185
# identifiers       14588
# sanctions            13
# phones            29593
# emails            29287
# dataset               0
# last_seen             0
# first_seen            0
# date_stamp            0
# last_change       26834
# new_entry             0
# deletion              0
# unchanged             0
# month                 0
# listing_count         0
# listing_date          0
# delisting_date    28795
# dtype: int64

# %%
res_deduplicated.columns
# Out:
# Index(['id', 'schema', 'name', 'aliases', 'birth_date', 'countries',
#        'addresses', 'identifiers', 'sanctions', 'phones', 'emails', 'dataset',
#        'last_seen', 'first_seen', 'date_stamp', 'last_change', 'new_entry',
#        'deletion', 'unchanged', 'month', 'listing_count', 'listing_date',
#        'delisting_date'],
#       dtype='object')

# %%
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
# Out:
#                               id        schema  \
# 0      NK-226JTDehVMSXex35EbKPmi  Organization
# 1      NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 2      NK-22iRdVwQHXiYMCAASM93qH  Organization
# 3      NK-22jYwFUGYJxd6bKdMnxb22  Organization
# 4      NK-22oMG6jqPQknWaMjzTn4hK       Company
# ...                          ...           ...
# 29648              ofac-sdn-9993        Person
# 29649              ofac-sdn-9994        Person
# 29650              ofac-sdn-9995        Person
# 29651              ofac-sdn-9996        Person
# 29652              ofac-sdn-9999        Person
#
#                                       name  \
# 0                          BENA PROPERTIES
# 1                          Michael Kuajien
# 2                          AL RASHID TRUST
# 3                       NEGIN PARTO KHAVAR
# 4      Limited Liability Company Garantiya
# ...                                    ...
# 29648            Yolanda Sofia CANO ALZATE
# 29649                Davinson GOMEZ OCAMPO
# 29650        Carlos Arturo PATINO RESTREPO
# 29651        Luis Alfonso GOMEZ BUSTAMANTE
# 29652          Jose Aldemar RENDON RAMIREZ
#
#                                                  aliases  birth_date  \
# 0                                  BANNA PROPERTIES;BENA         NaN
# 1             Michael Kuajian;Michael Kuajien Duer Mayok  1979-01-01
# 2      AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# 3      ERTEBATE EGHTESSADE MONIR;NEGIN PARTO;NEGIN PA...         NaN
# 4                                          Garantiya OOO         NaN
# ...                                                  ...         ...
# 29648                                                NaN  1957-04-25
# 29649                                              GORDO  1960-07-10
# 29650                                 PATE MURO;PATEMURO  1964-04-27
# 29651                                                NaN  1953-11-01
# 29652                                             MECHAS  1950-07-24
#
#       countries                                          addresses  \
# 0            sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1         ke;ss                                Nairobi;South Sudan
# 2            pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# 3            ir  Tehran, Fatmi Gharabi Street, between Sindokht...
# 4            ru              bulvar Tverskoi, d. 15 str. 2, Moscow
# ...         ...                                                ...
# 29648        co                       c/o GAVIOTAS LTDA., Colombia
# 29649        co  Calle 16 No. 1-58, Cartago, Valle, Colombia;c/...
# 29650        co  Calle 20 No. 6-30, Ofc. 1304, Pereira, Risaral...
# 29651        co  Calle 1B No. 1-26, Barrio El Prado, Cartago, V...
# 29652        co  Carrera 13 No. 18-50, Cartago, Valle, Colombia...
#
#                     identifiers  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4      5067746901426;7703610362
# ...                         ...
# 29648                  31399608
# 29649                   2470433
# 29650                   9991679
# 29651                   4451571
# 29652                  16202349
#
#                                                sanctions phones  ...  \
# 0      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 1      Program - Block - SDN List - Executive Order 1...    NaN  ...
# 2      Block - Program - SDN List - Unknown - 2001-09-24    NaN  ...
# 3      Block - Program - SDN List - Executive Order 1...    NaN  ...
# 4      Block - SDN List - Program - Executive Order 1...    NaN  ...
# ...                                                  ...    ...  ...
# 29648  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29649  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29650  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29651  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
# 29652  SDN List - Block - Program - Unknown - 2006-10-25    NaN  ...
#
#       date_stamp last_change new_entry deletion unchanged    month  \
# 0       20210930         NaN      True    False     False  2021-09
# 1       20210928         NaN      True    False     False  2021-09
# 2       20210918         NaN      True    False     False  2021-09
# 3       20210918         NaN      True    False     False  2021-09
# 4       20230226         NaN      True    False     False  2023-02
# ...          ...         ...       ...      ...       ...      ...
# 29648   20210820         NaN      True    False     False  2021-08
# 29649   20210820         NaN      True    False     False  2021-08
# 29650   20210820         NaN      True    False     False  2021-08
# 29651   20210820         NaN      True    False     False  2021-08
# 29652   20210820         NaN      True    False     False  2021-08
#
#        listing_count  listing_date  delisting_date new_listing_count
# 0              18450      20210930             NaN                 1
# 1              18450      20210928             NaN                 1
# 2              18450      20210918             NaN                 1
# 3              18450      20210918             NaN                 1
# 4              12137      20230226             NaN                 1
# ...              ...           ...             ...               ...
# 29648           9124      20210820             NaN                 1
# 29649           9124      20210820             NaN                 1
# 29650           9124      20210820             NaN                 1
# 29651           9124      20210820             NaN                 1
# 29652           9124      20210820             NaN                 1
#
# [29653 rows x 24 columns]

# %%
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)

# %%
res_deduplicated.to_csv("us_ofac_sdn.csv")

# %% [markdown]
# # now the other data

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20231231',freq='D').strftime('%Y%m%d')
print(date_list)
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []
for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/us_ofac_cons/targets.simple.csv'
    websites.append(test)
print(websites)
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes
print(res)
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows
# Reset index for the final result
res.reset_index(drop=True, inplace=True)
print(res)
#test thematching function
test = res.query('new_entry == True')
print(test)
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
print(res)

print("Deduplicate")
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)
# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')
# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)
# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
res_deduplicated.columns
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)
res_deduplicated.to_csv("us_ofac_cons.csv")
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=883)
# ['https://data.opensanctions.org/datasets/20210801/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210915/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210916/us_ofac_cons/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210917/u ...
#                   id        schema                       name  \
# 0    ofac-cons-15268  Organization      BANK OF KUNLUN CO LTD
# 1    ofac-cons-17013  Organization               VTB BANK OAO
# 2    ofac-cons-17014  Organization  Russian Agricultural Bank
# 3    ofac-cons-17015       Company            Vnesheconombank
# 4    ofac-cons-17016  Organization            GAZPROMBANK OAO
# ..               ...           ...                        ...
# 439          Q400735        Person               Ahmad SA'DAT
# 440          Q428203        Person            Jamil MAJDALAWI
# 441          Q465542        Person          Mohammed ABU TEIR
# 442        Q53641533        Person          Salah AL-BARDAWIL
# 443          Q708854        Person      Mahmoud Khaled ZAHHAR
#
#                                                aliases birth_date countries  \
# 0    KARAMAY CITY COMMERCIAL BANK CO LTD.;KARAMAY U...        NaN        cn
# 1    BANK VNESHNEY TORGOVLI ROSSIYSKOY FEDERATSII, ...        NaN        ru
# 2    OTKRYTOE AKTSIONERNOE ROSSISKI SELSKOKHOZYAIST...        NaN        ru
# 3    Bank Razvitiya I Vneshneekonomicheskoi Deyatel...        NaN        ru
# 4    GPB, OAO;GPB, OJSC;Gazprombank Gas Industry OJ...        NaN        ru
# ..                                                 ...        ...       ...
# 439                                                NaN        NaN       NaN
# 440                                                NaN        NaN       NaN
# 441  Mohammad Mahmoud ABOU TAYR;Mohammed Mahmud ABU...       1951       NaN
# 442                         Salah Mohammad EL BARDAWIL       1959       NaN
# 443  Mahmoud Khaled AL ZAHAR;Mahmoud Zahar;Mahmoud ...       1945        ps
#
#                                              addresses  \
# 0    172 Xibin Rd, Ranghulu District, (Daqing, Heil...
# 1    29, Bolshaya Morskaya str., St. Petersburg, Ru...
# 2    3 Gagarinsky per., Moscow, Russia, 119034;3, G...
# 3    9 Akademika Sakharova prospekt, Moscow, Russia...
# 4    16, Building 1, Nametkina St., Moscow, Russia,...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441                                                NaN
# 442                                                NaN
# 443                                                NaN
#
#                            identifiers  \
# 0                             CKLBCNBJ
# 1    1027739609391;7702070139;VTBRRUMM
# 2               1027700342890;RUAGRUMM
# 3                             BFEARUMM
# 4    1027700167110;7744001497;GAZPRUMM
# ..                                 ...
# 439                                NaN
# 440                                NaN
# 441                                NaN
# 442                                NaN
# 443                                NaN
#
#                                              sanctions  phones  \
# 0    CAPTA List - 561 Full Restrictions - Program -...     NaN
# 1    Consolidated List - 13662 Sectoral Directive 1...     NaN
# 2    Consolidated List - 13662 Sectoral Directive 1...     NaN
# 3    Consolidated List - 13662 Sectoral Directive 1...     NaN
# 4    Consolidated List - 13662 Sectoral Directive 1...     NaN
# ..                                                 ...     ...
# 439  Consolidated List - General License 4 Under EO...     NaN
# 440  Consolidated List - General License 4 Under EO...     NaN
# 441  Consolidated List - General License 4 Under EO...     NaN
# 442  Consolidated List - General License 4 Under EO...     NaN
# 443  Consolidated List - General License 4 Under EO...     NaN
#
#                      emails                              dataset  \
# 0                       NaN  US OFAC Consolidated (non-SDN) List
# 1                       NaN  US OFAC Consolidated (non-SDN) List
# 2            office@rshb.ru  US OFAC Consolidated (non-SDN) List
# 3               info@veb.ru  US OFAC Consolidated (non-SDN) List
# 4    mailbox@gazprombank.ru  US OFAC Consolidated (non-SDN) List
# ..                      ...                                  ...
# 439                     NaN  US OFAC Consolidated (non-SDN) List
# 440                     NaN  US OFAC Consolidated (non-SDN) List
# 441                     NaN  US OFAC Consolidated (non-SDN) List
# 442                     NaN  US OFAC Consolidated (non-SDN) List
# 443                     NaN  US OFAC Consolidated (non-SDN) List
#
#                last_seen           first_seen date_stamp          last_change
# 0    2021-07-26 11:55:45  2021-08-20 20:39:54   20210820                  NaN
# 1    2021-07-26 11:55:45  2021-08-20 20:39:54   20210820                  NaN
# 2    2021-07-26 11:55:45  2021-08-20 20:39:54   20210820                  NaN
# 3    2021-07-26 11:55:45  2021-08-20 20:39:54   20210820                  NaN
# 4    2021-07-26 11:55:45  2021-08-20 20:39:54   20210820                  NaN
# ..                   ...                  ...        ...                  ...
# 439  2023-12-31T22:35:01  2023-04-20T10:56:14   20231231  2023-04-20T10:56:14
# 440  2023-12-31T22:35:01  2023-04-20T10:56:14   20231231  2023-04-20T10:56:14
# 441  2023-12-31T22:35:01  2023-04-20T10:56:14   20231231  2023-04-20T10:56:14
# 442  2023-12-31T22:35:01  2023-04-20T10:56:14   20231231  2023-04-20T10:56:14
# 443  2023-12-31T22:35:01  2023-04-20T10:56:14   20231231  2023-11-14T14:35:01
#
# [382200 rows x 16 columns]
#                                id   schema                     name  \
# 0       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 1       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 2       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 3       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 4       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# ...                           ...      ...                      ...
# 382195             ofac-cons-9716   Person         Qais Abdul KARIM
# 382196             ofac-cons-9716   Person         Qais Abdul KARIM
# 382197             ofac-cons-9716   Person         Qais Abdul KARIM
# 382198             ofac-cons-9716   Person         Qais Abdul KARIM
# 382199             ofac-cons-9716   Person         Qais Abdul KARIM
#
#                                               aliases birth_date countries  \
# 0       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 1       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 2       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 3       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 4       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# ...                                               ...        ...       ...
# 382195                                            NaN        NaN       NaN
# 382196                                            NaN        NaN       NaN
# 382197                                            NaN        NaN       NaN
# 382198                                            NaN        NaN       NaN
# 382199                                            NaN        NaN       NaN
#
#                                                 addresses  \
# 0       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 1       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 2       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 3       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 4       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# ...                                                   ...
# 382195                                                NaN
# 382196                                                NaN
# 382197                                                NaN
# 382198                                                NaN
# 382199                                                NaN
#
#                      identifiers  \
# 0       1037728033606;7728294503
# 1       1037728033606;7728294503
# 2       1037728033606;7728294503
# 3       1037728033606;7728294503
# 4       1037728033606;7728294503
# ...                          ...
# 382195                       NaN
# 382196                       NaN
# 382197                       NaN
# 382198                       NaN
# 382199                       NaN
#
#                                                 sanctions  phones emails  \
# 0       13662 Sectoral Directive 1 - Sectoral Sanction...     NaN    NaN
# 1       13662 Sectoral Directive 1 - Program - Consoli...     NaN    NaN
# 2       Program - 13662 Sectoral Directive 1 - Consoli...     NaN    NaN
# 3       Consolidated List - Program - 13662 Sectoral D...     NaN    NaN
# 4       13662 Sectoral Directive 1 - Program - Consoli...     NaN    NaN
# ...                                                   ...     ...    ...
# 382195  Consolidated List - Reject - Program - General...     NaN    NaN
# 382196  Consolidated List - Program - Reject - General...     NaN    NaN
# 382197  Program - Reject - Consolidated List - General...     NaN    NaN
# 382198  Program - Consolidated List - Reject - General...     NaN    NaN
# 382199  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
#
#                                     dataset            last_seen  \
# 0       US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 1       US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 2       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# 3       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# 4       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# ...                                     ...                  ...
# 382195  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382196  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382197  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382198  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382199  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
#
#                  first_seen date_stamp last_change  new_entry  deletion  \
# 0       2021-09-28 03:03:19   20210928         NaN       True     False
# 1       2021-09-29 03:02:51   20210929         NaN      False     False
# 2       2021-09-30 11:39:21   20210930         NaN      False     False
# 3       2021-10-01 03:02:43   20211001         NaN      False     False
# 4       2021-10-02 03:03:02   20211002         NaN      False     False
# ...                     ...        ...         ...        ...       ...
# 382195  2021-09-24 03:02:55   20210925         NaN      False     False
# 382196  2021-09-26 14:52:11   20210926         NaN      False     False
# 382197  2021-09-27 09:09:30   20210927         NaN      False     False
# 382198  2021-09-28 03:03:19   20210928         NaN      False     False
# 382199  2021-09-29 03:02:51   20210929         NaN      False      True
#
#         unchanged
# 0           False
# 1            True
# 2            True
# 3            True
# 4            True
# ...           ...
# 382195       True
# 382196       True
# 382197       True
# 382198       True
# 382199      False
#
# [382200 rows x 19 columns]
#                                id        schema  \
# 0       NK-28ZcFDmHBF9L3WkDBBwH6H       Company
# 822     NK-2BsamqL437nSYMzH9KHktg  Organization
# 1473    NK-2FBeAKkRfBHbfVLpuEpNZv        Person
# 2293    NK-2FbKDZw9xDh29GoQicYG8f       Company
# 3125    NK-2JCKKtyfmLdhLbRRvconU8       Company
# ...                           ...           ...
# 381995             ofac-cons-9712        Person
# 382036             ofac-cons-9713        Person
# 382077             ofac-cons-9714        Person
# 382118             ofac-cons-9715        Person
# 382159             ofac-cons-9716        Person
#
#                                                   name  \
# 0                              GAZPROMBANK LEASING ZAO
# 822                        SZ DJI Technology Co., Ltd.
# 1473                       Yahia Abdul Aziz AL-ABADSAH
# 2293                    SBERBANK INSURANCE COMPANY LTD
# 3125    KORUS CONSULTING CIS LIMITED LIABILITY COMPANY
# ...                                                ...
# 381995                                 Mohammed SHIHAB
# 382036                                    Ahmad SA'DAT
# 382077                                 Jamil MAJDALAWI
# 382118                                 Khaledah JARRAR
# 382159                                Qais Abdul KARIM
#
#                                                   aliases  \
# 0           CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING
# 822                                         深圳市大疆创新科技有限公司
# 1473                           Yehia Abdul Aziz EL ABADSA
# 2293    LLC INSURANCE COMPANY SBERBANK INSURANCE;OBSHC...
# 3125    KORUS KONSALTING SNG, OOO;LLL KORUS CONSULTING...
# ...                                                   ...
# 381995                    Mohamed Abed Hadi Rahman SHEHAB
# 382036                                                NaN
# 382077                                                NaN
# 382118                                                NaN
# 382159                                                NaN
#
#                    birth_date countries  \
# 0                         NaN        ru
# 822                       NaN        cn
# 1473                     1958        ps
# 2293                      NaN        ru
# 3125                      NaN        ru
# ...                       ...       ...
# 381995  1956-01-01;1956-12-31       NaN
# 382036                    NaN       NaN
# 382077                    NaN       NaN
# 382118                    NaN       NaN
# 382159                    NaN       NaN
#
#                                                 addresses  \
# 0       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 822     14 F, West Block of Skyworth Semiconductor Des...
# 1473                                          Khan Younis
# 2293    42 Bolshaya Yakimanka St., b. 1-2, office 209,...
# 3125    68 Sampsonievsky Avenue, letter N, Room 1N, Sa...
# ...                                                   ...
# 381995                                       undetermined
# 382036                                       undetermined
# 382077                                       undetermined
# 382118                                       undetermined
# 382159                                       undetermined
#
#                      identifiers  \
# 0       1037728033606;7728294503
# 822           914403007954257495
# 1473                         NaN
# 2293               1147746683479
# 3125               1057812752502
# ...                          ...
# 381995                       NaN
# 382036                       NaN
# 382077                       NaN
# 382118                       NaN
# 382159                       NaN
#
#                                                 sanctions  phones emails  \
# 0       13662 Sectoral Directive 1 - Sectoral Sanction...     NaN    NaN
# 822     Consolidated List - Program - CMIC Executive O...     NaN    NaN
# 1473    Reject - Program - Consolidated List - General...     NaN    NaN
# 2293    13662 Sectoral Directive 1 - Consolidated List...     NaN    NaN
# 3125    13662 Sectoral Directive 1 - Sectoral Sanction...     NaN    NaN
# ...                                                   ...     ...    ...
# 381995  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
# 382036  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
# 382077  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
# 382118  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
# 382159  Non-SDN Palestinian Legislative Council List -...     NaN    NaN
#
#                                     dataset            last_seen  \
# 0       US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 822     US OFAC Consolidated (non-SDN) List  2021-12-17 03:03:07
# 1473    US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# 2293    US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 3125    US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# ...                                     ...                  ...
# 381995  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382036  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382077  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382118  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382159  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
#
#                  first_seen date_stamp last_change  new_entry  deletion  \
# 0       2021-09-28 03:03:19   20210928         NaN       True     False
# 822     2022-03-19 18:17:19   20220319         NaN       True     False
# 1473    2021-09-30 11:39:21   20210930         NaN       True     False
# 2293    2021-09-18 12:23:43   20210918         NaN       True     False
# 3125    2021-09-28 03:03:19   20210928         NaN       True     False
# ...                     ...        ...         ...        ...       ...
# 381995  2021-08-20 20:39:54   20210820         NaN       True     False
# 382036  2021-08-20 20:39:54   20210820         NaN       True     False
# 382077  2021-08-20 20:39:54   20210820         NaN       True     False
# 382118  2021-08-20 20:39:54   20210820         NaN       True     False
# 382159  2021-08-20 20:39:54   20210820         NaN       True     False
#
#         unchanged
# 0           False
# 822         False
# 1473        False
# 2293        False
# 3125        False
# ...           ...
# 381995      False
# 382036      False
# 382077      False
# 382118      False
# 382159      False
#
# [956 rows x 19 columns]
#                                id   schema                     name  \
# 0       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 1       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 2       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 3       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# 4       NK-28ZcFDmHBF9L3WkDBBwH6H  Company  GAZPROMBANK LEASING ZAO
# ...                           ...      ...                      ...
# 382195             ofac-cons-9716   Person         Qais Abdul KARIM
# 382196             ofac-cons-9716   Person         Qais Abdul KARIM
# 382197             ofac-cons-9716   Person         Qais Abdul KARIM
# 382198             ofac-cons-9716   Person         Qais Abdul KARIM
# 382199             ofac-cons-9716   Person         Qais Abdul KARIM
#
#                                               aliases birth_date countries  \
# 0       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 1       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 2       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 3       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# 4       CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING        NaN        ru
# ...                                               ...        ...       ...
# 382195                                            NaN        NaN       NaN
# 382196                                            NaN        NaN       NaN
# 382197                                            NaN        NaN       NaN
# 382198                                            NaN        NaN       NaN
# 382199                                            NaN        NaN       NaN
#
#                                                 addresses  \
# 0       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 1       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 2       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 3       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 4       D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# ...                                                   ...
# 382195                                                NaN
# 382196                                                NaN
# 382197                                                NaN
# 382198                                                NaN
# 382199                                                NaN
#
#                      identifiers  \
# 0       1037728033606;7728294503
# 1       1037728033606;7728294503
# 2       1037728033606;7728294503
# 3       1037728033606;7728294503
# 4       1037728033606;7728294503
# ...                          ...
# 382195                       NaN
# 382196                       NaN
# 382197                       NaN
# 382198                       NaN
# 382199                       NaN
#
#                                                 sanctions  phones  ...  \
# 0       13662 Sectoral Directive 1 - Sectoral Sanction...     NaN  ...
# 1       13662 Sectoral Directive 1 - Program - Consoli...     NaN  ...
# 2       Program - 13662 Sectoral Directive 1 - Consoli...     NaN  ...
# 3       Consolidated List - Program - 13662 Sectoral D...     NaN  ...
# 4       13662 Sectoral Directive 1 - Program - Consoli...     NaN  ...
# ...                                                   ...     ...  ...
# 382195  Consolidated List - Reject - Program - General...     NaN  ...
# 382196  Consolidated List - Program - Reject - General...     NaN  ...
# 382197  Program - Reject - Consolidated List - General...     NaN  ...
# 382198  Program - Consolidated List - Reject - General...     NaN  ...
# 382199  Non-SDN Palestinian Legislative Council List -...     NaN  ...
#
#                                     dataset            last_seen  \
# 0       US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 1       US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 2       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# 3       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# 4       US OFAC Consolidated (non-SDN) List  2021-09-30 11:39:21
# ...                                     ...                  ...
# 382195  US OFAC Consolidated (non-SDN) List  2021-07-26 11:55:45
# 382196  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382197  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382198  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
# 382199  US OFAC Consolidated (non-SDN) List  2021-09-26 14:52:11
#
#                  first_seen date_stamp last_change new_entry  deletion  \
# 0       2021-09-28 03:03:19   20210928         NaN      True     False
# 1       2021-09-29 03:02:51   20210929         NaN     False     False
# 2       2021-09-30 11:39:21   20210930         NaN     False     False
# 3       2021-10-01 03:02:43   20211001         NaN     False     False
# 4       2021-10-02 03:03:02   20211002         NaN     False     False
# ...                     ...        ...         ...       ...       ...
# 382195  2021-09-24 03:02:55   20210925         NaN     False     False
# 382196  2021-09-26 14:52:11   20210926         NaN     False     False
# 382197  2021-09-27 09:09:30   20210927         NaN     False     False
# 382198  2021-09-28 03:03:19   20210928         NaN     False     False
# 382199  2021-09-29 03:02:51   20210929         NaN     False      True
#
#         unchanged    month listing_count
# 0           False  2021-09           867
# 1            True  2021-09           867
# 2            True  2021-09           867
# 3            True  2021-10           433
# 4            True  2021-10           433
# ...           ...      ...           ...
# 382195       True  2021-09           867
# 382196       True  2021-09           867
# 382197       True  2021-09           867
# 382198       True  2021-09           867
# 382199      False  2021-09           867
#
# [382200 rows x 21 columns]
# Deduplicate
#                             id        schema  \
# 0    NK-28ZcFDmHBF9L3WkDBBwH6H       Company
# 1    NK-2BsamqL437nSYMzH9KHktg  Organization
# 2    NK-2FBeAKkRfBHbfVLpuEpNZv        Person
# 3    NK-2FbKDZw9xDh29GoQicYG8f       Company
# 4    NK-2JCKKtyfmLdhLbRRvconU8       Company
# ..                         ...           ...
# 951             ofac-cons-9712        Person
# 952             ofac-cons-9713        Person
# 953             ofac-cons-9714        Person
# 954             ofac-cons-9715        Person
# 955             ofac-cons-9716        Person
#
#                                                name  \
# 0                           GAZPROMBANK LEASING ZAO
# 1                       SZ DJI Technology Co., Ltd.
# 2                       Yahia Abdul Aziz AL-ABADSAH
# 3                    SBERBANK INSURANCE COMPANY LTD
# 4    KORUS CONSULTING CIS LIMITED LIABILITY COMPANY
# ..                                              ...
# 951                                 Mohammed SHIHAB
# 952                                    Ahmad SA'DAT
# 953                                 Jamil MAJDALAWI
# 954                                 Khaledah JARRAR
# 955                                Qais Abdul KARIM
#
#                                                aliases             birth_date  \
# 0        CLOSED JOINT-STOCK COMPANY GAZPROMBANK LIZING                    NaN
# 1                                        深圳市大疆创新科技有限公司                    NaN
# 2                           Yehia Abdul Aziz EL ABADSA                   1958
# 3    LLC INSURANCE COMPANY SBERBANK INSURANCE;OBSHC...                    NaN
# 4    KORUS KONSALTING SNG, OOO;LLL KORUS CONSULTING...                    NaN
# ..                                                 ...                    ...
# 951                    Mohamed Abed Hadi Rahman SHEHAB  1956-01-01;1956-12-31
# 952                                                NaN                    NaN
# 953                                                NaN                    NaN
# 954                                                NaN                    NaN
# 955                                                NaN                    NaN
#
#     countries                                          addresses  \
# 0          ru  D.40 Ulitsa Miklukho-Maklaya, Moscow, 117342;P...
# 1          cn  14 F, West Block of Skyworth Semiconductor Des...
# 2          ps                                        Khan Younis
# 3          ru  42 Bolshaya Yakimanka St., b. 1-2, office 209,...
# 4          ru  68 Sampsonievsky Avenue, letter N, Room 1N, Sa...
# ..        ...                                                ...
# 951       NaN                                       undetermined
# 952       NaN                                       undetermined
# 953       NaN                                       undetermined
# 954       NaN                                       undetermined
# 955       NaN                                       undetermined
#
#                   identifiers  \
# 0    1037728033606;7728294503
# 1          914403007954257495
# 2                         NaN
# 3               1147746683479
# 4               1057812752502
# ..                        ...
# 951                       NaN
# 952                       NaN
# 953                       NaN
# 954                       NaN
# 955                       NaN
#
#                                              sanctions  phones  ...  \
# 0    13662 Sectoral Directive 1 - Sectoral Sanction...     NaN  ...
# 1    Consolidated List - Program - CMIC Executive O...     NaN  ...
# 2    Reject - Program - Consolidated List - General...     NaN  ...
# 3    13662 Sectoral Directive 1 - Consolidated List...     NaN  ...
# 4    13662 Sectoral Directive 1 - Sectoral Sanction...     NaN  ...
# ..                                                 ...     ...  ...
# 951  Non-SDN Palestinian Legislative Council List -...     NaN  ...
# 952  Non-SDN Palestinian Legislative Council List -...     NaN  ...
# 953  Non-SDN Palestinian Legislative Council List -...     NaN  ...
# 954  Non-SDN Palestinian Legislative Council List -...     NaN  ...
# 955  Non-SDN Palestinian Legislative Council List -...     NaN  ...
#
#               first_seen date_stamp last_change new_entry deletion unchanged  \
# 0    2021-09-28 03:03:19   20210928         NaN      True    False     False
# 1    2022-03-19 18:17:19   20220319         NaN      True    False     False
# 2    2021-09-30 11:39:21   20210930         NaN      True    False     False
# 3    2021-09-18 12:23:43   20210918         NaN      True    False     False
# 4    2021-09-28 03:03:19   20210928         NaN      True    False     False
# ..                   ...        ...         ...       ...      ...       ...
# 951  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 952  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 953  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 954  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 955  2021-08-20 20:39:54   20210820         NaN      True    False     False
#
#        month  listing_count  listing_date delisting_date
# 0    2021-09            867      20210928            NaN
# 1    2022-03            470      20220319            NaN
# 2    2021-09            867      20210930            NaN
# 3    2021-09            867      20210918            NaN
# 4    2021-09            867      20210928            NaN
# ..       ...            ...           ...            ...
# 951  2021-08            432      20210820            NaN
# 952  2021-08            432      20210820            NaN
# 953  2021-08            432      20210820            NaN
# 954  2021-08            432      20210820            NaN
# 955  2021-08            432      20210820            NaN
#
# [956 rows x 23 columns]
# ['ru' 'cn' 'ps' nan 'cy' 'vg' 'at' 'cn;hk' 'nl' 'am' 'ch' 'cn;ky' 'by'
#  'ge' 'kz' 'ky' 'mm' 'ua' 'tr' 'az' 'lu' 'gg;ru' 'cz' 'cy;vg' 'rs' 'ao']
# ['Company' 'Organization' 'Person']
# ['20210928' '20220319' '20210930' '20210918' '20220226' '20220413'
#  '20220418' '20220529' '20220408' '20220608' '20230318' '20220722'
#  '20220305' '20220228' '20220724' '20231031' '20220712' '20231120'
#  '20220903' '20220302' '20220316' '20220411' '20220318' '20220203'
#  '20220406' '20211003' '20220721' '20220421' '20220324' '20220705'
#  '20220602' '20221210' '20220304' '20220623' '20220612' '20221212'
#  '20220727' '20231221' '20220223' '20211217' '20211211' '20220225'
#  '20210820']
# id                  0
# schema              0
# name                0
# aliases            82
# birth_date        801
# countries         115
# addresses          61
# identifiers       359
# sanctions           0
# phones            956
# emails            662
# dataset             0
# last_seen           0
# first_seen          0
# date_stamp          0
# last_change       951
# new_entry           0
# deletion            0
# unchanged           0
# month               0
# listing_count       0
# listing_date        0
# delisting_date    950
# dtype: int64

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20231231',freq='D').strftime('%Y%m%d')
print(date_list)
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []
for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/us_bis_denied/targets.simple.csv'
    websites.append(test)
print(websites)
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes
print(res)
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows
# Reset index for the final result
res.reset_index(drop=True, inplace=True)
print(res)
#test thematching function
test = res.query('new_entry == True')
print(test)
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
print(res)

print("Deduplicate")
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)
# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')
# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)
# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
res_deduplicated.columns
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)
res_deduplicated.to_csv("us_bis.csv")
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=883)
# ['https://data.opensanctions.org/datasets/20210801/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210915/us_bis_denied/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210916/us_bis_denied/targets.simple.csv', 'htt ...
#                                           id       schema  \
# 0          us-bis-01-10-1984-captain-elyazgi  LegalEntity
# 1          us-bis-01-10-1984-colonel-elyazgi  LegalEntity
# 2      us-bis-01-10-1984-najmeddin-a-elyazgi  LegalEntity
# 3             us-bis-01-10-1984-nedim-sulyak  LegalEntity
# 4    us-bis-01-12-2015-mario-obdulio-padilla  LegalEntity
# ..                                       ...          ...
# 512                NK-oLnRC8m3Zr6aebcxFHsLga  LegalEntity
# 513                NK-oMExHi3V5pvXuLKnHD8W4c  LegalEntity
# 514                NK-oPaaxkdBXr6xpNxGdZLPBN  LegalEntity
# 515                NK-oW3jdwu9LWByhgx9aqFqhF  LegalEntity
# 516                NK-oXWzNpKCS6PenT6kVYJa9G  LegalEntity
#
#                               name aliases  birth_date countries  \
# 0                  CAPTAIN ELYAZGI     NaN         NaN        ly
# 1                  COLONEL ELYAZGI     NaN         NaN        ly
# 2             NAJMEDDIN A. ELYAZGI     NaN         NaN        ly
# 3                     NEDIM SULYAK     NaN         NaN        us
# 4            MARIO OBDULIO PADILLA     NaN         NaN        us
# ..                             ...     ...         ...       ...
# 512                  COTRICOM S.A.     NaN         NaN        fr
# 513                    TUQIANG XIE     NaN         NaN       NaN
# 514                    ALI KOURANI     NaN         NaN       NaN
# 515                       DINA ZHU     NaN         NaN       NaN
# 516  SERIGO EDUARDO PEREZ-BARRAGAN     NaN         NaN        mx
#
#                                              addresses  identifiers  \
# 0                           OKBA AIR BASE, TRIPOLI, LY          NaN
# 1                           OKBA AIR BASE, TRIPOLI, LY          NaN
# 2                           OKBA AIR BASE, TRIPOLI, LY          NaN
# 3               1303 LANDWEHR ROAD, NORTHBROOK, IL, US          NaN
# 4    INMATE #98126-004, FCI PETERSBURG LOW, FEDERAL...          NaN
# ..                                                 ...          ...
# 512                       4 ALLES DES MESANGES, YERRES          NaN
# 513                           110 ESPINA, 92620 IRVINE          NaN
# 514  INMTATE NUMBER: 79196-054, USP MARION U.S. PEN...          NaN
# 515       101 WINDSOR CHASE DRIVE, 30043 LAWRENCEVILLE          NaN
# 516    ALTAMIRA 411 PONIENTE, 89137 TAMPICO TAMAULIPAS          NaN
#
#                                              sanctions  phones  emails  \
# 0                    49 F.R. 2002 1/17/84 - 1984-01-10     NaN     NaN
# 1                    49 F.R. 2002 1/17/84 - 1984-01-10     NaN     NaN
# 2                    49 F.R. 2002 1/17/84 - 1984-01-10     NaN     NaN
# 3                    49 F.R. 2002 1/17/84 - 1984-01-10     NaN     NaN
# 4      80 F.R. 2681  1/20/15 - 2015-01-12 - 2022-12-17     NaN     NaN
# ..                                                 ...     ...     ...
# 512                52 F.R. 38497 10/16/87 - 1987-10-08     NaN     NaN
# 513  88 F.R. 58545 8/28/2023 - 2023-08-22 - 2032-03-30     NaN     NaN
# 514  86 F.R. 69007 12/6/2021 - 2021-11-30 - 2029-12-03     NaN     NaN
# 515  88 F.R. 73309 10/25/2023 - 2023-10-05 - 2024-1...     NaN     NaN
# 516   87 F.R. 19476 4/4/2022 - 2022-03-30 - 2026-05-23     NaN     NaN
#
#                         dataset            last_seen           first_seen  \
# 0    US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 1    US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 2    US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 3    US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 4    US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# ..                          ...                  ...                  ...
# 512  US BIS Denied Persons List  2023-12-31T16:58:08  2023-04-20T12:11:17
# 513  US BIS Denied Persons List  2023-12-31T16:58:08  2023-08-23T15:00:01
# 514  US BIS Denied Persons List  2023-12-31T16:58:08  2023-04-20T12:11:17
# 515  US BIS Denied Persons List  2023-12-31T16:58:08  2023-10-20T18:01:43
# 516  US BIS Denied Persons List  2023-12-31T16:58:08  2023-04-20T12:11:17
#
#     date_stamp          last_change
# 0     20210820                  NaN
# 1     20210820                  NaN
# 2     20210820                  NaN
# 3     20210820                  NaN
# 4     20210820                  NaN
# ..         ...                  ...
# 512   20231231  2023-07-27T12:03:01
# 513   20231231  2023-08-28T18:01:55
# 514   20231231  2023-04-20T12:11:17
# 515   20231231  2023-10-25T16:57:01
# 516   20231231  2023-07-27T12:03:01
#
# [385794 rows x 16 columns]
#                                            id       schema  \
# 0                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 1                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 2                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 3                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 4                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# ...                                       ...          ...
# 385789  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385790  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385791  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385792  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385793  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
#
#                           name aliases  birth_date countries  \
# 0       JEROME STUART PENDZICH     NaN         NaN        us
# 1       JEROME STUART PENDZICH     NaN         NaN        us
# 2       JEROME STUART PENDZICH     NaN         NaN        us
# 3       JEROME STUART PENDZICH     NaN         NaN        us
# 4       JEROME STUART PENDZICH     NaN         NaN        us
# ...                        ...     ...         ...       ...
# 385789     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385790     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385791     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385792     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385793     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
#
#                                                 addresses  identifiers  \
# 0       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 1       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 2       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 3       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 4       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# ...                                                   ...          ...
# 385789  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385790  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385791  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385792  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385793  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
#
#                                              sanctions  phones  emails  \
# 0       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# 1       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# 2       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# 3       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# 4       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# ...                                                ...     ...     ...
# 385789  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
# 385790  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
# 385791  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
# 385792  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
# 385793  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
#
#                            dataset            last_seen           first_seen  \
# 0       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-18 12:23:43
# 1       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-19 03:02:53
# 2       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-20 03:03:05
# 3       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-21 03:03:02
# 4       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-22 03:02:52
# ...                            ...                  ...                  ...
# 385789  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-13 03:02:45
# 385790  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-14 03:02:48
# 385791  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-15 03:04:39
# 385792  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-16 03:02:52
# 385793  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-17 03:02:46
#
#        date_stamp last_change  new_entry  deletion  unchanged
# 0        20210918         NaN       True     False      False
# 1        20210919         NaN      False     False       True
# 2        20210920         NaN      False     False       True
# 3        20210921         NaN      False     False       True
# 4        20210922         NaN      False     False       True
# ...           ...         ...        ...       ...        ...
# 385789   20210913         NaN      False     False       True
# 385790   20210914         NaN      False     False       True
# 385791   20210915         NaN      False     False       True
# 385792   20210916         NaN      False     False       True
# 385793   20210917         NaN      False      True      False
#
# [385794 rows x 19 columns]
#                                            id       schema  \
# 0                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 53                  NK-29UKv94hzzofL4syPM73UQ  LegalEntity
# 885                 NK-2BKEQcHDfMCn4zA6VAEjba  LegalEntity
# 1672                NK-2Ena7XxvGa7wvL8MmrG3de  LegalEntity
# 2397                NK-2HZh2ruqvDvsjgiWxNUPGJ  LegalEntity
# ...                                       ...          ...
# 385604    us-bis-12-31-2018-veronica-trujillo  LegalEntity
# 385633   us-bis-12-31-2019-edgar-sanchez-muro  LegalEntity
# 385662          us-bis-12-31-2019-resit-tavan  LegalEntity
# 385691  us-bis-12-31-2019-ruben-beltran-ramos  LegalEntity
# 385765  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
#
#                           name aliases  birth_date countries  \
# 0       JEROME STUART PENDZICH     NaN         NaN        us
# 53                REXFORD LTD.     NaN         NaN        gb
# 885             ALI REZA PARSA     NaN         NaN        ca
# 1672            DOUGLAS GLOVER     NaN         NaN       NaN
# 2397     SAEID YAHYA CHARKHIAN     NaN         NaN        ae
# ...                        ...     ...         ...       ...
# 385604       VERONICA TRUJILLO     NaN         NaN       NaN
# 385633      EDGAR SANCHEZ-MURO     NaN         NaN       NaN
# 385662             RESIT TAVAN     NaN         NaN        tr
# 385691     RUBEN BELTRAN-RAMOS     NaN         NaN       NaN
# 385765     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
#
#                                                 addresses  identifiers  \
# 0       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 53                        138 BUDBROOKE ROAD, WARWICK, GB          NaN
# 885     518 STARBOARD CRESCENT WATERLOO, ONTARIO;INMAT...          NaN
# 1672               229 EAST HAVEN DRIVE, 35215 BIRMINGHAM          NaN
# 2397        VILLA 5, STREET 1, ARABIAN RANCHES, DUBAI, AE          NaN
# ...                                                   ...          ...
# 385604  INMATE NUMBER 64909-408, FCI PHOENIX, 37910 N....          NaN
# 385633             2065 CAMARGO STREET, 78526 BROWNSVILLE          NaN
# 385662    TATLI SU MAH. NO. 72/A, UMRANIYE - ISTANBUL, TR          NaN
# 385691  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385765  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
#
#                                                 sanctions  phones  emails  \
# 0          78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN     NaN
# 53                    49 F.R. 49666 12/21/84 - 1984-12-14     NaN     NaN
# 885     82 F.R. 28473, 28474 6/22/2017 - 2017-06-07 - ...     NaN     NaN
# 1672    86 F.R. 69008 12/6/2021 - 2021-11-30 - 2026-04-08     NaN     NaN
# 2397    82 F.R. 61540 12/28/2017 - 2017-12-21 - 2029-1...     NaN     NaN
# ...                                                   ...     ...     ...
# 385604    84 F.R. 1423 2/4/2019 - 2018-12-31 - 2024-08-11     NaN     NaN
# 385633     85 F.R. 873 1/8/2020 - 2019-12-31 - 2024-06-19     NaN     NaN
# 385662     85 F.R. 874 1/8/2020 - 2019-12-31 - 2028-08-29     NaN     NaN
# 385691     85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
# 385765     85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN     NaN
#
#                            dataset            last_seen           first_seen  \
# 0       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-18 12:23:43
# 53      US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-18 12:23:43
# 885     US BIS Denied Persons List  2021-07-26 11:55:45  2021-11-02 07:54:25
# 1672    US BIS Denied Persons List  2021-12-03 03:02:58  2022-01-03 03:03:37
# 2397    US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-18 12:23:43
# ...                            ...                  ...                  ...
# 385604  US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 385633  US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 385662  US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 385691  US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
# 385765  US BIS Denied Persons List  2021-07-26 11:55:45  2021-08-20 20:39:54
#
#        date_stamp last_change  new_entry  deletion  unchanged
# 0        20210918         NaN       True     False      False
# 53       20210918         NaN       True     False      False
# 885      20211102         NaN       True     False      False
# 1672     20220103         NaN       True     False      False
# 2397     20210918         NaN       True     False      False
# ...           ...         ...        ...       ...        ...
# 385604   20210820         NaN       True     False      False
# 385633   20210820         NaN       True     False      False
# 385662   20210820         NaN       True     False      False
# 385691   20210820         NaN       True     False      False
# 385765   20210820         NaN       True     False      False
#
# [1517 rows x 19 columns]
#                                            id       schema  \
# 0                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 1                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 2                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 3                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 4                   NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# ...                                       ...          ...
# 385789  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385790  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385791  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385792  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
# 385793  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
#
#                           name aliases  birth_date countries  \
# 0       JEROME STUART PENDZICH     NaN         NaN        us
# 1       JEROME STUART PENDZICH     NaN         NaN        us
# 2       JEROME STUART PENDZICH     NaN         NaN        us
# 3       JEROME STUART PENDZICH     NaN         NaN        us
# 4       JEROME STUART PENDZICH     NaN         NaN        us
# ...                        ...     ...         ...       ...
# 385789     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385790     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385791     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385792     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
# 385793     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
#
#                                                 addresses  identifiers  \
# 0       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 1       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 2       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 3       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 4       209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# ...                                                   ...          ...
# 385789  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385790  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385791  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385792  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 385793  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
#
#                                              sanctions  phones  ...  \
# 0       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# 1       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# 2       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# 3       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# 4       78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# ...                                                ...     ...  ...
# 385789  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
# 385790  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
# 385791  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
# 385792  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
# 385793  85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
#
#                            dataset            last_seen           first_seen  \
# 0       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-18 12:23:43
# 1       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-19 03:02:53
# 2       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-20 03:03:05
# 3       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-21 03:03:02
# 4       US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-22 03:02:52
# ...                            ...                  ...                  ...
# 385789  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-13 03:02:45
# 385790  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-14 03:02:48
# 385791  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-15 03:04:39
# 385792  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-16 03:02:52
# 385793  US BIS Denied Persons List  2021-07-26 11:55:45  2021-09-17 03:02:46
#
#        date_stamp last_change new_entry  deletion  unchanged    month  \
# 0        20210918         NaN      True     False      False  2021-09
# 1        20210919         NaN     False     False       True  2021-09
# 2        20210920         NaN     False     False       True  2021-09
# 3        20210921         NaN     False     False       True  2021-09
# 4        20210922         NaN     False     False       True  2021-09
# ...           ...         ...       ...       ...        ...      ...
# 385789   20210913         NaN     False     False       True  2021-09
# 385790   20210914         NaN     False     False       True  2021-09
# 385791   20210915         NaN     False     False       True  2021-09
# 385792   20210916         NaN     False     False       True  2021-09
# 385793   20210917         NaN     False      True      False  2021-09
#
#        listing_count
# 0                697
# 1                697
# 2                697
# 3                697
# 4                697
# ...              ...
# 385789           697
# 385790           697
# 385791           697
# 385792           697
# 385793           697
#
# [385794 rows x 21 columns]
# Deduplicate
#                                          id       schema  \
# 0                 NK-26VThjdJM9kZJw89C9j6QH  LegalEntity
# 1                 NK-29UKv94hzzofL4syPM73UQ  LegalEntity
# 2                 NK-2BKEQcHDfMCn4zA6VAEjba  LegalEntity
# 3                 NK-2Ena7XxvGa7wvL8MmrG3de  LegalEntity
# 4                 NK-2HZh2ruqvDvsjgiWxNUPGJ  LegalEntity
# ...                                     ...          ...
# 1512    us-bis-12-31-2018-veronica-trujillo  LegalEntity
# 1513   us-bis-12-31-2019-edgar-sanchez-muro  LegalEntity
# 1514          us-bis-12-31-2019-resit-tavan  LegalEntity
# 1515  us-bis-12-31-2019-ruben-beltran-ramos  LegalEntity
# 1516  us-bis-12-31-2019-ruben-ramos-beltran  LegalEntity
#
#                         name aliases  birth_date countries  \
# 0     JEROME STUART PENDZICH     NaN         NaN        us
# 1               REXFORD LTD.     NaN         NaN        gb
# 2             ALI REZA PARSA     NaN         NaN        ca
# 3             DOUGLAS GLOVER     NaN         NaN       NaN
# 4      SAEID YAHYA CHARKHIAN     NaN         NaN        ae
# ...                      ...     ...         ...       ...
# 1512       VERONICA TRUJILLO     NaN         NaN       NaN
# 1513      EDGAR SANCHEZ-MURO     NaN         NaN       NaN
# 1514             RESIT TAVAN     NaN         NaN        tr
# 1515     RUBEN BELTRAN-RAMOS     NaN         NaN       NaN
# 1516     RUBEN RAMOS-BELTRAN     NaN         NaN       NaN
#
#                                               addresses  identifiers  \
# 0     209 REECE HILL ROAD, HAMPTON, TN 37658-3615, U...          NaN
# 1                       138 BUDBROOKE ROAD, WARWICK, GB          NaN
# 2     518 STARBOARD CRESCENT WATERLOO, ONTARIO;INMAT...          NaN
# 3                229 EAST HAVEN DRIVE, 35215 BIRMINGHAM          NaN
# 4         VILLA 5, STREET 1, ARABIAN RANCHES, DUBAI, AE          NaN
# ...                                                 ...          ...
# 1512  INMATE NUMBER 64909-408, FCI PHOENIX, 37910 N....          NaN
# 1513             2065 CAMARGO STREET, 78526 BROWNSVILLE          NaN
# 1514    TATLI SU MAH. NO. 72/A, UMRANIYE - ISTANBUL, TR          NaN
# 1515  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
# 1516  INMATE NUMBER: 50076-479, BIG SPRING CORRECTIO...          NaN
#
#                                               sanctions  phones  ...  \
# 0        78 F.R. 4832 1/23/13 - 2013-01-14 - 2021-10-12     NaN  ...
# 1                   49 F.R. 49666 12/21/84 - 1984-12-14     NaN  ...
# 2     82 F.R. 28473, 28474 6/22/2017 - 2017-06-07 - ...     NaN  ...
# 3     86 F.R. 69008 12/6/2021 - 2021-11-30 - 2026-04-08     NaN  ...
# 4     82 F.R. 61540 12/28/2017 - 2017-12-21 - 2029-1...     NaN  ...
# ...                                                 ...     ...  ...
# 1512    84 F.R. 1423 2/4/2019 - 2018-12-31 - 2024-08-11     NaN  ...
# 1513     85 F.R. 873 1/8/2020 - 2019-12-31 - 2024-06-19     NaN  ...
# 1514     85 F.R. 874 1/8/2020 - 2019-12-31 - 2028-08-29     NaN  ...
# 1515     85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
# 1516     85 F.R. 875 1/8/2020 - 2019-12-31 - 2028-11-20     NaN  ...
#
#                first_seen date_stamp last_change new_entry deletion unchanged  \
# 0     2021-09-18 12:23:43   20210918         NaN      True    False     False
# 1     2021-09-18 12:23:43   20210918         NaN      True    False     False
# 2     2021-11-02 07:54:25   20211102         NaN      True    False     False
# 3     2022-01-03 03:03:37   20220103         NaN      True    False     False
# 4     2021-09-18 12:23:43   20210918         NaN      True    False     False
# ...                   ...        ...         ...       ...      ...       ...
# 1512  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 1513  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 1514  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 1515  2021-08-20 20:39:54   20210820         NaN      True    False     False
# 1516  2021-08-20 20:39:54   20210820         NaN      True    False     False
#
#         month  listing_count  listing_date delisting_date
# 0     2021-09            697      20210918            NaN
# 1     2021-09            697      20210918            NaN
# 2     2021-11            645      20211102            NaN
# 3     2022-01            442      20220103            NaN
# 4     2021-09            697      20210918            NaN
# ...       ...            ...           ...            ...
# 1512  2021-08            429      20210820            NaN
# 1513  2021-08            429      20210820            NaN
# 1514  2021-08            429      20210820            NaN
# 1515  2021-08            429      20210820            NaN
# 1516  2021-08            429      20210820            NaN
#
# [1517 rows x 23 columns]
# ['us' 'gb' 'ca' nan 'ae' 'gb;lb;sy;tr' 'fr' 'de' 'se' 'ru' 'de;es' 'ly'
#  'mx' 'cn' 'ir' 'lb' 'in' 'tw' 'sg' 've' 'ch;fr;ly' 'be' 'tr' 'mv' 'sy'
#  'ir;us' 'iq;sa' 'in;us' 'ch' 'gr' 'lu;ly;mt' 'at' 'ru;tr' 'ae;iq;jo' 'bg'
#  'iq;jo' 'li' 'by' 'lu' 'ua' 'sg;us' 'iq' 'gb;lb;sy' 'lb;sy;tr']
# ['LegalEntity']
# ['20210918' '20211102' '20220103' '20211103' '20220401' '20230309'
#  '20221015' '20211106' '20211023' '20210930' '20230228' '20230902'
#  '20231109' '20231221' '20230506' '20231117' '20230513' '20220709'
#  '20230406' '20230322' '20220409' '20230203' '20220624' '20230614'
#  '20220119' '20211117' '20230519' '20220827' '20221221' '20220611'
#  '20230301' '20230912' '20220803' '20220831' '20230226' '20230929'
#  '20230224' '20230824' '20230814' '20211205' '20230419' '20230108'
#  '20230210' '20230531' '20221214' '20211121' '20211109' '20230113'
#  '20230721' '20221204' '20230129' '20230619' '20230331' '20211201'
#  '20220903' '20221021' '20231116' '20220203' '20221001' '20220913'
#  '20230523' '20211115' '20220226' '20211229' '20220626' '20220608'
#  '20220929' '20230215' '20220529' '20211123' '20220722' '20230418'
#  '20220620' '20220519' '20231119' '20230304' '20230830' '20220928'
#  '20220706' '20230913' '20221102' '20211014' '20220425' '20231021'
#  '20230106' '20230110' '20230111' '20210820' '20230112' '20230117'
#  '20220113' '20230120' '20220121' '20230127' '20230201' '20220223'
#  '20220224' '20220215' '20230223' '20230227' '20230303' '20210925'
#  '20230307' '20220514' '20230404' '20230329' '20230330' '20220331'
#  '20220408' '20230411' '20230414' '20220422' '20230504' '20230510'
#  '20230512' '20230530' '20230518' '20230511' '20230522' '20220523'
#  '20230613' '20220610' '20220613' '20230608' '20230609' '20230616'
#  '20220617' '20220719' '20230715' '20230725' '20221006' '20230811'
#  '20230822' '20230823' '20220826' '20230901' '20220829' '20220830'
#  '20210902' '20220912' '20230911' '20210910' '20210915' '20210922'
#  '20210911' '20230925' '20220825' '20220930' '20230928' '20231020'
#  '20231007' '20221014' '20221020' '20221101' '20231102' '20231108'
#  '20211110' '20221108' '20211111' '20221117' '20231118' '20211119'
#  '20211203' '20211207' '20221202' '20231205' '20221206' '20221215'
#  '20231220' '20221220' '20230124']
# id                   0
# schema               0
# name                 0
# aliases           1508
# birth_date        1517
# countries          656
# addresses            0
# identifiers       1517
# sanctions           52
# phones            1517
# emails            1517
# dataset              0
# last_seen            0
# first_seen           0
# date_stamp           0
# last_change       1387
# new_entry            0
# deletion             0
# unchanged            0
# month                0
# listing_count        0
# listing_date         0
# delisting_date    1330
# dtype: int64

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20231231',freq='D').strftime('%Y%m%d')
print(date_list)
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []
for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/eu_fsf/targets.simple.csv'
    websites.append(test)
print(websites)
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes
print(res)
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows
# Reset index for the final result
res.reset_index(drop=True, inplace=True)
print(res)
#test thematching function
test = res.query('new_entry == True')
print(test)
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
print(res)

print("Deduplicate")
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)
# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')
# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)
# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
res_deduplicated.columns
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)
res_deduplicated.to_csv("eu_fsf.csv")
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=883)
# ['https://data.opensanctions.org/datasets/20210801/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210915/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210916/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210917/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210918/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210919/eu_fsf/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210920/eu_fsf/targets.simple.csv', 'https://data.opensan ...
#                      id  schema                          name  \
# 0     eu-fsf-eu-1001-60  Person                 Yassin Syawal
# 1     eu-fsf-eu-1003-87  Person              Isamuddin Riduan
# 2     eu-fsf-eu-1006-79  Person   Salim Y Salamuddin JULKIPLI
# 3       eu-fsf-eu-101-7  Person   Amir Hamudi Hassan Al-Sa'di
# 4     eu-fsf-eu-1010-96  Person        Abu Jibril Abdurrahman
# ...                 ...     ...                           ...
# 4340          Q99541861  Person  Andrej Vladimirovitj JATSKIN
# 4341          Q99615093  Person  Sergei Petrovich RUBNIKOVICH
# 4342          Q99675811  Person   Sergej Nikolajevitj MURATOV
# 4343          Q99767758  Person        Lenar Rinatovich SAFIN
# 4344          Q99861219  Person       Ivan Ivanovich GOLOVATY
#
#                                                 aliases  \
# 0     Abdul Hadi Yasin;Abu Muamar;Abu Seta;Mahmud;Mu...
# 1     Encep Nurjaman (birth name);Hambali;Hambali Bi...
# 2                             Julkipli Salim;Kipli Sali
# 3                           Amir Hamoudi Hassan Al-Sadi
# 4     Fihiruddin Muqti;Fikiruddin Muqti;Mohamad Iqba...
# ...                                                 ...
# 4340  Andrey Vladimirovich YATSKIN;Андрей Владимиров...
# 4341  Cергей Петрович РУБНИКОВИЧ;Cяргей Пятровіч РУБ...
# 4342  Sergey Nikolayevich MURATOV;Сергей Николаевич ...
# 4343       Lenar Rinatovitj SAFIN;Ленар Ринатович САФИН
# 4344  Ivan GALAVATIJ;Ivan Ivanavich GALAVATYI;Ivan I...
#
#                  birth_date countries  \
# 0                1962-09-03        id
# 1                1964-04-04        id
# 2                1967-06-20        ph
# 3                1938-04-05        iq
# 4     1957-08-17;1958-08-17        id
# ...                     ...       ...
# 4340             1969-04-25       NaN
# 4341                   1974        by
# 4342             1964-01-13       NaN
# 4343             1969-02-11       NaN
# 4344             1976-06-15        by
#
#                                               addresses identifiers  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     Jalan Nakula, Komplek Witana Harja III Blok C ...         NaN
# ...                                                 ...         ...
# 4340                                                NaN         NaN
# 4341                                                NaN         NaN
# 4342                                                NaN         NaN
# 4343                                                NaN         NaN
# 4344                                                NaN         NaN
#
#                                               sanctions phones emails  \
# 0                 TAQA - 2019/555 (OJ L97) - 2019-04-09    NaN    NaN
# 1                TAQA - 577/2011 (OJ L159) - 2011-06-16    NaN    NaN
# 2                  TAQA - 34/2012 (OJ L15) - 2012-01-17    NaN    NaN
# 3     IRQ - 1210/2003 (OJ L169) - UNSC RESOLUTION 14...    NaN    NaN
# 4                TAQA - 597/2011 (OJ L162) - 2011-06-21    NaN    NaN
# ...                                                 ...    ...    ...
# 4340             UKR - 2022/1529 (OJ L239) - 2022-09-16    NaN    NaN
# 4341             BLR - 2021/997 (OJ L219I) - 2021-06-21    NaN    NaN
# 4342             UKR - 2022/1529 (OJ L239) - 2022-09-16    NaN    NaN
# 4343             UKR - 2023/571 (OJ L75 I) - 2023-03-15    NaN    NaN
# 4344               BLR - 2023/419 (OJ L61) - 2023-02-27    NaN    NaN
#
#                                  dataset            last_seen  \
# 0     EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 1     EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 2     EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 3     EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 4     EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# ...                                  ...                  ...
# 4340  EU Financial Sanctions Files (FSF)  2023-12-31T22:57:01
# 4341  EU Financial Sanctions Files (FSF)  2023-12-31T22:57:01
# 4342  EU Financial Sanctions Files (FSF)  2023-12-31T22:57:01
# 4343  EU Financial Sanctions Files (FSF)  2023-12-31T22:57:01
# 4344  EU Financial Sanctions Files (FSF)  2023-12-31T22:57:01
#
#                first_seen date_stamp          last_change
# 0     2021-08-20 20:39:54   20210820                  NaN
# 1     2021-08-20 20:39:54   20210820                  NaN
# 2     2021-08-20 20:39:54   20210820                  NaN
# 3     2021-08-20 20:39:54   20210820                  NaN
# 4     2021-08-20 20:39:54   20210820                  NaN
# ...                   ...        ...                  ...
# 4340  2023-04-20T18:00:25   20231231  2023-07-14T20:00:27
# 4341  2023-04-20T18:00:25   20231231  2023-07-26T20:01:14
# 4342  2023-04-20T18:00:25   20231231  2023-07-14T20:00:27
# 4343  2023-04-20T18:00:25   20231231  2023-04-21T16:00:21
# 4344  2023-04-20T18:00:25   20231231  2023-07-26T20:01:14
#
# [3010845 rows x 16 columns]
#                                 id        schema  \
# 0        NK-23LHNCbxbLpka28ByPhbHW        Person
# 1        NK-23LHNCbxbLpka28ByPhbHW        Person
# 2        NK-23LHNCbxbLpka28ByPhbHW        Person
# 3        NK-23LHNCbxbLpka28ByPhbHW        Person
# 4        NK-23LHNCbxbLpka28ByPhbHW        Person
# ...                            ...           ...
# 3010840           eu-fsf-eu-994-91  Organization
# 3010841           eu-fsf-eu-994-91  Organization
# 3010842          eu-fsf-eu-9952-96        Person
# 3010843          eu-fsf-eu-9992-69  Organization
# 3010844          eu-fsf-eu-9994-67  Organization
#
#                                       name  \
# 0                                Musenyeri
# 1                                  Achille
# 2                       Leopold Mujyambere
# 3                       Leopold Mujyambere
# 4                       Leopold Mujyambere
# ...                                    ...
# 3010840  Al-Haramain Foundation (Pakistan)
# 3010841  Al-Haramain Foundation (Pakistan)
# 3010842                Neda Muhammad NADÍM
# 3010843                       Grupo Wagner
# 3010844                            RIA FNA
#
#                                                    aliases  \
# 0          Achille;Frere Petrus Ibrahim;Leopold Mujyambere
# 1        Frere Petrus Ibrahim;Leopold Mujyambere;Musenyeri
# 2                   Achille;Frere Petrus Ibrahim;Musenyeri
# 3                   Achille;Frere Petrus Ibrahim;Musenyeri
# 4                   Achille;Frere Petrus Ibrahim;Musenyeri
# ...                                                    ...
# 3010840                                                NaN
# 3010841                                                NaN
# 3010842                Neda Mohammad NADEEM;نداء محمد ندیم
# 3010843  Groupe Vagner;Groupe Wagner;Grupa Vagnera;Grup...
# 3010844  FNA;Federal News Agency LLC;Federalinė naujien...
#
#                    birth_date countries  \
# 0        1962;1962-03-17;1966     cd;rw
# 1        1962;1962-03-17;1966     cd;rw
# 2        1962;1962-03-17;1966     cd;rw
# 3        1962;1962-03-17;1966     cd;rw
# 4        1962;1962-03-17;1966     cd;rw
# ...                       ...       ...
# 3010840                   NaN        pk
# 3010841                   NaN        pk
# 3010842                   NaN        af
# 3010843                   NaN       NaN
# 3010844                   NaN       NaN
#
#                                                 addresses identifiers  \
# 0                                                Kinshasa         NaN
# 1                                                Kinshasa         NaN
# 2                                                Kinshasa         NaN
# 3                                                Kinshasa         NaN
# 4                                                Kinshasa         NaN
# ...                                                   ...         ...
# 3010840  House No 279, Nazimuddin Road, F-10/1, Islamabad         NaN
# 3010841  House No 279, Nazimuddin Road, F-10/1, Islamabad         NaN
# 3010842                                               NaN         NaN
# 3010843                                               NaN         NaN
# 3010844                                               NaN         NaN
#
#                                        sanctions phones emails  \
# 0           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# 1           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# 2           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# 3           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# 4           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# ...                                          ...    ...    ...
# 3010840   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN    NaN
# 3010841   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN    NaN
# 3010842     HR - 2023/500 (OJ L69I) - 2023-03-07    NaN    NaN
# 3010843  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN    NaN
# 3010844  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN    NaN
#
#                                     dataset            last_seen  \
# 0        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 1        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 2        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 4        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# ...                                     ...                  ...
# 3010840  EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3010841  EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3010842  EU Financial Sanctions Files (FSF)  2023-03-09 18:41:03
# 3010843  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
# 3010844  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
#
#                   first_seen date_stamp last_change  new_entry  deletion  \
# 0        2021-09-28 03:03:19   20210928         NaN       True     False
# 1        2021-09-29 03:02:51   20210929         NaN      False     False
# 2        2021-09-30 11:39:21   20210930         NaN      False     False
# 3        2021-10-01 03:02:43   20211001         NaN      False     False
# 4        2021-10-02 03:03:02   20211002         NaN      False     False
# ...                      ...        ...         ...        ...       ...
# 3010840  2021-11-15 14:45:38   20211115         NaN      False     False
# 3010841  2021-11-16 03:03:05   20211116         NaN      False      True
# 3010842  2023-03-09 18:41:03   20230309         NaN       True      True
# 3010843  2023-04-20 18:00:25   20230420         NaN       True      True
# 3010844  2023-04-20 18:00:25   20230420         NaN       True      True
#
#          unchanged
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 3010840       True
# 3010841      False
# 3010842      False
# 3010843      False
# 3010844      False
#
# [3010845 rows x 19 columns]
#                                 id        schema  \
# 0        NK-23LHNCbxbLpka28ByPhbHW        Person
# 45       NK-23SyENRGv7v4HrW797y2Tf        Person
# 80       NK-23dinXRmxTu4sehASYNAGE        Person
# 706      NK-23wLbkLretoJxTci3VMZwE        Person
# 795      NK-25Z3H4pijwnkYMmpybVYzQ        Person
# ...                            ...           ...
# 3010752          eu-fsf-eu-9932-61        Person
# 3010753           eu-fsf-eu-994-91   LegalEntity
# 3010842          eu-fsf-eu-9952-96        Person
# 3010843          eu-fsf-eu-9992-69  Organization
# 3010844          eu-fsf-eu-9994-67  Organization
#
#                                       name  \
# 0                                Musenyeri
# 45                              Said Saeed
# 80              Irina Anatolievna KOSTENKO
# 706             Олег Леонидович СЛИЖЕВСКИЙ
# 795            Maria Vladimirovna PIROGOVA
# ...                                    ...
# 3010752                Mohammad Seif Eddin
# 3010753  Al-Haramain Foundation (Pakistan)
# 3010842                Neda Muhammad NADÍM
# 3010843                       Grupo Wagner
# 3010844                            RIA FNA
#
#                                                    aliases  \
# 0          Achille;Frere Petrus Ibrahim;Leopold Mujyambere
# 45                    Said SAID;Said Sa'id Sa'id;سعيد سعيد
# 80       Irina Anatoljevna KOSTENKO;Iryna Anatolijivna ...
# 706      Aleh Leanidavich SLIZHEUSKI;Aleh Leanidavitj S...
# 795      Marija Vladimirova PIROGOVA;Marija Volodymyriv...
# ...                                                    ...
# 3010752  Mohammad SEIFEDDINE;Mohammad Seif El Din;محمد ...
# 3010753                                                NaN
# 3010842                Neda Mohammad NADEEM;نداء محمد ندیم
# 3010843  Groupe Vagner;Groupe Wagner;Grupa Vagnera;Grup...
# 3010844  FNA;Federal News Agency LLC;Federalinė naujien...
#
#                    birth_date countries  \
# 0        1962;1962-03-17;1966     cd;rw
# 45            1955;1955-12-11       NaN
# 80                 1974-04-04       NaN
# 706                1972-08-16       NaN
# 795                1993-05-13       NaN
# ...                       ...       ...
# 3010752                   NaN       NaN
# 3010753                   NaN        pk
# 3010842                   NaN        af
# 3010843                   NaN       NaN
# 3010844                   NaN       NaN
#
#                                                  addresses identifiers  \
# 0                                                 Kinshasa         NaN
# 45                                                     NaN         NaN
# 80                                                     NaN         NaN
# 706                                                    NaN         NaN
# 795                                                    NaN         NaN
# ...                                                    ...         ...
# 3010752                                                NaN         NaN
# 3010753  House No 279, Nazimuddin Road, F-10/1, Islamab...         NaN
# 3010842                                                NaN         NaN
# 3010843                                                NaN         NaN
# 3010844                                                NaN         NaN
#
#                                        sanctions phones emails  \
# 0           COD - 2017/396 (OJ L60) - 2017-03-09    NaN    NaN
# 45       CHEM - 2020/1463 (OJ L335) - 2020-10-14    NaN    NaN
# 80         UKR - 2022/581 (OJ L110) - 2022-04-08    NaN    NaN
# 706         BLR - 2021/339 (OJ L68) - 2021-02-27    NaN    NaN
# 795        UKR - 2022/581 (OJ L110) - 2022-04-08    NaN    NaN
# ...                                          ...    ...    ...
# 3010752  SYR - 2021/1983 (OJ L402I) - 2021-11-15    NaN    NaN
# 3010753   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN    NaN
# 3010842     HR - 2023/500 (OJ L69I) - 2023-03-07    NaN    NaN
# 3010843  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN    NaN
# 3010844  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN    NaN
#
#                                     dataset            last_seen  \
# 0        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 45       EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 80       EU Financial Sanctions Files (FSF)  2022-04-14 18:11:10
# 706      EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 795      EU Financial Sanctions Files (FSF)  2022-04-14 18:11:10
# ...                                     ...                  ...
# 3010752  EU Financial Sanctions Files (FSF)  2023-03-08 18:02:43
# 3010753  EU Financial Sanctions Files (FSF)  2021-07-26 11:55:45
# 3010842  EU Financial Sanctions Files (FSF)  2023-03-09 18:41:03
# 3010843  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
# 3010844  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
#
#                   first_seen date_stamp last_change  new_entry  deletion  \
# 0        2021-09-28 03:03:19   20210928         NaN       True     False
# 45       2021-09-28 03:03:19   20210928         NaN       True     False
# 80       2022-04-11 12:29:35   20220414         NaN       True     False
# 706      2021-09-18 12:23:43   20210918         NaN       True     False
# 795      2022-04-11 12:29:35   20220414         NaN       True     False
# ...                      ...        ...         ...        ...       ...
# 3010752  2023-03-08 18:02:43   20230308         NaN       True      True
# 3010753  2021-08-20 20:39:54   20210820         NaN       True     False
# 3010842  2023-03-09 18:41:03   20230309         NaN       True      True
# 3010843  2023-04-20 18:00:25   20230420         NaN       True      True
# 3010844  2023-04-20 18:00:25   20230420         NaN       True      True
#
#          unchanged
# 0            False
# 45           False
# 80           False
# 706          False
# 795          False
# ...            ...
# 3010752      False
# 3010753      False
# 3010842      False
# 3010843      False
# 3010844      False
#
# [10793 rows x 19 columns]
#                                 id        schema  \
# 0        NK-23LHNCbxbLpka28ByPhbHW        Person
# 1        NK-23LHNCbxbLpka28ByPhbHW        Person
# 2        NK-23LHNCbxbLpka28ByPhbHW        Person
# 3        NK-23LHNCbxbLpka28ByPhbHW        Person
# 4        NK-23LHNCbxbLpka28ByPhbHW        Person
# ...                            ...           ...
# 3010840           eu-fsf-eu-994-91  Organization
# 3010841           eu-fsf-eu-994-91  Organization
# 3010842          eu-fsf-eu-9952-96        Person
# 3010843          eu-fsf-eu-9992-69  Organization
# 3010844          eu-fsf-eu-9994-67  Organization
#
#                                       name  \
# 0                                Musenyeri
# 1                                  Achille
# 2                       Leopold Mujyambere
# 3                       Leopold Mujyambere
# 4                       Leopold Mujyambere
# ...                                    ...
# 3010840  Al-Haramain Foundation (Pakistan)
# 3010841  Al-Haramain Foundation (Pakistan)
# 3010842                Neda Muhammad NADÍM
# 3010843                       Grupo Wagner
# 3010844                            RIA FNA
#
#                                                    aliases  \
# 0          Achille;Frere Petrus Ibrahim;Leopold Mujyambere
# 1        Frere Petrus Ibrahim;Leopold Mujyambere;Musenyeri
# 2                   Achille;Frere Petrus Ibrahim;Musenyeri
# 3                   Achille;Frere Petrus Ibrahim;Musenyeri
# 4                   Achille;Frere Petrus Ibrahim;Musenyeri
# ...                                                    ...
# 3010840                                                NaN
# 3010841                                                NaN
# 3010842                Neda Mohammad NADEEM;نداء محمد ندیم
# 3010843  Groupe Vagner;Groupe Wagner;Grupa Vagnera;Grup...
# 3010844  FNA;Federal News Agency LLC;Federalinė naujien...
#
#                    birth_date countries  \
# 0        1962;1962-03-17;1966     cd;rw
# 1        1962;1962-03-17;1966     cd;rw
# 2        1962;1962-03-17;1966     cd;rw
# 3        1962;1962-03-17;1966     cd;rw
# 4        1962;1962-03-17;1966     cd;rw
# ...                       ...       ...
# 3010840                   NaN        pk
# 3010841                   NaN        pk
# 3010842                   NaN        af
# 3010843                   NaN       NaN
# 3010844                   NaN       NaN
#
#                                                 addresses identifiers  \
# 0                                                Kinshasa         NaN
# 1                                                Kinshasa         NaN
# 2                                                Kinshasa         NaN
# 3                                                Kinshasa         NaN
# 4                                                Kinshasa         NaN
# ...                                                   ...         ...
# 3010840  House No 279, Nazimuddin Road, F-10/1, Islamabad         NaN
# 3010841  House No 279, Nazimuddin Road, F-10/1, Islamabad         NaN
# 3010842                                               NaN         NaN
# 3010843                                               NaN         NaN
# 3010844                                               NaN         NaN
#
#                                        sanctions phones  ...  \
# 0           COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# 1           COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# 2           COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# 3           COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# 4           COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# ...                                          ...    ...  ...
# 3010840   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN  ...
# 3010841   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN  ...
# 3010842     HR - 2023/500 (OJ L69I) - 2023-03-07    NaN  ...
# 3010843  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN  ...
# 3010844  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN  ...
#
#                                     dataset            last_seen  \
# 0        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 1        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 2        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 4        EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# ...                                     ...                  ...
# 3010840  EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3010841  EU Financial Sanctions Files (FSF)  2021-09-26 14:52:11
# 3010842  EU Financial Sanctions Files (FSF)  2023-03-09 18:41:03
# 3010843  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
# 3010844  EU Financial Sanctions Files (FSF)  2023-04-20 20:00:25
#
#                   first_seen date_stamp last_change new_entry  deletion  \
# 0        2021-09-28 03:03:19   20210928         NaN      True     False
# 1        2021-09-29 03:02:51   20210929         NaN     False     False
# 2        2021-09-30 11:39:21   20210930         NaN     False     False
# 3        2021-10-01 03:02:43   20211001         NaN     False     False
# 4        2021-10-02 03:03:02   20211002         NaN     False     False
# ...                      ...        ...         ...       ...       ...
# 3010840  2021-11-15 14:45:38   20211115         NaN     False     False
# 3010841  2021-11-16 03:03:05   20211116         NaN     False      True
# 3010842  2023-03-09 18:41:03   20230309         NaN      True      True
# 3010843  2023-04-20 18:00:25   20230420         NaN      True      True
# 3010844  2023-04-20 18:00:25   20230420         NaN      True      True
#
#          unchanged    month listing_count
# 0            False  2021-09          3638
# 1             True  2021-09          3638
# 2             True  2021-09          3638
# 3             True  2021-10          3281
# 4             True  2021-10          3281
# ...            ...      ...           ...
# 3010840       True  2021-11          2929
# 3010841      False  2021-11          2929
# 3010842      False  2023-03          4111
# 3010843      False  2023-04          4058
# 3010844      False  2023-04          4058
#
# [3010845 rows x 21 columns]
# Deduplicate
#                               id        schema  \
# 0      NK-23LHNCbxbLpka28ByPhbHW        Person
# 1      NK-23SyENRGv7v4HrW797y2Tf        Person
# 2      NK-23dinXRmxTu4sehASYNAGE        Person
# 3      NK-23wLbkLretoJxTci3VMZwE        Person
# 4      NK-25Z3H4pijwnkYMmpybVYzQ        Person
# ...                          ...           ...
# 10788          eu-fsf-eu-9932-61        Person
# 10789           eu-fsf-eu-994-91   LegalEntity
# 10790          eu-fsf-eu-9952-96        Person
# 10791          eu-fsf-eu-9992-69  Organization
# 10792          eu-fsf-eu-9994-67  Organization
#
#                                     name  \
# 0                              Musenyeri
# 1                             Said Saeed
# 2             Irina Anatolievna KOSTENKO
# 3             Олег Леонидович СЛИЖЕВСКИЙ
# 4            Maria Vladimirovna PIROGOVA
# ...                                  ...
# 10788                Mohammad Seif Eddin
# 10789  Al-Haramain Foundation (Pakistan)
# 10790                Neda Muhammad NADÍM
# 10791                       Grupo Wagner
# 10792                            RIA FNA
#
#                                                  aliases  \
# 0        Achille;Frere Petrus Ibrahim;Leopold Mujyambere
# 1                   Said SAID;Said Sa'id Sa'id;سعيد سعيد
# 2      Irina Anatoljevna KOSTENKO;Iryna Anatolijivna ...
# 3      Aleh Leanidavich SLIZHEUSKI;Aleh Leanidavitj S...
# 4      Marija Vladimirova PIROGOVA;Marija Volodymyriv...
# ...                                                  ...
# 10788  Mohammad SEIFEDDINE;Mohammad Seif El Din;محمد ...
# 10789                                                NaN
# 10790                Neda Mohammad NADEEM;نداء محمد ندیم
# 10791  Groupe Vagner;Groupe Wagner;Grupa Vagnera;Grup...
# 10792  FNA;Federal News Agency LLC;Federalinė naujien...
#
#                  birth_date countries  \
# 0      1962;1962-03-17;1966     cd;rw
# 1           1955;1955-12-11       NaN
# 2                1974-04-04       NaN
# 3                1972-08-16       NaN
# 4                1993-05-13       NaN
# ...                     ...       ...
# 10788                   NaN       NaN
# 10789                   NaN        pk
# 10790                   NaN        af
# 10791                   NaN       NaN
# 10792                   NaN       NaN
#
#                                                addresses identifiers  \
# 0                                               Kinshasa         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 10788                                                NaN         NaN
# 10789  House No 279, Nazimuddin Road, F-10/1, Islamab...         NaN
# 10790                                                NaN         NaN
# 10791                                                NaN         NaN
# 10792                                                NaN         NaN
#
#                                      sanctions phones  ...  \
# 0         COD - 2017/396 (OJ L60) - 2017-03-09    NaN  ...
# 1      CHEM - 2020/1463 (OJ L335) - 2020-10-14    NaN  ...
# 2        UKR - 2022/581 (OJ L110) - 2022-04-08    NaN  ...
# 3         BLR - 2021/339 (OJ L68) - 2021-02-27    NaN  ...
# 4        UKR - 2022/581 (OJ L110) - 2022-04-08    NaN  ...
# ...                                        ...    ...  ...
# 10788  SYR - 2021/1983 (OJ L402I) - 2021-11-15    NaN  ...
# 10789   TAQA - 316/2012 (OJ L103) - 2012-04-12    NaN  ...
# 10790     HR - 2023/500 (OJ L69I) - 2023-03-07    NaN  ...
# 10791  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN  ...
# 10792  UKR - 2023/755 (OJ L100 I) - 2023-04-13    NaN  ...
#
#                 first_seen date_stamp last_change new_entry deletion  \
# 0      2021-09-28 03:03:19   20210928         NaN      True    False
# 1      2021-09-28 03:03:19   20210928         NaN      True    False
# 2      2022-04-11 12:29:35   20220414         NaN      True    False
# 3      2021-09-18 12:23:43   20210918         NaN      True    False
# 4      2022-04-11 12:29:35   20220414         NaN      True    False
# ...                    ...        ...         ...       ...      ...
# 10788  2023-03-08 18:02:43   20230308         NaN      True     True
# 10789  2021-08-20 20:39:54   20210820         NaN      True    False
# 10790  2023-03-09 18:41:03   20230309         NaN      True     True
# 10791  2023-04-20 18:00:25   20230420         NaN      True     True
# 10792  2023-04-20 18:00:25   20230420         NaN      True     True
#
#       unchanged    month  listing_count  listing_date delisting_date
# 0         False  2021-09           3638      20210928            NaN
# 1         False  2021-09           3638      20210928            NaN
# 2         False  2022-04           3574      20220414            NaN
# 3         False  2021-09           3638      20210918            NaN
# 4         False  2022-04           3574      20220414            NaN
# ...         ...      ...            ...           ...            ...
# 10788     False  2023-03           4111      20230308       20230308
# 10789     False  2021-08           2374      20210820            NaN
# 10790     False  2023-03           4111      20230309       20230309
# 10791     False  2023-04           4058      20230420       20230420
# 10792     False  2023-04           4058      20230420       20230420
#
# [10793 rows x 23 columns]
# ['cd;rw' nan 'ye' 'ru' 'tn' 'ir' 'by' 'mm' 'gw' 'ni' 'ua' 've' 'kp' 'sy'
#  'af' 'kz;ru' 'sa' 'eg' 'mr' 'iq' 'gb' 'cd;kp' 'fr;sy' 'rw' 'my' 'az' 'cn'
#  'am' 'ru;ua' 'id' 'cd;ug' 'ly' 'by;ua' 'pk' 'cf;sd' 'ke' 'md' 'bi'
#  'iq;sy' 'cf;td' 'ph' 'tr' 'iq;it' 'af;pk' 'iq;sa' 'iq;no' 'ma' 'dz' 'ml'
#  'ss' 'by;ru' 'cd' 'er' 'de;ru' 'ug' 'eg;iq;jo' 'lb' 'gb;sy' 'ru;sy;tr'
#  'tz' 'ge' 'jo;us' 'ae' 'sd' 'cd;cf;ug' 'cf' 'id;sy' 'lv' 'us;ye' 'by;kp'
#  'af;pk;uz' 'ae;ye' 'fr;tr' 'cy' 'qa' 'sy;tr' 'vg' 'kg' 'ch;iq' 'so'
#  'ph;sy' 'id;ph' 'kp;ly' 'jo' 'de' 'sy;tj' 'ae;sy;tr' 'ch' 'af;qa;sa' 'kw'
#  'ca;sy' 'ae;iq' 'by;hu' 'fr;ye' 'ch;ru' 'iq;ly;sy;tn' 'ke;so' 'de;ma'
#  'it;tn' 'et;ke' 'it;ma' 'ua;ua-lpr' 'bf' 'cd;nl;rw' 'de;tr' 'ng' 'nl'
#  'gn' 'ru;sd' 'kz' 'ua;uz' 'iq;jo' 'md;ru' 'lt' 'ir;us' 'ua;ua-dpr' 'ba'
#  'eg;gb;us' 'dz;ps' 'mz' 'zw' 'fr' 'bh' 'af;kw' 'ca;lb' 'cf;ss;ug' 'ly;om'
#  'af;qa' 'kp;vn' 'sk' 'ae;kn;sy' 'uz' 'bd' 'no' 'ht' 'ph;sa' 'il;ru' 'us'
#  'de;rw' 'be' 'sa;ye' 'cd;cf' 'by;ge' 'ly;tn' 'fr;sy;tn' 'al' 'it;tn;yucs'
#  'kp;ru' 'tt;us' 'cf;ga;ss;ug' 'sa;sy' 'mr;sa' 'ru;tj' 'eg;gb' 'iq;jo;sy'
#  'ru;ua;ua-dpr' 'iq;lb;sy' 'ps' 'sd;ye' 'ae;in;pk' 'li' 'be;tn' 'lb;ly'
#  'eg;it;ma;tn' 'iq;sy;ye' 'dz;ml' 'km' 'ly;ml;sd' 'ae;af;ir;pk' 'se;so'
#  'so;us' 'lv;ru' 'iq;ru;sy' 'af;ir;pk' 'lb;ly;sy' 'sn' 'it;ve'
#  'dz;ma;ml;mr;ne;tn' 'sa;us' 'kw;sa;us' 'dz;ml;ne' 'be;cd' 'lb;sy' 'pa'
#  'ma;ml' 'au' 'cy;kz;ru' 'jo;lb' 'id;my;sy' 'ge;ru' 'iq;ru' 'kg;ru'
#  'ma;tr' 'pk;sa' 'kg;ru;ua' 'cf;nl' 'tz;us' 'ml;mr' 'cf;ru' 'jp' 'cd;cg'
#  'sd;ss' 'fr;tn' 'ae;ly' 'sd;ss;ug' 'in;sa' 'fi;ru' 'ae;af;kw;pk' 'eg;it'
#  'fr;sy;tr' 'jo;ps' 'bd;ps;us;ye' 'sy;tr;tt' 'ge;sy' 'kw;pk' 'ru;sy'
#  'ps;sy' 'jo;sy' 'ca;lb;sy' 'mh' 'de;dz' 'gb;ly' 'cf;cg;td' 'dz;fr;ma;tn'
#  'sg' 'it;ma;tn' 'et' 'cn;vg' 'ba;sy' 'iq;us' 'af;sa;ye' 'af;pk;sy'
#  'ru;uz' 'am;fi;ru' 'hr;rs' 'cy;ru' 'ee;ru' 'az;ru' 'kz;ru;ua' 'kz;mt;ru'
#  'gb;il;ru' 'md;ro;ru' 'cn;ru' 'il;md' 'et;so' 'rs;yucs' 'in;pk' 'ca'
#  'cd;nl' 'om' 'ss;ug' 'kn;sy' 'gb;us']
# ['Person' 'Organization' 'LegalEntity']
# ['20210928' '20220414' '20210918' '20211113' '20211220' '20211228'
#  '20211004' '20220303' '20220302' '20211117' '20220119' '20220605'
#  '20211014' '20221119' '20220316' '20211205' '20230807' '20211003'
#  '20211023' '20210923' '20211005' '20230223' '20220223' '20221010'
#  '20230309' '20210930' '20230729' '20211103' '20210929' '20210922'
#  '20220205' '20221228' '20221109' '20231214' '20220203' '20230301'
#  '20220425' '20220312' '20230127' '20210927' '20211102' '20230322'
#  '20230911' '20220226' '20230701' '20220411' '20211030' '20220601'
#  '20221222' '20230525' '20230303' '20210926' '20211109' '20220729'
#  '20211001' '20221021' '20211121' '20221025' '20210924' '20220310'
#  '20221019' '20230803' '20211112' '20211019' '20211115' '20221210'
#  '20221214' '20230502' '20220725' '20220103' '20220222' '20230310'
#  '20220227' '20220609' '20211224' '20230919' '20230506' '20211106'
#  '20220307' '20230601' '20230302' '20230129' '20220304' '20220610'
#  '20230909' '20230227' '20220211' '20230203' '20230205' '20230704'
#  '20220505' '20211229' '20231004' '20230608' '20220501' '20220206'
#  '20220225' '20211201' '20230421' '20230531' '20211022' '20231201'
#  '20231019' '20221013' '20220722' '20211216' '20220611' '20220621'
#  '20221001' '20221120' '20211123' '20211207' '20220417' '20230808'
#  '20220208' '20231020' '20221110' '20231212' '20231108' '20220408'
#  '20220626' '20220718' '20220602' '20231031' '20220608' '20220428'
#  '20220224' '20220318' '20211221' '20230209' '20230530' '20220721'
#  '20220730' '20220305' '20220712' '20220530' '20220427' '20221207'
#  '20220424' '20220418' '20231006' '20220228' '20230702' '20211215'
#  '20230113' '20231202' '20220413' '20220421' '20230917' '20230305'
#  '20220204' '20230614' '20230712' '20230710' '20220705' '20211208'
#  '20230902' '20230124' '20230323' '20230326' '20220315' '20230523'
#  '20230117' '20231218' '20221213' '20230705' '20230513' '20230206'
#  '20231213' '20230406' '20211118' '20220419' '20220604' '20220704'
#  '20231010' '20230810' '20230505' '20220715' '20220531' '20220317'
#  '20221129' '20231207' '20220904' '20220623' '20221208' '20220827'
#  '20231221' '20220612' '20220925' '20231026' '20231217' '20220313'
#  '20220301' '20220527' '20220416' '20220614' '20220930' '20220324'
#  '20220906' '20230121' '20220811' '20220926' '20220823' '20230602'
#  '20220529' '20220630' '20220727' '20220802' '20230411' '20221219'
#  '20230307' '20220521' '20231003' '20221026' '20230331' '20220819'
#  '20220804' '20230215' '20220927' '20220817' '20230131' '20221231'
#  '20221220' '20231116' '20221212' '20230214' '20230306' '20231114'
#  '20231115' '20230625' '20230921' '20220503' '20220323' '20220516'
#  '20220703' '20220919' '20220905' '20220603' '20221202' '20220824'
#  '20230724' '20220701' '20220726' '20220520' '20220102' '20220803'
#  '20220309' '20220615' '20220129' '20230212' '20220728' '20220519'
#  '20230207' '20220908' '20231228' '20220920' '20231127' '20220509'
#  '20230428' '20231208' '20231112' '20220913' '20210820' '20230524'
#  '20230607' '20230613' '20230629' '20230728' '20230802' '20230805'
#  '20230804' '20230814' '20230908' '20230918' '20211012' '20211027'
#  '20211116' '20211111' '20211204' '20211126' '20211214' '20220111'
#  '20220112' '20211222' '20220104' '20220314' '20220422' '20220713'
#  '20220724' '20220805' '20220808' '20221007' '20221018' '20221020'
#  '20221118' '20221108' '20221128' '20221209' '20221221' '20230125'
#  '20230119' '20230130' '20230201' '20230221' '20230228' '20230222'
#  '20230308' '20230420']
# id                    0
# schema                0
# name                  0
# aliases            1754
# birth_date         3865
# countries          3743
# addresses          8311
# identifiers        9480
# sanctions            57
# phones            10519
# emails            10515
# dataset               0
# last_seen             0
# first_seen            0
# date_stamp            0
# last_change       10162
# new_entry             0
# deletion              0
# unchanged             0
# month                 0
# listing_count         0
# listing_date          0
# delisting_date     9384
# dtype: int64

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20231231',freq='D').strftime('%Y%m%d')
print(date_list)
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []
for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/eu_sanctions_map/targets.simple.csv'
    websites.append(test)
print(websites)
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes
print(res)
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows
# Reset index for the final result
res.reset_index(drop=True, inplace=True)
print(res)
#test thematching function
test = res.query('new_entry == True')
print(test)
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
print(res)

print("Deduplicate")
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)
# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')
# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions
# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)
# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')
# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)
# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
res_deduplicated.columns
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)
res_deduplicated.to_csv("eu_sanctions_map.csv")
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=883)
# ['https://data.opensanctions.org/datasets/20210801/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/eu_sanctions_map/targets.simple.csv', 'https://data.opensanctions.org/dataset ...
#                                                    id       schema  \
# 0   eu-sancmap-175cbd95e16f55350037259bffd0db5c703...       Vessel
# 1   eu-sancmap-22465b7c323f62f811f983b17e05644658b...  LegalEntity
# 2   eu-sancmap-2e29d7cedca1b3e07b7809dcdcf0525250d...       Vessel
# 3   eu-sancmap-5f9d3445c8efce7a990a925754e029aca21...       Person
# 4   eu-sancmap-66f96b24db9833c702bb3560ac4bb3ca4ad...       Vessel
# ..                                                ...          ...
# 94  eu-sancmap-8fbbf594e557333e4280ff018b11f837fd8...       Vessel
# 95  eu-sancmap-a1a2a200b111d7825a25201865cac570e9b...  LegalEntity
# 96  eu-sancmap-dd03ba813d7c14cc9570ed2f49627d63908...       Vessel
# 97  eu-sancmap-fd1013b334b2efa28ab2ceda6fc53fc6bc2...       Vessel
# 98  eu-sancmap-feb60d88b4a9c985444b47b0c297cba9ea4...       Vessel
#
#                                                  name aliases birth_date  \
# 0   CHON MYONG 1 Other information: DPRK oil tanke...     NaN        NaN
# 1                                 MIN NING DE YOU 078     NaN        NaN
# 2                                          NEW REGENT     NaN        NaN
# 3   Ahmoudou AG ASRIW (alias: a) Amadou Ag Isriw; ...     NaN        NaN
# 4                                     BILLIONS NO. 18     NaN        NaN
# ..                                                ...     ...        ...
# 94                                        WAN HENG 11     NaN        NaN
# 95                                           Tsargrad     NaN        NaN
# 96                                             FAN KE     NaN        NaN
# 97                                           PETREL 8     NaN        NaN
# 98  AN SAN 1 Other information: DPRK tanker M/V AN...     NaN        NaN
#
#    countries addresses        identifiers  \
# 0        NaN       NaN            8712362
# 1        NaN       NaN                NaN
# 2        NaN       NaN            8312497
# 3        NaN       NaN                NaN
# 4        NaN       NaN            9191773
# ..       ...       ...                ...
# 94       NaN       NaN            8791667
# 95       NaN       NaN                NaN
# 96       NaN       NaN            8914934
# 97       NaN       NaN  620233000;9562233
# 98       NaN       NaN            7303803
#
#                                             sanctions phones emails  \
# 0                                                  ""    NaN    NaN
# 1   M/V MIN NING DE YOU engaged in a ship-to-ship ...    NaN    NaN
# 2   The M/V NEW REGENT engaged in a ship-to-ship t...    NaN    NaN
# 3   Ahmoudou Ag Asriw is a senior commander of the...    NaN    NaN
# 4                                                  ""    NaN    NaN
# ..                                                ...    ...    ...
# 94  M/V WAN HENG 11 engaged in a ship-to-ship tran...    NaN    NaN
# 95                                                 ""    NaN    NaN
# 96  M/V FAN KE loaded DPRK coal at Nampo, DPRK, in...    NaN    NaN
# 97                                                 ""    NaN    NaN
# 98                                                 ""    NaN    NaN
#
#              dataset           first_seen            last_seen date_stamp  \
# 0   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 1   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 2   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 3   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 4   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# ..               ...                  ...                  ...        ...
# 94  EU Sanctions Map  2023-04-20T12:14:15  2023-12-31T18:48:01   20231231
# 95  EU Sanctions Map  2023-07-04T12:03:21  2023-12-31T18:48:01   20231231
# 96  EU Sanctions Map  2023-04-20T12:14:15  2023-12-31T18:48:01   20231231
# 97  EU Sanctions Map  2023-04-20T12:14:15  2023-12-31T18:48:01   20231231
# 98  EU Sanctions Map  2023-04-20T12:14:15  2023-12-31T18:48:01   20231231
#
#             last_change
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 94  2023-04-20T12:14:15
# 95  2023-07-04T12:03:21
# 96  2023-04-20T12:14:15
# 97  2023-04-20T12:14:15
# 98  2023-04-20T12:14:15
#
# [55483 rows x 16 columns]
#                                                       id       schema  \
# 0                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 1                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 2                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 3                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 4                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# ...                                                  ...          ...
# 55478  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55479  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55480  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55481  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55482  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
#
#              name aliases birth_date countries addresses        identifiers  \
# 0      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 1      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 2      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 3      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 4      Sovcombank     NaN        NaN       NaN       NaN                NaN
# ...           ...     ...        ...       ...       ...                ...
# 55478    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55479    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55480    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55481    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55482    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
#
#       sanctions phones emails           dataset           first_seen  \
# 0            ""    NaN    NaN  EU Sanctions Map  2022-05-10 07:48:17
# 1            ""    NaN    NaN  EU Sanctions Map  2022-05-10 07:48:17
# 2            ""    NaN    NaN  EU Sanctions Map  2022-05-10 07:48:17
# 3            ""    NaN    NaN  EU Sanctions Map  2022-05-10 07:48:17
# 4            ""    NaN    NaN  EU Sanctions Map  2022-05-10 07:48:17
# ...         ...    ...    ...               ...                  ...
# 55478        ""    NaN    NaN  EU Sanctions Map  2023-04-20T12:14:15
# 55479        ""    NaN    NaN  EU Sanctions Map  2023-04-20T12:14:15
# 55480        ""    NaN    NaN  EU Sanctions Map  2023-04-20T12:14:15
# 55481        ""    NaN    NaN  EU Sanctions Map  2023-04-20T12:14:15
# 55482        ""    NaN    NaN  EU Sanctions Map  2023-04-20T12:14:15
#
#                  last_seen date_stamp          last_change  new_entry  \
# 0      2022-07-12 13:52:13   20220712                  NaN       True
# 1      2022-07-13 18:12:14   20220713                  NaN      False
# 2      2022-07-14 18:12:16   20220714                  NaN      False
# 3      2022-07-15 18:13:21   20220715                  NaN      False
# 4      2022-07-16 18:11:37   20220716                  NaN      False
# ...                    ...        ...                  ...        ...
# 55478  2023-08-12T18:02:21   20230812  2023-04-20T12:14:15      False
# 55479  2023-08-13T18:03:17   20230813  2023-04-20T12:14:15      False
# 55480  2023-08-14T18:02:57   20230814  2023-04-20T12:14:15      False
# 55481  2023-08-15T18:02:46   20230815  2023-04-20T12:14:15      False
# 55482  2023-08-16T18:03:35   20230816  2023-04-20T12:14:15      False
#
#        deletion  unchanged
# 0         False      False
# 1         False       True
# 2         False       True
# 3         False       True
# 4         False       True
# ...         ...        ...
# 55478     False       True
# 55479     False       True
# 55480     False       True
# 55481     False       True
# 55482      True      False
#
# [55483 rows x 19 columns]
#                                                       id       schema  \
# 0                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 10                             NK-32NYYLd4iT2JDc2pukDRqY  LegalEntity
# 39                             NK-3TSuSKtWtcuB3qBdLC8Y8d       Vessel
# 639                            NK-4C4LEUKsLKwUnJmGeJjnp2  LegalEntity
# 1239                           NK-4JYGfcjP3Frn24sYQ3ZXE2       Vessel
# ...                                                  ...          ...
# 53359  eu-sancmap-e51b08db944318e41b5d48fcea3d1e643ec...  LegalEntity
# 53360  eu-sancmap-f19cf43dd475a50ac0b6eb94fe005ed95ad...       Vessel
# 53820  eu-sancmap-fd1013b334b2efa28ab2ceda6fc53fc6bc2...       Vessel
# 54420  eu-sancmap-feb60d88b4a9c985444b47b0c297cba9ea4...       Vessel
# 55020  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
#
#                                                     name aliases birth_date  \
# 0                                             Sovcombank     NaN        NaN
# 10                                         Bank Dabrabyt     NaN        NaN
# 39                                          UL JI BONG 6     NaN        NaN
# 639                                              ROSNEFT     NaN        NaN
# 1239                                             PAEK MA     NaN        NaN
# ...                                                  ...     ...        ...
# 53359                                       Pervyi Kanal     NaN        NaN
# 53360                                         TONG SAN 2     NaN        NaN
# 53820                                           PETREL 8     NaN        NaN
# 54420  AN SAN 1 Other information: DPRK tanker M/V AN...     NaN        NaN
# 55020                                           JIE SHUN     NaN        NaN
#
#       countries addresses        identifiers  \
# 0           NaN       NaN                NaN
# 10          NaN       NaN                NaN
# 39          NaN       NaN            9114555
# 639         NaN       NaN                NaN
# 1239        NaN       NaN            9066978
# ...         ...       ...                ...
# 53359       NaN       NaN                NaN
# 53360       NaN       NaN  445539000;8937675
# 53820       NaN       NaN  620233000;9562233
# 54420       NaN       NaN            7303803
# 55020       NaN       NaN  514569000;8518780
#
#                                                sanctions phones emails  \
# 0                                                     ""    NaN    NaN
# 10                                                    ""    NaN    NaN
# 39                                                    ""    NaN    NaN
# 639                                                   ""    NaN    NaN
# 1239   DPRK vessel M/V PAEK MA was involved in ship-t...    NaN    NaN
# ...                                                  ...    ...    ...
# 53359                                                 ""    NaN    NaN
# 53360                                                 ""    NaN    NaN
# 53820                                                 ""    NaN    NaN
# 54420                                                 ""    NaN    NaN
# 55020                                                 ""    NaN    NaN
#
#                 dataset           first_seen            last_seen date_stamp  \
# 0      EU Sanctions Map  2022-05-10 07:48:17  2022-07-12 13:52:13   20220712
# 10     EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 39     EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 639    EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 1239   EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# ...                 ...                  ...                  ...        ...
# 53359  EU Sanctions Map  2023-03-09 12:40:12  2023-03-09 18:41:04   20230309
# 53360  EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 53820  EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 54420  EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
# 55020  EU Sanctions Map  2022-05-10 07:48:17  2022-05-10 18:12:58   20220510
#
#       last_change  new_entry  deletion  unchanged
# 0             NaN       True     False      False
# 10            NaN       True     False      False
# 39            NaN       True     False      False
# 639           NaN       True     False      False
# 1239          NaN       True     False      False
# ...           ...        ...       ...        ...
# 53359         NaN       True      True      False
# 53360         NaN       True     False      False
# 53820         NaN       True     False      False
# 54420         NaN       True     False      False
# 55020         NaN       True     False      False
#
# [134 rows x 19 columns]
#                                                       id       schema  \
# 0                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 1                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 2                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 3                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 4                              NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# ...                                                  ...          ...
# 55478  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55479  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55480  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55481  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
# 55482  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
#
#              name aliases birth_date countries addresses        identifiers  \
# 0      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 1      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 2      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 3      Sovcombank     NaN        NaN       NaN       NaN                NaN
# 4      Sovcombank     NaN        NaN       NaN       NaN                NaN
# ...           ...     ...        ...       ...       ...                ...
# 55478    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55479    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55480    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55481    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
# 55482    JIE SHUN     NaN        NaN       NaN       NaN  514569000;8518780
#
#       sanctions phones  ...           dataset           first_seen  \
# 0            ""    NaN  ...  EU Sanctions Map  2022-05-10 07:48:17
# 1            ""    NaN  ...  EU Sanctions Map  2022-05-10 07:48:17
# 2            ""    NaN  ...  EU Sanctions Map  2022-05-10 07:48:17
# 3            ""    NaN  ...  EU Sanctions Map  2022-05-10 07:48:17
# 4            ""    NaN  ...  EU Sanctions Map  2022-05-10 07:48:17
# ...         ...    ...  ...               ...                  ...
# 55478        ""    NaN  ...  EU Sanctions Map  2023-04-20T12:14:15
# 55479        ""    NaN  ...  EU Sanctions Map  2023-04-20T12:14:15
# 55480        ""    NaN  ...  EU Sanctions Map  2023-04-20T12:14:15
# 55481        ""    NaN  ...  EU Sanctions Map  2023-04-20T12:14:15
# 55482        ""    NaN  ...  EU Sanctions Map  2023-04-20T12:14:15
#
#                  last_seen date_stamp          last_change new_entry  \
# 0      2022-07-12 13:52:13   20220712                  NaN      True
# 1      2022-07-13 18:12:14   20220713                  NaN     False
# 2      2022-07-14 18:12:16   20220714                  NaN     False
# 3      2022-07-15 18:13:21   20220715                  NaN     False
# 4      2022-07-16 18:11:37   20220716                  NaN     False
# ...                    ...        ...                  ...       ...
# 55478  2023-08-12T18:02:21   20230812  2023-04-20T12:14:15     False
# 55479  2023-08-13T18:03:17   20230813  2023-04-20T12:14:15     False
# 55480  2023-08-14T18:02:57   20230814  2023-04-20T12:14:15     False
# 55481  2023-08-15T18:02:46   20230815  2023-04-20T12:14:15     False
# 55482  2023-08-16T18:03:35   20230816  2023-04-20T12:14:15     False
#
#        deletion  unchanged    month listing_count
# 0         False      False  2022-07            99
# 1         False       True  2022-07            99
# 2         False       True  2022-07            99
# 3         False       True  2022-07            99
# 4         False       True  2022-07            99
# ...         ...        ...      ...           ...
# 55478     False       True  2023-08           102
# 55479     False       True  2023-08           102
# 55480     False       True  2023-08           102
# 55481     False       True  2023-08           102
# 55482      True      False  2023-08           102
#
# [55483 rows x 21 columns]
# Deduplicate
#                                                     id       schema  \
# 0                            NK-2kLa63Qa2yXPxpd3zCFrwt  LegalEntity
# 1                            NK-32NYYLd4iT2JDc2pukDRqY  LegalEntity
# 2                            NK-3TSuSKtWtcuB3qBdLC8Y8d       Vessel
# 3                            NK-4C4LEUKsLKwUnJmGeJjnp2  LegalEntity
# 4                            NK-4JYGfcjP3Frn24sYQ3ZXE2       Vessel
# ..                                                 ...          ...
# 129  eu-sancmap-e51b08db944318e41b5d48fcea3d1e643ec...  LegalEntity
# 130  eu-sancmap-f19cf43dd475a50ac0b6eb94fe005ed95ad...       Vessel
# 131  eu-sancmap-fd1013b334b2efa28ab2ceda6fc53fc6bc2...       Vessel
# 132  eu-sancmap-feb60d88b4a9c985444b47b0c297cba9ea4...       Vessel
# 133  eu-sancmap-febf18c1754d6a3242b40757aabb5937ad0...       Vessel
#
#                                                   name aliases birth_date  \
# 0                                           Sovcombank     NaN        NaN
# 1                                        Bank Dabrabyt     NaN        NaN
# 2                                         UL JI BONG 6     NaN        NaN
# 3                                              ROSNEFT     NaN        NaN
# 4                                              PAEK MA     NaN        NaN
# ..                                                 ...     ...        ...
# 129                                       Pervyi Kanal     NaN        NaN
# 130                                         TONG SAN 2     NaN        NaN
# 131                                           PETREL 8     NaN        NaN
# 132  AN SAN 1 Other information: DPRK tanker M/V AN...     NaN        NaN
# 133                                           JIE SHUN     NaN        NaN
#
#     countries addresses        identifiers  \
# 0         NaN       NaN                NaN
# 1         NaN       NaN                NaN
# 2         NaN       NaN            9114555
# 3         NaN       NaN                NaN
# 4         NaN       NaN            9066978
# ..        ...       ...                ...
# 129       NaN       NaN                NaN
# 130       NaN       NaN  445539000;8937675
# 131       NaN       NaN  620233000;9562233
# 132       NaN       NaN            7303803
# 133       NaN       NaN  514569000;8518780
#
#                                              sanctions phones  ...  \
# 0                                                   ""    NaN  ...
# 1                                                   ""    NaN  ...
# 2                                                   ""    NaN  ...
# 3                                                   ""    NaN  ...
# 4    DPRK vessel M/V PAEK MA was involved in ship-t...    NaN  ...
# ..                                                 ...    ...  ...
# 129                                                 ""    NaN  ...
# 130                                                 ""    NaN  ...
# 131                                                 ""    NaN  ...
# 132                                                 ""    NaN  ...
# 133                                                 ""    NaN  ...
#
#                last_seen date_stamp last_change new_entry deletion unchanged  \
# 0    2022-07-12 13:52:13   20220712         NaN      True    False     False
# 1    2022-05-10 18:12:58   20220510         NaN      True    False     False
# 2    2022-05-10 18:12:58   20220510         NaN      True    False     False
# 3    2022-05-10 18:12:58   20220510         NaN      True    False     False
# 4    2022-05-10 18:12:58   20220510         NaN      True    False     False
# ..                   ...        ...         ...       ...      ...       ...
# 129  2023-03-09 18:41:04   20230309         NaN      True     True     False
# 130  2022-05-10 18:12:58   20220510         NaN      True    False     False
# 131  2022-05-10 18:12:58   20220510         NaN      True    False     False
# 132  2022-05-10 18:12:58   20220510         NaN      True    False     False
# 133  2022-05-10 18:12:58   20220510         NaN      True    False     False
#
#        month  listing_count  listing_date delisting_date
# 0    2022-07             99      20220712            NaN
# 1    2022-05             83      20220510            NaN
# 2    2022-05             83      20220510            NaN
# 3    2022-05             83      20220510            NaN
# 4    2022-05             83      20220510            NaN
# ..       ...            ...           ...            ...
# 129  2023-03             99      20230309       20230309
# 130  2022-05             83      20220510            NaN
# 131  2022-05             83      20220510            NaN
# 132  2022-05             83      20220510            NaN
# 133  2022-05             83      20220510            NaN
#
# [134 rows x 23 columns]
# [nan]
# ['LegalEntity' 'Vessel' 'Person']
# ['20220712' '20220510' '20230310' '20220620' '20220624' '20221109'
#  '20230705' '20220702' '20230814' '20220608' '20220718' '20230817'
#  '20220722' '20230421' '20220705' '20220520' '20220614' '20230309'
#  '20220617' '20230704']
# id                  0
# schema              0
# name                0
# aliases           118
# birth_date        134
# countries         134
# addresses         134
# identifiers        93
# sanctions           0
# phones            134
# emails            134
# dataset             0
# first_seen          0
# last_seen           0
# date_stamp          0
# last_change       124
# new_entry           0
# deletion            0
# unchanged           0
# month               0
# listing_count       0
# listing_date        0
# delisting_date    127
# dtype: int64
