# %% [markdown]
# **This is the simplified Opensantions data in csv format**

# %%
#import packages
import requests
import pandas as pd
import numpy as np
import datetime
import os
import re

# %% [markdown]
# # Retrieval of the data

# %%
#I can access the data via pandas very easily, output already in tabular form
#data = pd.read_csv('https://data.opensanctions.org/datasets/20240121/us_ofac_sdn/targets.simple.csv')
#data

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20230101',end='20231231',freq='D').strftime('%Y%m%d')
date_list
# Out:
# Index(['20230101', '20230102', '20230103', '20230104', '20230105', '20230106',
#        '20230107', '20230108', '20230109', '20230110',
#        ...
#        '20231222', '20231223', '20231224', '20231225', '20231226', '20231227',
#        '20231228', '20231229', '20231230', '20231231'],
#       dtype='object', length=365)

# %%
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []

for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/default/targets.simple.csv'
    websites.append(test)
print(websites)
# Out:
# ['https://data.opensanctions.org/datasets/20230101/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230102/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230103/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230104/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230105/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230106/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230107/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230108/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230109/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230110/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230111/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230112/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230113/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230114/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230115/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230116/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230117/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230118/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230119/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230120/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230121/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230122/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230123/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230124/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230125/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230126/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230127/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230128/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230129/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230130/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230131/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230201/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230202/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230203/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230204/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230205/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230206/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230207/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230208/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230209/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230210/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230211/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230212/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230213/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230214/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230215/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230216/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230217/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230218/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230219/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20230220 ...

# %% [markdown]
# #first check for missing days
# for site in websites:
#     try:
#         response = requests.get(site)
#         response.raise_for_status()  # Raises an HTTPError for bad response
#     except requests.exceptions.RequestException as e:
#         print(f"Error accessing {site}: {e}")
#         continue

# %%
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes

# %%
res
# Out:
#                                                   id       schema  \
# 0       acf-00040861bc3f593000830d987d09967ef3503ef1       Person
# 1       acf-0011c68a768924609dc5da5707ac7fa4c4d645a2       Person
# 2       acf-001e7e4c0363f08f1e784c230457960b84a6416f       Person
# 3       acf-002c208139012c8d93b6298358188d7cadafe648       Person
# 4       acf-002cc8fdf8fe41185091a7cb6c598663e7a22eb5       Person
# ...                                              ...          ...
# 550942                                  wbdeb-811412  LegalEntity
# 550943                                  wbdeb-811413  LegalEntity
# 550944                                  wbdeb-816302  LegalEntity
# 550945                                   wbdeb-83317  LegalEntity
# 550946       zafic-58-mahmoud-mohammad-ahmad-bahaziq       Person
#
#                                   name                         aliases  \
# 0                       Kolyvanov Egor                  Колыванов Егор
# 1              Shipov Sergei Yurievich            Шипов Сергей Юрьевич
# 2             Egorov Ivan Mikhailovich          Егоров Иван Михайлович
# 3       Goreslavsky Alexey Sergeyevich  Гореславский Алексей Сергеевич
# 4       Samoilova Natalya Vladimirovna  Самойлова Наталья Владимировна
# ...                                ...                             ...
# 550942   MULTI-TECH CONSULT (PTY) LTD.                             NaN
# 550943             MR. PETER LAMBILEKI                             NaN
# 550944                       LEI SITAO                             NaN
# 550945                    SEYDOU IDANI                             NaN
# 550946  MAHMOUD MOHAMMAD AHMAD BAHAZIQ                             NaN
#
#                    birth_date countries  \
# 0                  1980-11-15       NaN
# 1                  1966-04-17       NaN
# 2                  1961-01-21       NaN
# 3                  1977-07-13       NaN
# 4                  1987-06-24       NaN
# ...                       ...       ...
# 550942                    NaN        bw
# 550943                    NaN        bw
# 550944                    NaN        cn
# 550945                    NaN        bf
# 550946  1956-07-07;1963-06-17        iq
#
#                                                 addresses  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 550942  PLOT 20746, BLOCK 3, INDUSTRIAL, GABORONE, Bot...
# 550943  PLOT 20746, BLOCK 3, INDUSTRIAL, GABORONE, Bot...
# 550944  NO.6 EPANG 1ST ROAD, WEIYANG DISTRICT, XI'AN C...
# 550945                                                NaN
# 550946               Heimdalsgate 36-V, 0578 Oslo, Norway
#
#                                     identifiers  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 550942                                      NaN
# 550943                                      NaN
# 550944                                      NaN
# 550945                                      NaN
# 550946  National Identification Number, 0075258
#
#                                                 sanctions phones emails  \
# 0                                                     NaN    NaN    NaN
# 1                                                     NaN    NaN    NaN
# 2                                                     NaN    NaN    NaN
# 3                                                     NaN    NaN    NaN
# 4                                                     NaN    NaN    NaN
# ...                                                   ...    ...    ...
# 550942                 Fraudulent Practices - 2023 - 2027    NaN    NaN
# 550943                 Fraudulent Practices - 2023 - 2027    NaN    NaN
# 550944           Cross Debarment: ADB - 2020 - 2999-12-31    NaN    NaN
# 550945  Consultant Guidelines 1.25(a)(i) - 2004 - 2999...    NaN    NaN
# 550946                                                 ""    NaN    NaN
#
#                                            dataset           first_seen  \
# 0           ACF List of bribetakers and warmongers  2022-05-05 15:26:25
# 1           ACF List of bribetakers and warmongers  2022-07-09 18:14:08
# 2           ACF List of bribetakers and warmongers  2022-05-05 15:26:25
# 3           ACF List of bribetakers and warmongers  2022-09-20 01:05:26
# 4           ACF List of bribetakers and warmongers  2022-09-20 01:05:26
# ...                                            ...                  ...
# 550942                WorldBank Debarred Providers  2023-12-06T15:03:01
# 550943                WorldBank Debarred Providers  2023-12-06T15:03:01
# 550944                WorldBank Debarred Providers  2023-12-22T15:03:01
# 550945                WorldBank Debarred Providers  2023-04-20T12:18:15
# 550946  South African Targeted Financial Sanctions  2023-04-20T12:35:20
#
#                   last_seen date_stamp          last_change
# 0       2023-01-01 18:12:56   20230101                  NaN
# 1       2023-01-01 18:12:56   20230101                  NaN
# 2       2023-01-01 18:12:56   20230101                  NaN
# 3       2023-01-01 18:12:56   20230101                  NaN
# 4       2023-01-01 18:12:56   20230101                  NaN
# ...                     ...        ...                  ...
# 550942  2023-12-31T15:03:01   20231231  2023-12-06T15:03:01
# 550943  2023-12-31T15:03:01   20231231  2023-12-06T15:03:01
# 550944  2023-12-31T15:03:01   20231231  2023-12-22T15:03:01
# 550945  2023-12-31T15:03:01   20231231  2023-04-20T12:18:15
# 550946  2023-12-31T18:45:01   20231231  2023-10-24T21:00:58
#
# [128036611 rows x 16 columns]

# %% [markdown]
# # Match the dates against each other

# %%
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows

# Reset index for the final result
res.reset_index(drop=True, inplace=True)

# %%
res
# Out:
#                                   id        schema  \
# 0          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 1          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 2          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 3          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 4          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# ...                              ...           ...
# 128036606                   zafic-93        Person
# 128036607                   zafic-94        Person
# 128036608                   zafic-96        Person
# 128036609                   zafic-97        Person
# 128036610                   zafic-98        Person
#
#                                                   name  \
# 0           Limited Liability Company "Zelinsky Group"
# 1           Limited Liability Company "Zelinsky Group"
# 2           Limited Liability Company "Zelinsky Group"
# 3           Limited Liability Company "Zelinsky Group"
# 4           Limited Liability Company "Zelinsky Group"
# ...                                                ...
# 128036606      MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 128036607                   ABU UBAYDAH YUSUF AL-ANABI
# 128036608  MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 128036609                 IBRAHIM HASSAN TALI AL-ASIRI
# 128036610               ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                      aliases  birth_date  \
# 0          "Общество с ограниченной ответственностью ""Зе...         NaN
# 1          "Общество с ограниченной ответственностью ""Зе...         NaN
# 2          "Общество с ограниченной ответственностью ""Зе...         NaN
# 3          "Общество с ограниченной ответственностью ""Зе...         NaN
# 4          "Общество с ограниченной ответственностью ""Зе...         NaN
# ...                                                      ...         ...
# 128036606                                                NaN  1969-12-18
# 128036607                                                NaN  1969-02-07
# 128036608                                                NaN  1974-12-11
# 128036609                                                NaN  1982-04-18
# 128036610                                                NaN  1971-04-21
#
#           countries                                          addresses  \
# 0                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 1                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 2                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 3                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 4                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# ...             ...                                                ...
# 128036606     it;tn                                              Italy
# 128036607        dz                                            Algeria
# 128036608        tn            50th Street, Number 23, Zehrouni, Tunis
# 128036609     sa;ye                                              Yemen
# 128036610        us                                                NaN
#
#                                                  identifiers  \
# 0                                   1187746408761;7725491052
# 1                                   1187746408761;7725491052
# 2                                   1187746408761;7725491052
# 3                                   1187746408761;7725491052
# 4                                   1187746408761;7725491052
# ...                                                      ...
# 128036606                                  Passport, G737411
# 128036607                                                NaN
# 128036608                                                NaN
# 128036609  National Identification Number, 1028745097, Pa...
# 128036610                                                NaN
#
#                                                    sanctions phones emails  \
# 0          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN    NaN
# 1          813/2023 - valid - 2023-12-07 - 2033-12-07;"Яв...    NaN    NaN
# 2          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN    NaN
# 3          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN    NaN
# 4          813/2023 - valid - 2023-12-07 - 2033-12-07;"Є ...    NaN    NaN
# ...                                                      ...    ...    ...
# 128036606                                                 ""    NaN    NaN
# 128036607                                                 ""    NaN    NaN
# 128036608                                                 ""    NaN    NaN
# 128036609                                                 ""    NaN    NaN
# 128036610                                                 ""    NaN    NaN
#
#                                                      dataset  \
# 0          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 1          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 2          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 3          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 4          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# ...                                                      ...
# 128036606         South African Targeted Financial Sanctions
# 128036607         South African Targeted Financial Sanctions
# 128036608         South African Targeted Financial Sanctions
# 128036609         South African Targeted Financial Sanctions
# 128036610         South African Targeted Financial Sanctions
#
#                     first_seen            last_seen date_stamp  \
# 0          2023-12-08T12:30:01  2023-12-13T18:30:01   20231213
# 1          2023-12-08T12:30:01  2023-12-14T18:30:01   20231214
# 2          2023-12-08T12:30:01  2023-12-15T18:30:01   20231215
# 3          2023-12-08T12:30:01  2023-12-16T18:30:01   20231216
# 4          2023-12-08T12:30:01  2023-12-17T18:30:01   20231217
# ...                        ...                  ...        ...
# 128036606  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036607  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036608  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036609  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036610  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
#
#                    last_change  new_entry  deletion  unchanged
# 0          2023-12-13T09:22:01       True     False      False
# 1          2023-12-13T09:22:01      False     False       True
# 2          2023-12-13T09:22:01      False     False       True
# 3          2023-12-13T09:22:01      False     False       True
# 4          2023-12-13T09:22:01      False     False       True
# ...                        ...        ...       ...        ...
# 128036606                  NaN       True      True      False
# 128036607                  NaN       True      True      False
# 128036608                  NaN       True      True      False
# 128036609                  NaN       True      True      False
# 128036610                  NaN       True      True      False
#
# [128036611 rows x 19 columns]

# %%
#test thematching function
test = res.query('new_entry == True')
test
# Out:
#                                   id        schema  \
# 0          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 19         NK-224TRezPqwzhQZ37exWxtX        Person
# 234        NK-226GXBdQ5p6NjgrTpTQNVW       Company
# 258        NK-228ZdYZVXaZBSBgVwapnks       Company
# 622        NK-228jBYSTdUSvbZvsKsiHh6  Organization
# ...                              ...           ...
# 128036606                   zafic-93        Person
# 128036607                   zafic-94        Person
# 128036608                   zafic-96        Person
# 128036609                   zafic-97        Person
# 128036610                   zafic-98        Person
#
#                                                         name  \
# 0                 Limited Liability Company "Zelinsky Group"
# 19                                       SANAVBARI NIKITENKO
# 234        Открытое акционерное общество "Электростальски...
# 258                           Private enterprise "Master-SG"
# 622                     Joint-stock company "Electroagregat"
# ...                                                      ...
# 128036606            MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 128036607                         ABU UBAYDAH YUSUF AL-ANABI
# 128036608        MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 128036609                       IBRAHIM HASSAN TALI AL-ASIRI
# 128036610                     ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                      aliases  birth_date  \
# 0          "Общество с ограниченной ответственностью ""Зе...         NaN
# 19                                                       NaN  1992-06-28
# 234        "Open Joint-Stock Company ""Elektrostal Chemic...         NaN
# 258        "ПП ""МАГІСТАР-СГ""";"ПРИВАТНЕ ПІДПРИЄМСТВО ""...         NaN
# 622        "Акционерное общество ""Электроагрегат""";"Акц...         NaN
# ...                                                      ...         ...
# 128036606                                                NaN  1969-12-18
# 128036607                                                NaN  1969-02-07
# 128036608                                                NaN  1974-12-11
# 128036609                                                NaN  1982-04-18
# 128036610                                                NaN  1971-04-21
#
#           countries                                          addresses  \
# 0                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 19               ru                                                NaN
# 234              ru  144001, Russian, Federation, Moscow region, м....
# 258              ua  79034, Lviv region, Lviv city, str. Navrotskoh...
# 622              ru  305022, Russian Federation, Kursk region, Kurs...
# ...             ...                                                ...
# 128036606     it;tn                                              Italy
# 128036607        dz                                            Algeria
# 128036608        tn            50th Street, Number 23, Zehrouni, Tunis
# 128036609     sa;ye                                              Yemen
# 128036610        us                                                NaN
#
#                                                  identifiers  \
# 0                                   1187746408761;7725491052
# 19                                                       NaN
# 234                       1025007108390;5053002307;505301001
# 258                                                 42206417
# 622                                 1024600965531;4631005223
# ...                                                      ...
# 128036606                                  Passport, G737411
# 128036607                                                NaN
# 128036608                                                NaN
# 128036609  National Identification Number, 1028745097, Pa...
# 128036610                                                NaN
#
#                                                    sanctions phones emails  \
# 0          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN    NaN
# 19                                                       NaN    NaN    NaN
# 234        "ВАТ ""ЕХМЗ ім. М.Д. Зелінського"" розробляє т...    NaN    NaN
# 258        "1) блокування активів – тимчасове обмеження п...    NaN    NaN
# 622        192/2023 - valid - 2023-04-01 - 2033-04-01;act...    NaN    NaN
# ...                                                      ...    ...    ...
# 128036606                                                 ""    NaN    NaN
# 128036607                                                 ""    NaN    NaN
# 128036608                                                 ""    NaN    NaN
# 128036609                                                 ""    NaN    NaN
# 128036610                                                 ""    NaN    NaN
#
#                                                      dataset  \
# 0          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 19                                      INTERPOL Red Notices
# 234        Russian National Settlement Depository (NSD, I...
# 258        Ukraine Consolidated State Registry;Ukraine NA...
# 622        Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# ...                                                      ...
# 128036606         South African Targeted Financial Sanctions
# 128036607         South African Targeted Financial Sanctions
# 128036608         South African Targeted Financial Sanctions
# 128036609         South African Targeted Financial Sanctions
# 128036610         South African Targeted Financial Sanctions
#
#                     first_seen            last_seen date_stamp  \
# 0          2023-12-08T12:30:01  2023-12-13T18:30:01   20231213
# 19         2023-05-06T06:10:15  2023-05-31T20:36:56   20230531
# 234        2022-01-01T00:00:00  2023-12-08T18:30:01   20231208
# 258        2022-04-06 08:09:32  2023-01-01 18:14:35   20230101
# 622        2023-04-02 12:17:08  2023-04-12 18:15:02   20230412
# ...                        ...                  ...        ...
# 128036606  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036607  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036608  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036609  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036610  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
#
#                    last_change  new_entry  deletion  unchanged
# 0          2023-12-13T09:22:01       True     False      False
# 19                         NaN       True     False      False
# 234        2023-12-08T12:30:01       True     False      False
# 258                        NaN       True     False      False
# 622                        NaN       True     False      False
# ...                        ...        ...       ...        ...
# 128036606                  NaN       True      True      False
# 128036607                  NaN       True      True      False
# 128036608                  NaN       True      True      False
# 128036609                  NaN       True      True      False
# 128036610                  NaN       True      True      False
#
# [662842 rows x 19 columns]

# %%
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
res
# Out:
#                                   id        schema  \
# 0          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 1          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 2          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 3          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 4          NK-223yQP6hRaMuiALDCJ6xbY  Organization
# ...                              ...           ...
# 128036606                   zafic-93        Person
# 128036607                   zafic-94        Person
# 128036608                   zafic-96        Person
# 128036609                   zafic-97        Person
# 128036610                   zafic-98        Person
#
#                                                   name  \
# 0           Limited Liability Company "Zelinsky Group"
# 1           Limited Liability Company "Zelinsky Group"
# 2           Limited Liability Company "Zelinsky Group"
# 3           Limited Liability Company "Zelinsky Group"
# 4           Limited Liability Company "Zelinsky Group"
# ...                                                ...
# 128036606      MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 128036607                   ABU UBAYDAH YUSUF AL-ANABI
# 128036608  MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 128036609                 IBRAHIM HASSAN TALI AL-ASIRI
# 128036610               ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                      aliases  birth_date  \
# 0          "Общество с ограниченной ответственностью ""Зе...         NaN
# 1          "Общество с ограниченной ответственностью ""Зе...         NaN
# 2          "Общество с ограниченной ответственностью ""Зе...         NaN
# 3          "Общество с ограниченной ответственностью ""Зе...         NaN
# 4          "Общество с ограниченной ответственностью ""Зе...         NaN
# ...                                                      ...         ...
# 128036606                                                NaN  1969-12-18
# 128036607                                                NaN  1969-02-07
# 128036608                                                NaN  1974-12-11
# 128036609                                                NaN  1982-04-18
# 128036610                                                NaN  1971-04-21
#
#           countries                                          addresses  \
# 0                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 1                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 2                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 3                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 4                ru  115054, Russian Federation, Moscow, 57 Dubinin...
# ...             ...                                                ...
# 128036606     it;tn                                              Italy
# 128036607        dz                                            Algeria
# 128036608        tn            50th Street, Number 23, Zehrouni, Tunis
# 128036609     sa;ye                                              Yemen
# 128036610        us                                                NaN
#
#                                                  identifiers  \
# 0                                   1187746408761;7725491052
# 1                                   1187746408761;7725491052
# 2                                   1187746408761;7725491052
# 3                                   1187746408761;7725491052
# 4                                   1187746408761;7725491052
# ...                                                      ...
# 128036606                                  Passport, G737411
# 128036607                                                NaN
# 128036608                                                NaN
# 128036609  National Identification Number, 1028745097, Pa...
# 128036610                                                NaN
#
#                                                    sanctions phones  ...  \
# 0          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 1          813/2023 - valid - 2023-12-07 - 2033-12-07;"Яв...    NaN  ...
# 2          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 3          813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 4          813/2023 - valid - 2023-12-07 - 2033-12-07;"Є ...    NaN  ...
# ...                                                      ...    ...  ...
# 128036606                                                 ""    NaN  ...
# 128036607                                                 ""    NaN  ...
# 128036608                                                 ""    NaN  ...
# 128036609                                                 ""    NaN  ...
# 128036610                                                 ""    NaN  ...
#
#                                                      dataset  \
# 0          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 1          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 2          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 3          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# 4          Ukraine NABC Sanctions Tracker;Ukraine Nationa...
# ...                                                      ...
# 128036606         South African Targeted Financial Sanctions
# 128036607         South African Targeted Financial Sanctions
# 128036608         South African Targeted Financial Sanctions
# 128036609         South African Targeted Financial Sanctions
# 128036610         South African Targeted Financial Sanctions
#
#                     first_seen            last_seen date_stamp  \
# 0          2023-12-08T12:30:01  2023-12-13T18:30:01   20231213
# 1          2023-12-08T12:30:01  2023-12-14T18:30:01   20231214
# 2          2023-12-08T12:30:01  2023-12-15T18:30:01   20231215
# 3          2023-12-08T12:30:01  2023-12-16T18:30:01   20231216
# 4          2023-12-08T12:30:01  2023-12-17T18:30:01   20231217
# ...                        ...                  ...        ...
# 128036606  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036607  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036608  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036609  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
# 128036610  2023-02-06 12:11:45  2023-02-06 18:23:11   20230206
#
#                    last_change new_entry  deletion  unchanged    month  \
# 0          2023-12-13T09:22:01      True     False      False  2023-12
# 1          2023-12-13T09:22:01     False     False       True  2023-12
# 2          2023-12-13T09:22:01     False     False       True  2023-12
# 3          2023-12-13T09:22:01     False     False       True  2023-12
# 4          2023-12-13T09:22:01     False     False       True  2023-12
# ...                        ...       ...       ...        ...      ...
# 128036606                  NaN      True      True      False  2023-02
# 128036607                  NaN      True      True      False  2023-02
# 128036608                  NaN      True      True      False  2023-02
# 128036609                  NaN      True      True      False  2023-02
# 128036610                  NaN      True      True      False  2023-02
#
#           listing_count
# 0                563325
# 1                563325
# 2                563325
# 3                563325
# 4                563325
# ...                 ...
# 128036606        281302
# 128036607        281302
# 128036608        281302
# 128036609        281302
# 128036610        281302
#
# [128036611 rows x 21 columns]

# %% [markdown]
# # Deduplicate

# %%
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)

# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')

# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)

# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
# Out:
#                                id        schema  \
# 0       NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 1       NK-224TRezPqwzhQZ37exWxtX        Person
# 2       NK-226GXBdQ5p6NjgrTpTQNVW       Company
# 3       NK-228ZdYZVXaZBSBgVwapnks       Company
# 4       NK-228jBYSTdUSvbZvsKsiHh6  Organization
# ...                           ...           ...
# 662837                   zafic-93        Person
# 662838                   zafic-94        Person
# 662839                   zafic-96        Person
# 662840                   zafic-97        Person
# 662841                   zafic-98        Person
#
#                                                      name  \
# 0              Limited Liability Company "Zelinsky Group"
# 1                                     SANAVBARI NIKITENKO
# 2       Открытое акционерное общество "Электростальски...
# 3                          Private enterprise "Master-SG"
# 4                    Joint-stock company "Electroagregat"
# ...                                                   ...
# 662837            MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 662838                         ABU UBAYDAH YUSUF AL-ANABI
# 662839        MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 662840                       IBRAHIM HASSAN TALI AL-ASIRI
# 662841                     ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                   aliases  birth_date  \
# 0       "Общество с ограниченной ответственностью ""Зе...         NaN
# 1                                                     NaN  1992-06-28
# 2       "Open Joint-Stock Company ""Elektrostal Chemic...         NaN
# 3       "ПП ""МАГІСТАР-СГ""";"ПРИВАТНЕ ПІДПРИЄМСТВО ""...         NaN
# 4       "Акционерное общество ""Электроагрегат""";"Акц...         NaN
# ...                                                   ...         ...
# 662837                                                NaN  1969-12-18
# 662838                                                NaN  1969-02-07
# 662839                                                NaN  1974-12-11
# 662840                                                NaN  1982-04-18
# 662841                                                NaN  1971-04-21
#
#        countries                                          addresses  \
# 0             ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 1             ru                                                NaN
# 2             ru  144001, Russian, Federation, Moscow region, м....
# 3             ua  79034, Lviv region, Lviv city, str. Navrotskoh...
# 4             ru  305022, Russian Federation, Kursk region, Kurs...
# ...          ...                                                ...
# 662837     it;tn                                              Italy
# 662838        dz                                            Algeria
# 662839        tn            50th Street, Number 23, Zehrouni, Tunis
# 662840     sa;ye                                              Yemen
# 662841        us                                                NaN
#
#                                               identifiers  \
# 0                                1187746408761;7725491052
# 1                                                     NaN
# 2                      1025007108390;5053002307;505301001
# 3                                                42206417
# 4                                1024600965531;4631005223
# ...                                                   ...
# 662837                                  Passport, G737411
# 662838                                                NaN
# 662839                                                NaN
# 662840  National Identification Number, 1028745097, Pa...
# 662841                                                NaN
#
#                                                 sanctions phones  ...  \
# 0       813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 1                                                     NaN    NaN  ...
# 2       "ВАТ ""ЕХМЗ ім. М.Д. Зелінського"" розробляє т...    NaN  ...
# 3       "1) блокування активів – тимчасове обмеження п...    NaN  ...
# 4       192/2023 - valid - 2023-04-01 - 2033-04-01;act...    NaN  ...
# ...                                                   ...    ...  ...
# 662837                                                 ""    NaN  ...
# 662838                                                 ""    NaN  ...
# 662839                                                 ""    NaN  ...
# 662840                                                 ""    NaN  ...
# 662841                                                 ""    NaN  ...
#
#                   last_seen date_stamp          last_change new_entry  \
# 0       2023-12-13T18:30:01   20231213  2023-12-13T09:22:01      True
# 1       2023-05-31T20:36:56   20230531                  NaN      True
# 2       2023-12-08T18:30:01   20231208  2023-12-08T12:30:01      True
# 3       2023-01-01 18:14:35   20230101                  NaN      True
# 4       2023-04-12 18:15:02   20230412                  NaN      True
# ...                     ...        ...                  ...       ...
# 662837  2023-02-06 18:23:11   20230206                  NaN      True
# 662838  2023-02-06 18:23:11   20230206                  NaN      True
# 662839  2023-02-06 18:23:11   20230206                  NaN      True
# 662840  2023-02-06 18:23:11   20230206                  NaN      True
# 662841  2023-02-06 18:23:11   20230206                  NaN      True
#
#        deletion unchanged    month  listing_count  listing_date delisting_date
# 0         False     False  2023-12         563325      20231213            NaN
# 1         False     False  2023-05         373925      20230531            NaN
# 2         False     False  2023-12         563325      20231208            NaN
# 3         False     False  2023-01         306805      20230101            NaN
# 4         False     False  2023-04         277039      20230412            NaN
# ...         ...       ...      ...            ...           ...            ...
# 662837     True     False  2023-02         281302      20230206       20230206
# 662838     True     False  2023-02         281302      20230206       20230206
# 662839     True     False  2023-02         281302      20230206       20230206
# 662840     True     False  2023-02         281302      20230206       20230206
# 662841     True     False  2023-02         281302      20230206       20230206
#
# [662842 rows x 23 columns]

# %%
res_deduplicated
# Out:
#                                id        schema  \
# 0       NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 1       NK-224TRezPqwzhQZ37exWxtX        Person
# 2       NK-226GXBdQ5p6NjgrTpTQNVW       Company
# 3       NK-228ZdYZVXaZBSBgVwapnks       Company
# 4       NK-228jBYSTdUSvbZvsKsiHh6  Organization
# ...                           ...           ...
# 662837                   zafic-93        Person
# 662838                   zafic-94        Person
# 662839                   zafic-96        Person
# 662840                   zafic-97        Person
# 662841                   zafic-98        Person
#
#                                                      name  \
# 0              Limited Liability Company "Zelinsky Group"
# 1                                     SANAVBARI NIKITENKO
# 2       Открытое акционерное общество "Электростальски...
# 3                          Private enterprise "Master-SG"
# 4                    Joint-stock company "Electroagregat"
# ...                                                   ...
# 662837            MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 662838                         ABU UBAYDAH YUSUF AL-ANABI
# 662839        MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 662840                       IBRAHIM HASSAN TALI AL-ASIRI
# 662841                     ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                   aliases  birth_date  \
# 0       "Общество с ограниченной ответственностью ""Зе...         NaN
# 1                                                     NaN  1992-06-28
# 2       "Open Joint-Stock Company ""Elektrostal Chemic...         NaN
# 3       "ПП ""МАГІСТАР-СГ""";"ПРИВАТНЕ ПІДПРИЄМСТВО ""...         NaN
# 4       "Акционерное общество ""Электроагрегат""";"Акц...         NaN
# ...                                                   ...         ...
# 662837                                                NaN  1969-12-18
# 662838                                                NaN  1969-02-07
# 662839                                                NaN  1974-12-11
# 662840                                                NaN  1982-04-18
# 662841                                                NaN  1971-04-21
#
#        countries                                          addresses  \
# 0             ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 1             ru                                                NaN
# 2             ru  144001, Russian, Federation, Moscow region, м....
# 3             ua  79034, Lviv region, Lviv city, str. Navrotskoh...
# 4             ru  305022, Russian Federation, Kursk region, Kurs...
# ...          ...                                                ...
# 662837     it;tn                                              Italy
# 662838        dz                                            Algeria
# 662839        tn            50th Street, Number 23, Zehrouni, Tunis
# 662840     sa;ye                                              Yemen
# 662841        us                                                NaN
#
#                                               identifiers  \
# 0                                1187746408761;7725491052
# 1                                                     NaN
# 2                      1025007108390;5053002307;505301001
# 3                                                42206417
# 4                                1024600965531;4631005223
# ...                                                   ...
# 662837                                  Passport, G737411
# 662838                                                NaN
# 662839                                                NaN
# 662840  National Identification Number, 1028745097, Pa...
# 662841                                                NaN
#
#                                                 sanctions phones  ...  \
# 0       813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 1                                                     NaN    NaN  ...
# 2       "ВАТ ""ЕХМЗ ім. М.Д. Зелінського"" розробляє т...    NaN  ...
# 3       "1) блокування активів – тимчасове обмеження п...    NaN  ...
# 4       192/2023 - valid - 2023-04-01 - 2033-04-01;act...    NaN  ...
# ...                                                   ...    ...  ...
# 662837                                                 ""    NaN  ...
# 662838                                                 ""    NaN  ...
# 662839                                                 ""    NaN  ...
# 662840                                                 ""    NaN  ...
# 662841                                                 ""    NaN  ...
#
#                   last_seen date_stamp          last_change new_entry  \
# 0       2023-12-13T18:30:01   20231213  2023-12-13T09:22:01      True
# 1       2023-05-31T20:36:56   20230531                  NaN      True
# 2       2023-12-08T18:30:01   20231208  2023-12-08T12:30:01      True
# 3       2023-01-01 18:14:35   20230101                  NaN      True
# 4       2023-04-12 18:15:02   20230412                  NaN      True
# ...                     ...        ...                  ...       ...
# 662837  2023-02-06 18:23:11   20230206                  NaN      True
# 662838  2023-02-06 18:23:11   20230206                  NaN      True
# 662839  2023-02-06 18:23:11   20230206                  NaN      True
# 662840  2023-02-06 18:23:11   20230206                  NaN      True
# 662841  2023-02-06 18:23:11   20230206                  NaN      True
#
#        deletion unchanged    month  listing_count  listing_date delisting_date
# 0         False     False  2023-12         563325      20231213            NaN
# 1         False     False  2023-05         373925      20230531            NaN
# 2         False     False  2023-12         563325      20231208            NaN
# 3         False     False  2023-01         306805      20230101            NaN
# 4         False     False  2023-04         277039      20230412            NaN
# ...         ...       ...      ...            ...           ...            ...
# 662837     True     False  2023-02         281302      20230206       20230206
# 662838     True     False  2023-02         281302      20230206       20230206
# 662839     True     False  2023-02         281302      20230206       20230206
# 662840     True     False  2023-02         281302      20230206       20230206
# 662841     True     False  2023-02         281302      20230206       20230206
#
# [662842 rows x 23 columns]

# %% [markdown]
# # Descriptives and clean up

# %%
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
# Out:
# ['ru' 'ua' 'es;vn' ... 'es;no' 'um' 'sa;us']
# ['Organization' 'Person' 'Company' 'LegalEntity' 'Airplane' 'Vessel'
#  'PublicBody' 'Security' 'CryptoWallet']
# ['20231213' '20230531' '20231208' '20230101' '20230412' '20230115'
#  '20230226' '20230323' '20230721' '20230526' '20230912' '20230605'
#  '20230703' '20230201' '20230314' '20230530' '20231206' '20230320'
#  '20230628' '20230830' '20230722' '20230916' '20231121' '20231027'
#  '20230515' '20231106' '20231223' '20231214' '20230608' '20230319'
#  '20230427' '20230522' '20230921' '20230915' '20230418' '20231019'
#  '20230712' '20230904' '20230302' '20230501' '20230502' '20230205'
#  '20230807' '20230523' '20230504' '20230216' '20230817' '20230715'
#  '20230518' '20230223' '20231020' '20230713' '20230215' '20231120'
#  '20230309' '20230120' '20230331' '20230705' '20230520' '20230228'
#  '20230406' '20231026' '20231212' '20230318' '20230403' '20231123'
#  '20230422' '20230704' '20230124' '20230413' '20230102' '20231128'
#  '20230301' '20230710' '20230423' '20230426' '20230227' '20230213'
#  '20231112' '20230210' '20231218' '20231130' '20230322' '20230911'
#  '20230604' '20230428' '20231201' '20230127' '20230326' '20230212'
#  '20230129' '20230924' '20230630' '20231007' '20230711' '20231008'
#  '20230928' '20230211' '20231101' '20230815' '20230902' '20231211'
#  '20230601' '20231217' '20230925' '20231109' '20230525' '20230303'
#  '20230117' '20231016' '20230723' '20230113' '20230519' '20230219'
#  '20231221' '20230824' '20230125' '20231222' '20230729' '20230220'
#  '20231117' '20230506' '20230923' '20231110' '20230313' '20230513'
#  '20230918' '20230803' '20231118' '20230424' '20230505' '20231229'
#  '20230503' '20230825' '20231207' '20230419' '20230602' '20230224'
#  '20230614' '20231129' '20231119' '20230402' '20230818' '20230203'
#  '20230808' '20230930' '20230110' '20230121' '20231220' '20230411'
#  '20230701' '20230304' '20230821' '20230306' '20231031' '20230917'
#  '20231127' '20230919' '20231005' '20231010' '20230929' '20230801'
#  '20230908' '20231108' '20230901' '20230607' '20230305' '20230626'
#  '20230724' '20230814' '20230130' '20230217' '20230214' '20231210'
#  '20230108' '20231004' '20231022' '20231204' '20230707' '20230307'
#  '20230514' '20230619' '20230310' '20231219' '20231028' '20231215'
#  '20230421' '20231116' '20230804' '20231228' '20230725' '20230810'
#  '20231002' '20231114' '20230206' '20230622' '20230104' '20230131'
#  '20230606' '20231230' '20230914' '20230509' '20231113' '20231029'
#  '20230516' '20230209' '20230308' '20230903' '20231227' '20231115'
#  '20231021' '20230615' '20230521' '20231202' '20231125' '20230512'
#  '20231013' '20231025' '20230913' '20230202' '20230624' '20230726'
#  '20231018' '20231024' '20230927' '20231104' '20230613' '20231107'
#  '20231009' '20230222' '20230623' '20230831' '20230122' '20230612'
#  '20231226' '20230103' '20230728' '20230702' '20230621' '20230706'
#  '20230417' '20231225' '20231124' '20230324' '20230922' '20230511'
#  '20230905' '20230819' '20231102' '20230128' '20230714' '20230627'
#  '20230429' '20230822' '20231030' '20230727' '20230112' '20230906'
#  '20230508' '20230107' '20230829' '20230430' '20230315' '20230330'
#  '20230625' '20230507' '20230118' '20230524' '20230528' '20230415'
#  '20230527' '20230813' '20230221' '20230616' '20230316' '20231231'
#  '20230907' '20230802' '20230414' '20230207' '20230920' '20230420'
#  '20230926' '20230116' '20231023' '20230123' '20230409' '20230208'
#  '20230329' '20230730' '20231015' '20230311' '20230405' '20231003'
#  '20230517' '20230225' '20230114' '20230106' '20230510' '20230718'
#  '20231126' '20230826' '20230407' '20230111' '20230109' '20231014'
#  '20231103' '20231122' '20230811' '20230105' '20230119' '20230617'
#  '20230126' '20230204' '20230708' '20230809' '20230408' '20230218'
#  '20231105' '20230325' '20230312' '20230317' '20230327' '20230328'
#  '20230401' '20230404' '20230410' '20231111' '20230416' '20230823'
#  '20230529' '20230618' '20230611' '20231017' '20230719' '20230609'
#  '20230827' '20230629' '20230620' '20230731' '20230805' '20230806'
#  '20230816' '20230909' '20230910' '20231001' '20231012' '20231006'
#  '20231209' '20231205' '20231203' '20231011' '20230828' '20230812'
#  '20230610' '20230720' '20231224' '20230717' '20230603' '20231216'
#  '20230321' '20230820' '20230709']

# %%
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
# Out:
# id                     0
# schema                 0
# name                   0
# aliases           424924
# birth_date        423980
# countries          47191
# addresses         509073
# identifiers       266132
# sanctions         476261
# phones            656171
# emails            651815
# dataset                0
# first_seen             1
# last_seen              1
# date_stamp             0
# last_change       450254
# new_entry              0
# deletion               0
# unchanged              0
# month                  0
# listing_count          0
# listing_date           0
# delisting_date    653282
# dtype: int64

# %%
res_deduplicated.columns
# Out:
# Index(['id', 'schema', 'name', 'aliases', 'birth_date', 'countries',
#        'addresses', 'identifiers', 'sanctions', 'phones', 'emails', 'dataset',
#        'first_seen', 'last_seen', 'date_stamp', 'last_change', 'new_entry',
#        'deletion', 'unchanged', 'month', 'listing_count', 'listing_date',
#        'delisting_date'],
#       dtype='object')

# %%
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
# Out:
#                                id        schema  \
# 0       NK-223yQP6hRaMuiALDCJ6xbY  Organization
# 1       NK-224TRezPqwzhQZ37exWxtX        Person
# 2       NK-226GXBdQ5p6NjgrTpTQNVW       Company
# 3       NK-228ZdYZVXaZBSBgVwapnks       Company
# 4       NK-228jBYSTdUSvbZvsKsiHh6  Organization
# ...                           ...           ...
# 662837                   zafic-93        Person
# 662838                   zafic-94        Person
# 662839                   zafic-96        Person
# 662840                   zafic-97        Person
# 662841                   zafic-98        Person
#
#                                                      name  \
# 0              Limited Liability Company "Zelinsky Group"
# 1                                     SANAVBARI NIKITENKO
# 2       Открытое акционерное общество "Электростальски...
# 3                          Private enterprise "Master-SG"
# 4                    Joint-stock company "Electroagregat"
# ...                                                   ...
# 662837            MEHREZ BEN MAHMOUD BEN SASSI AL-AMDOUNI
# 662838                         ABU UBAYDAH YUSUF AL-ANABI
# 662839        MOHAMED BEN BELGACEM BEN ABDALLAH AL-AOUADI
# 662840                       IBRAHIM HASSAN TALI AL-ASIRI
# 662841                     ANWAR NASSER ABDULLA AL-AULAQI
#
#                                                   aliases  birth_date  \
# 0       "Общество с ограниченной ответственностью ""Зе...         NaN
# 1                                                     NaN  1992-06-28
# 2       "Open Joint-Stock Company ""Elektrostal Chemic...         NaN
# 3       "ПП ""МАГІСТАР-СГ""";"ПРИВАТНЕ ПІДПРИЄМСТВО ""...         NaN
# 4       "Акционерное общество ""Электроагрегат""";"Акц...         NaN
# ...                                                   ...         ...
# 662837                                                NaN  1969-12-18
# 662838                                                NaN  1969-02-07
# 662839                                                NaN  1974-12-11
# 662840                                                NaN  1982-04-18
# 662841                                                NaN  1971-04-21
#
#        countries                                          addresses  \
# 0             ru  115054, Russian Federation, Moscow, 57 Dubinin...
# 1             ru                                                NaN
# 2             ru  144001, Russian, Federation, Moscow region, м....
# 3             ua  79034, Lviv region, Lviv city, str. Navrotskoh...
# 4             ru  305022, Russian Federation, Kursk region, Kurs...
# ...          ...                                                ...
# 662837     it;tn                                              Italy
# 662838        dz                                            Algeria
# 662839        tn            50th Street, Number 23, Zehrouni, Tunis
# 662840     sa;ye                                              Yemen
# 662841        us                                                NaN
#
#                                               identifiers  \
# 0                                1187746408761;7725491052
# 1                                                     NaN
# 2                      1025007108390;5053002307;505301001
# 3                                                42206417
# 4                                1024600965531;4631005223
# ...                                                   ...
# 662837                                  Passport, G737411
# 662838                                                NaN
# 662839                                                NaN
# 662840  National Identification Number, 1028745097, Pa...
# 662841                                                NaN
#
#                                                 sanctions phones  ...  \
# 0       813/2023 - valid - 2023-12-07 - 2033-12-07;"Th...    NaN  ...
# 1                                                     NaN    NaN  ...
# 2       "ВАТ ""ЕХМЗ ім. М.Д. Зелінського"" розробляє т...    NaN  ...
# 3       "1) блокування активів – тимчасове обмеження п...    NaN  ...
# 4       192/2023 - valid - 2023-04-01 - 2033-04-01;act...    NaN  ...
# ...                                                   ...    ...  ...
# 662837                                                 ""    NaN  ...
# 662838                                                 ""    NaN  ...
# 662839                                                 ""    NaN  ...
# 662840                                                 ""    NaN  ...
# 662841                                                 ""    NaN  ...
#
#        date_stamp          last_change new_entry deletion unchanged    month  \
# 0        20231213  2023-12-13T09:22:01      True    False     False  2023-12
# 1        20230531                  NaN      True    False     False  2023-05
# 2        20231208  2023-12-08T12:30:01      True    False     False  2023-12
# 3        20230101                  NaN      True    False     False  2023-01
# 4        20230412                  NaN      True    False     False  2023-04
# ...           ...                  ...       ...      ...       ...      ...
# 662837   20230206                  NaN      True     True     False  2023-02
# 662838   20230206                  NaN      True     True     False  2023-02
# 662839   20230206                  NaN      True     True     False  2023-02
# 662840   20230206                  NaN      True     True     False  2023-02
# 662841   20230206                  NaN      True     True     False  2023-02
#
#         listing_count  listing_date  delisting_date new_listing_count
# 0              563325      20231213             NaN                 1
# 1              373925      20230531             NaN                 1
# 2              563325      20231208             NaN                 1
# 3              306805      20230101             NaN                 1
# 4              277039      20230412             NaN                 1
# ...               ...           ...             ...               ...
# 662837         281302      20230206        20230206                 1
# 662838         281302      20230206        20230206                 1
# 662839         281302      20230206        20230206                 1
# 662840         281302      20230206        20230206                 1
# 662841         281302      20230206        20230206                 1
#
# [662842 rows x 24 columns]

# %%
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)

# %%
res_deduplicated.to_csv("default_batch3.csv")
