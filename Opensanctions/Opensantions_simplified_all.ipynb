# %% [markdown]
# **This is the simplified Opensantions data in csv format**

# %%
#import packages
import requests
import pandas as pd
import numpy as np
import datetime
import os
import re

# %% [markdown]
# # Retrieval of the data

# %%
#I can access the data via pandas very easily, output already in tabular form
#data = pd.read_csv('https://data.opensanctions.org/datasets/20240121/us_ofac_sdn/targets.simple.csv')
#data

# %%
#create urls for all relevant dates
date_list = pd.date_range(start='20210801',end='20211231',freq='D').strftime('%Y%m%d')
date_list
# Out:
# Index(['20210801', '20210802', '20210803', '20210804', '20210805', '20210806',
#        '20210807', '20210808', '20210809', '20210810',
#        ...
#        '20211222', '20211223', '20211224', '20211225', '20211226', '20211227',
#        '20211228', '20211229', '20211230', '20211231'],
#       dtype='object', length=153)

# %%
#get all the urls for all the dates we need the data for
#make each day an individual list so we can compare and match them
websites = []

for i in date_list:
    test = 'https://data.opensanctions.org/datasets/'+(i)+'/default/targets.simple.csv'
    websites.append(test)
print(websites)
# Out:
# ['https://data.opensanctions.org/datasets/20210801/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210802/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210803/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210804/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210805/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210806/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210807/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210808/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210809/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210810/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210811/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210812/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210813/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210814/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210815/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210816/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210817/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210818/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210819/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210820/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210821/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210822/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210823/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210824/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210825/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210826/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210827/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210828/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210829/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210830/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210831/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210901/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210902/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210903/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210904/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210905/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210906/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210907/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210908/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210909/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210910/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210911/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210912/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210913/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210914/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210915/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210916/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210917/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210918/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210919/default/targets.simple.csv', 'https://data.opensanctions.org/datasets/20210920 ...

# %% [markdown]
# #first check for missing days
# for site in websites:
#     try:
#         response = requests.get(site)
#         response.raise_for_status()  # Raises an HTTPError for bad response
#     except requests.exceptions.RequestException as e:
#         print(f"Error accessing {site}: {e}")
#         continue

# %%
#now loop over the batches to get all the data and append the dataframes to one another
#this gives us a list of dataframes
#the loop must contain a date identifyer as a new column so each dataframe is marked with the retrieval date that is then needed to match the different days against each other
entities_list = []
date_pattern = r'/datasets/(\d{8})/'
for site in websites:
    response = requests.get(site)
    if response.status_code != 200:
        continue
    data = pd.read_csv(site, low_memory=False)
    match = re.search(date_pattern, site) #extract the date from the url
    if match:
        date = match.group(1)
        data['date_stamp'] = date #set an individual date stamp for each dataframe matching the url date
        #ata =  data.set_index('date_stamp') #set as an index
    entities_list.append(data)
res = pd.concat(entities_list)  # concatenate list of dataframes

# %%
res
# Out:
#                   id       schema  \
# 0        au-dfat-100       Person
# 1       au-dfat-1001  LegalEntity
# 2       au-dfat-1002  LegalEntity
# 3       au-dfat-1006  LegalEntity
# 4        au-dfat-101       Person
# ...              ...          ...
# 117917  wbdeb-631417  LegalEntity
# 117918  wbdeb-631419  LegalEntity
# 117919  wbdeb-631420  LegalEntity
# 117920   wbdeb-68368  LegalEntity
# 117921   wbdeb-83317  LegalEntity
#
#                                                      name  \
# 0                              Nazir Mohammad Abdul Basir
# 1              STATE TRADE ORGANIZATION FOR CAPITAL GOODS
# 2             STATE TRADE ORGANIZATION FOR CONSUMER GOODS
# 3       STATE TRADING ENTERPRISE FOR PRECISION INSTRUM...
# 4                                Mohammad Eshaq Akhunzada
# ...                                                   ...
# 117917  INGENIEROS CONSULTORES Y ASESORES TÉCNICOS SOC...
# 117918                         WALTERIO ROMERO VALLADARES
# 117919                         TRACTEBEL ENGINEERING S.A.
# 117920                              RIBALCO INTERNATIONAL
# 117921                                       SEYDOU IDANI
#
#                                               aliases birth_date countries  \
# 0                             Nazar Mohammad;نظر محمد        NaN        af
# 1                                                 NaN        NaN       NaN
# 2                                                 NaN        NaN       NaN
# 3       STATE ESTABLISHMENT FOR PRECISION INSTRUMENTS        NaN       NaN
# 4         Mohammad Ishaq Akhund;محمد اسحاق آخوند زاده        NaN        af
# ...                                               ...        ...       ...
# 117917                                            NaN        NaN        hn
# 117918                                            NaN        NaN        hn
# 117919                                            NaN        NaN        be
# 117920                                            NaN        NaN        gb
# 117921                                            NaN        NaN        bf
#
#                                                 addresses identifiers  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 117917  COLONIA HATO DE ENMEDIO, SECTOR 8, BLOQUE 108,...         NaN
# 117918  COLONIA HATO DE ENMEDIO, SECTOR 8,BLOQUE 108, ...         NaN
# 117919      BOULEVARD SIMON BOLIVAR, 34-36, 1000 BRUSSELS         NaN
# 117920                                          BERKSHIRE         NaN
# 117921                                                NaN         NaN
#
#                                                 sanctions phones emails  \
# 0                                          1988 (Taliban)    NaN    NaN
# 1                                             1518 (Iraq)    NaN    NaN
# 2                                             1518 (Iraq)    NaN    NaN
# 3                                             1518 (Iraq)    NaN    NaN
# 4                                          1988 (Taliban)    NaN    NaN
# ...                                                   ...    ...    ...
# 117917     Cross Debarment: IDB - 2021-12-23 - 2033-11-21    NaN    NaN
# 117918     Cross Debarment: IDB - 2021-12-23 - 2033-12-21    NaN    NaN
# 117919     Cross Debarment: IDB - 2021-12-23 - 2025-09-28    NaN    NaN
# 117920  Procurement Guidelines 1.15(a)(i) & (ii) - 200...    NaN    NaN
# 117921  Consultant Guidelines 1.25(a)(i) - 2004-10-25 ...    NaN    NaN
#
#                              dataset            last_seen  \
# 0                 Due Diligence List  2021-07-26 11:55:45
# 1                 Due Diligence List  2021-07-26 11:55:45
# 2                 Due Diligence List  2021-07-26 11:55:45
# 3                 Due Diligence List  2021-07-26 11:55:45
# 4                 Due Diligence List  2021-07-26 11:55:45
# ...                              ...                  ...
# 117917  WorldBank Debarred Providers  2021-12-26 03:03:57
# 117918  WorldBank Debarred Providers  2021-12-26 03:03:57
# 117919  WorldBank Debarred Providers  2021-12-26 03:03:57
# 117920  WorldBank Debarred Providers  2021-07-26 11:55:45
# 117921  WorldBank Debarred Providers  2021-07-26 11:55:45
#
#                  first_seen date_stamp
# 0       2021-08-23 19:57:27   20210823
# 1       2021-08-23 19:57:27   20210823
# 2       2021-08-23 19:57:27   20210823
# 3       2021-08-23 19:57:27   20210823
# 4       2021-08-23 19:57:27   20210823
# ...                     ...        ...
# 117917  2021-12-31 03:03:35   20211231
# 117918  2021-12-31 03:03:35   20211231
# 117919  2021-12-31 03:03:35   20211231
# 117920  2021-12-31 03:03:35   20211231
# 117921  2021-12-31 03:03:35   20211231
#
# [16176854 rows x 15 columns]

# %% [markdown]
# # Match the dates against each other

# %%
#now match the different dates against each other and return an indicator per row for a new listing or delisting
# Sort the DataFrame based on date_stamp and id
res.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res.duplicated(subset=['id'], keep='first')
deletions = ~res.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Set the values of new_entry, deletion, and unchanged columns
res['new_entry'] = new_entries
res['deletion'] = deletions
res['unchanged'] = unchanged_rows

# Reset index for the final result
res.reset_index(drop=True, inplace=True)

# %%
res
# Out:
#                                  id        schema  \
# 0         NK-226JTDehVMSXex35EbKPmi  Organization
# 1         NK-226JTDehVMSXex35EbKPmi  Organization
# 2         NK-226JTDehVMSXex35EbKPmi  Organization
# 3         NK-226JTDehVMSXex35EbKPmi  Organization
# 4         NK-226JTDehVMSXex35EbKPmi  Organization
# ...                             ...           ...
# 16176849                wbdeb-99814   LegalEntity
# 16176850                wbdeb-99814   LegalEntity
# 16176851                wbdeb-99814   LegalEntity
# 16176852                wbdeb-99814   LegalEntity
# 16176853                wbdeb-99814   LegalEntity
#
#                                      name                aliases birth_date  \
# 0                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 1                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 2                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 3                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 4                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# ...                                   ...                    ...        ...
# 16176849  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176850  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176851  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176852  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176853  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
#
#          countries                                          addresses  \
# 0               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 2               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 3               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 4               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# ...            ...                                                ...
# 16176849        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176850        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176851        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176852        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176853        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#          identifiers                                          sanctions  \
# 0                NaN  Block - Program - SDN List - Executive Order 1...
# 1                NaN  Program - SDN List - Block - Executive Order 1...
# 2                NaN  Program - SDN List - Block - Executive Order 1...
# 3                NaN  Block - SDN List - Program - Executive Order 1...
# 4                NaN  Program - Block - SDN List - Executive Order 1...
# ...              ...                                                ...
# 16176849         NaN                                                NaN
# 16176850         NaN                                                NaN
# 16176851         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
# 16176852         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
# 16176853         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
#
#          phones emails                                            dataset  \
# 0           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 1           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 2           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 3           NaN    NaN  US OFAC Specially Designated Nationals (SDN) L...
# 4           NaN    NaN  US OFAC Specially Designated Nationals (SDN) L...
# ...         ...    ...                                                ...
# 16176849    NaN    NaN                       WorldBank Debarred Providers
# 16176850    NaN    NaN                       WorldBank Debarred Providers
# 16176851    NaN    NaN                       WorldBank Debarred Providers
# 16176852    NaN    NaN                       WorldBank Debarred Providers
# 16176853    NaN    NaN                       WorldBank Debarred Providers
#
#                     last_seen           first_seen date_stamp  new_entry  \
# 0         2021-09-30 11:39:21  2021-09-30 11:39:21   20210930       True
# 1         2021-09-30 11:39:21  2021-10-01 03:02:43   20211001      False
# 2         2021-09-30 11:39:21  2021-10-02 03:03:02   20211002      False
# 3         2021-09-30 11:39:21  2021-10-03 08:46:36   20211003      False
# 4         2021-09-30 11:39:21  2021-10-04 03:02:58   20211004      False
# ...                       ...                  ...        ...        ...
# 16176849  2021-07-26 11:55:45  2021-11-04 03:03:12   20211104      False
# 16176850  2021-07-26 11:55:45  2021-11-05 03:02:53   20211105      False
# 16176851  2021-07-26 11:55:45  2021-11-06 11:02:58   20211106      False
# 16176852  2021-07-26 11:55:45  2021-11-07 03:02:51   20211107      False
# 16176853  2021-07-26 11:55:45  2021-11-08 03:03:08   20211108      False
#
#           deletion  unchanged
# 0            False      False
# 1            False       True
# 2            False       True
# 3            False       True
# 4             True      False
# ...            ...        ...
# 16176849     False       True
# 16176850     False       True
# 16176851     False       True
# 16176852     False       True
# 16176853      True      False
#
# [16176854 rows x 18 columns]

# %%
#test thematching function
test = res.query('new_entry == True')
test
# Out:
#                                  id        schema  \
# 0         NK-226JTDehVMSXex35EbKPmi  Organization
# 5         NK-22FBSypYXKBCkX2JoWwgrk       Company
# 58        NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 153       NK-22baaNEkbgBeZokNLmpaKd        Person
# 246       NK-22iRdVwQHXiYMCAASM93qH  Organization
# ...                             ...           ...
# 16176412                wbdeb-83317   LegalEntity
# 16176542                wbdeb-85420   LegalEntity
# 16176620                wbdeb-90379   LegalEntity
# 16176698                wbdeb-96552   LegalEntity
# 16176776                wbdeb-99814   LegalEntity
#
#                                                name  \
# 0                                   BENA PROPERTIES
# 5         GRUPO MECÁNICA DEL VUELO SISTEMAS, S.A.U.
# 58                                  Michael Kuajien
# 153                              DZHAMBULAT GALIMOV
# 246                                 AL RASHID TRUST
# ...                                             ...
# 16176412                               SEYDOU IDANI
# 16176542            TIS CONSULTANTS COMPANY LIMITED
# 16176620     EASTERN BUILDERS AND ENGINEERS LIMITED
# 16176698     KWAPLAH INTERNATIONAL TRADING CO. INC.
# 16176776            CLOSED JOINT STOCK CO "SHARORA"
#
#                                                     aliases  birth_date  \
# 0                                     BANNA PROPERTIES;BENA         NaN
# 5         Grupo Mecánica del Vuelo Sistemas, S.A.U.;Grup...         NaN
# 58        KUAJIAN, Michael;KUAJIEN DUER MAYOK, Michael;K...  1979-01-01
# 153                      Джанбулат Магомедтагирович Галимов  1989-01-05
# 246       AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# ...                                                     ...         ...
# 16176412                                                NaN         NaN
# 16176542                                                NaN         NaN
# 16176620                                                NaN         NaN
# 16176698                                                NaN         NaN
# 16176776                                                NaN         NaN
#
#          countries                                          addresses  \
# 0               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 5            es;vn  ISAAC NEWTON 11, PARQUE TECNOLÓGICO DE MADRID,...
# 58           ke;ss                                Nairobi;South Sudan
# 153             ru                                                NaN
# 246             pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# ...            ...                                                ...
# 16176412        bf                                       Burkina Faso
# 16176542        th  151 TEAM BUILDING, MOO 12, NUANCHAN ROAD, KLON...
# 16176620        ug                     P.O. BOX 9062, KAMPALA, Uganda
# 16176698        us  425 S.W., MADISON AVENUE, SUITE U, CORVALLIS, ...
# 16176776        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#          identifiers                                          sanctions  \
# 0                NaN  Block - Program - SDN List - Executive Order 1...
# 5                NaN  CROSS-DEBARMENT: WBG - 2021-03-02 - 2024-09-01...
# 58               NaN  GLOMAG;Program - Block - SDN List - Executive ...
# 153              NaN  террорист - Письмо Федеральной службы по финан...
# 246              NaN  Block - Program - SDN List - Unknown - 2001-09...
# ...              ...                                                ...
# 16176412         NaN                   Consultant Guidelines 1.25(a)(i)
# 16176542         NaN                   Consultant Guidelines 1.25(a)(i)
# 16176620         NaN  "Procurement Guidelines, 1.14(a)(i); 1.14(a)(ii)"
# 16176698         NaN  Procurement Guidelines 1.15(a)(i) & (ii), 1.14...
# 16176776         NaN                Procurement Guidelines, 1.15(a)(ii)
#
#          phones emails                                            dataset  \
# 0           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 5           NaN    NaN  African Development Bank Debarred Entities;Int...
# 58          NaN    NaN  US OFAC Specially Designated Nationals (SDN) L...
# 153         NaN    NaN          INTERPOL Red Notices;Kyrgyz National List
# 246         NaN    NaN                                 Due Diligence List
# ...         ...    ...                                                ...
# 16176412    NaN    NaN                                 Due Diligence List
# 16176542    NaN    NaN                                 Due Diligence List
# 16176620    NaN    NaN                                 Due Diligence List
# 16176698    NaN    NaN                                 Due Diligence List
# 16176776    NaN    NaN                                 Due Diligence List
#
#                     last_seen           first_seen date_stamp  new_entry  \
# 0         2021-09-30 11:39:21  2021-09-30 11:39:21   20210930       True
# 5         2021-07-26 11:55:45  2021-11-09 03:03:03   20211109       True
# 58        2021-07-26 11:55:45  2021-09-28 03:03:19   20210928       True
# 153       2021-07-26 11:55:45  2021-09-30 11:39:21   20210930       True
# 246       2021-07-26 11:55:45  2021-09-18 12:23:43   20210918       True
# ...                       ...                  ...        ...        ...
# 16176412  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823       True
# 16176542  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823       True
# 16176620  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823       True
# 16176698  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823       True
# 16176776  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823       True
#
#           deletion  unchanged
# 0            False      False
# 5            False      False
# 58           False      False
# 153          False      False
# 246          False      False
# ...            ...        ...
# 16176412     False      False
# 16176542     False      False
# 16176620     False      False
# 16176698     False      False
# 16176776     False      False
#
# [220890 rows x 18 columns]

# %%
# Add a 'month' column
res['month'] = pd.to_datetime(res['date_stamp']).dt.to_period('M')
#get a count of all listings per month
res['listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res['listing_count'] = res.groupby('month')['id'].transform('nunique')
res
# Out:
#                                  id        schema  \
# 0         NK-226JTDehVMSXex35EbKPmi  Organization
# 1         NK-226JTDehVMSXex35EbKPmi  Organization
# 2         NK-226JTDehVMSXex35EbKPmi  Organization
# 3         NK-226JTDehVMSXex35EbKPmi  Organization
# 4         NK-226JTDehVMSXex35EbKPmi  Organization
# ...                             ...           ...
# 16176849                wbdeb-99814   LegalEntity
# 16176850                wbdeb-99814   LegalEntity
# 16176851                wbdeb-99814   LegalEntity
# 16176852                wbdeb-99814   LegalEntity
# 16176853                wbdeb-99814   LegalEntity
#
#                                      name                aliases birth_date  \
# 0                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 1                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 2                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 3                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# 4                         BENA PROPERTIES  BANNA PROPERTIES;BENA        NaN
# ...                                   ...                    ...        ...
# 16176849  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176850  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176851  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176852  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
# 16176853  CLOSED JOINT STOCK CO "SHARORA"                    NaN        NaN
#
#          countries                                          addresses  \
# 0               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 2               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 3               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 4               sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# ...            ...                                                ...
# 16176849        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176850        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176851        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176852        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
# 16176853        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#          identifiers                                          sanctions  \
# 0                NaN  Block - Program - SDN List - Executive Order 1...
# 1                NaN  Program - SDN List - Block - Executive Order 1...
# 2                NaN  Program - SDN List - Block - Executive Order 1...
# 3                NaN  Block - SDN List - Program - Executive Order 1...
# 4                NaN  Program - Block - SDN List - Executive Order 1...
# ...              ...                                                ...
# 16176849         NaN                                                NaN
# 16176850         NaN                                                NaN
# 16176851         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
# 16176852         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
# 16176853         NaN  Procurement Guidelines, 1.15(a)(ii) - 2011-11-...
#
#          phones emails                                            dataset  \
# 0           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 1           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 2           NaN    NaN  US OFAC Specially Designated Nationals (SDN) List
# 3           NaN    NaN  US OFAC Specially Designated Nationals (SDN) L...
# 4           NaN    NaN  US OFAC Specially Designated Nationals (SDN) L...
# ...         ...    ...                                                ...
# 16176849    NaN    NaN                       WorldBank Debarred Providers
# 16176850    NaN    NaN                       WorldBank Debarred Providers
# 16176851    NaN    NaN                       WorldBank Debarred Providers
# 16176852    NaN    NaN                       WorldBank Debarred Providers
# 16176853    NaN    NaN                       WorldBank Debarred Providers
#
#                     last_seen           first_seen date_stamp  new_entry  \
# 0         2021-09-30 11:39:21  2021-09-30 11:39:21   20210930       True
# 1         2021-09-30 11:39:21  2021-10-01 03:02:43   20211001      False
# 2         2021-09-30 11:39:21  2021-10-02 03:03:02   20211002      False
# 3         2021-09-30 11:39:21  2021-10-03 08:46:36   20211003      False
# 4         2021-09-30 11:39:21  2021-10-04 03:02:58   20211004      False
# ...                       ...                  ...        ...        ...
# 16176849  2021-07-26 11:55:45  2021-11-04 03:03:12   20211104      False
# 16176850  2021-07-26 11:55:45  2021-11-05 03:02:53   20211105      False
# 16176851  2021-07-26 11:55:45  2021-11-06 11:02:58   20211106      False
# 16176852  2021-07-26 11:55:45  2021-11-07 03:02:51   20211107      False
# 16176853  2021-07-26 11:55:45  2021-11-08 03:03:08   20211108      False
#
#           deletion  unchanged    month  listing_count
# 0            False      False  2021-09         147560
# 1            False       True  2021-10         130093
# 2            False       True  2021-10         130093
# 3            False       True  2021-10         130093
# 4             True      False  2021-10         130093
# ...            ...        ...      ...            ...
# 16176849     False       True  2021-11         134236
# 16176850     False       True  2021-11         134236
# 16176851     False       True  2021-11         134236
# 16176852     False       True  2021-11         134236
# 16176853      True      False  2021-11         134236
#
# [16176854 rows x 20 columns]

# %% [markdown]
# # Deduplicate

# %%
res_deduplicated = res.copy()
res_deduplicated.sort_values(by=['id', 'date_stamp'], inplace=True)

# Identify new entries and deletions based on the index and columns you want to compare
new_entries = ~res_deduplicated.duplicated(subset=['id'], keep='first')
deletions = ~res_deduplicated.duplicated(subset=['id'], keep='last')

# Identify unchanged rows by checking for duplicates based on the id and date_stamp
unchanged_rows = ~new_entries & ~deletions

# Create new columns for first seen and last seen dates
res_deduplicated['listing_date'] = res_deduplicated['date_stamp'].where(new_entries)
res_deduplicated['delisting_date'] = res_deduplicated['date_stamp'].where(deletions)

# Deduplicate the entries (keep the first occurrence for each entity)
res_deduplicated = res_deduplicated.drop_duplicates(subset=['id'], keep='first')

# Reset index for the final result
res_deduplicated.reset_index(drop=True, inplace=True)

# Print or further analyze the deduplicated DataFrame 'res_deduplicated'
print(res_deduplicated)
# Out:
#                                id        schema  \
# 0       NK-226JTDehVMSXex35EbKPmi  Organization
# 1       NK-22FBSypYXKBCkX2JoWwgrk       Company
# 2       NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 3       NK-22baaNEkbgBeZokNLmpaKd        Person
# 4       NK-22iRdVwQHXiYMCAASM93qH  Organization
# ...                           ...           ...
# 220885                wbdeb-83317   LegalEntity
# 220886                wbdeb-85420   LegalEntity
# 220887                wbdeb-90379   LegalEntity
# 220888                wbdeb-96552   LegalEntity
# 220889                wbdeb-99814   LegalEntity
#
#                                              name  \
# 0                                 BENA PROPERTIES
# 1       GRUPO MECÁNICA DEL VUELO SISTEMAS, S.A.U.
# 2                                 Michael Kuajien
# 3                              DZHAMBULAT GALIMOV
# 4                                 AL RASHID TRUST
# ...                                           ...
# 220885                               SEYDOU IDANI
# 220886            TIS CONSULTANTS COMPANY LIMITED
# 220887     EASTERN BUILDERS AND ENGINEERS LIMITED
# 220888     KWAPLAH INTERNATIONAL TRADING CO. INC.
# 220889            CLOSED JOINT STOCK CO "SHARORA"
#
#                                                   aliases  birth_date  \
# 0                                   BANNA PROPERTIES;BENA         NaN
# 1       Grupo Mecánica del Vuelo Sistemas, S.A.U.;Grup...         NaN
# 2       KUAJIAN, Michael;KUAJIEN DUER MAYOK, Michael;K...  1979-01-01
# 3                      Джанбулат Магомедтагирович Галимов  1989-01-05
# 4       AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# ...                                                   ...         ...
# 220885                                                NaN         NaN
# 220886                                                NaN         NaN
# 220887                                                NaN         NaN
# 220888                                                NaN         NaN
# 220889                                                NaN         NaN
#
#        countries                                          addresses  \
# 0             sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1          es;vn  ISAAC NEWTON 11, PARQUE TECNOLÓGICO DE MADRID,...
# 2          ke;ss                                Nairobi;South Sudan
# 3             ru                                                NaN
# 4             pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# ...          ...                                                ...
# 220885        bf                                       Burkina Faso
# 220886        th  151 TEAM BUILDING, MOO 12, NUANCHAN ROAD, KLON...
# 220887        ug                     P.O. BOX 9062, KAMPALA, Uganda
# 220888        us  425 S.W., MADISON AVENUE, SUITE U, CORVALLIS, ...
# 220889        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#        identifiers                                          sanctions phones  \
# 0              NaN  Block - Program - SDN List - Executive Order 1...    NaN
# 1              NaN  CROSS-DEBARMENT: WBG - 2021-03-02 - 2024-09-01...    NaN
# 2              NaN  GLOMAG;Program - Block - SDN List - Executive ...    NaN
# 3              NaN  террорист - Письмо Федеральной службы по финан...    NaN
# 4              NaN  Block - Program - SDN List - Unknown - 2001-09...    NaN
# ...            ...                                                ...    ...
# 220885         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220886         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220887         NaN  "Procurement Guidelines, 1.14(a)(i); 1.14(a)(ii)"    NaN
# 220888         NaN  Procurement Guidelines 1.15(a)(i) & (ii), 1.14...    NaN
# 220889         NaN                Procurement Guidelines, 1.15(a)(ii)    NaN
#
#         ...            last_seen           first_seen date_stamp new_entry  \
# 0       ...  2021-09-30 11:39:21  2021-09-30 11:39:21   20210930      True
# 1       ...  2021-07-26 11:55:45  2021-11-09 03:03:03   20211109      True
# 2       ...  2021-07-26 11:55:45  2021-09-28 03:03:19   20210928      True
# 3       ...  2021-07-26 11:55:45  2021-09-30 11:39:21   20210930      True
# 4       ...  2021-07-26 11:55:45  2021-09-18 12:23:43   20210918      True
# ...     ...                  ...                  ...        ...       ...
# 220885  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220886  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220887  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220888  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220889  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
#
#        deletion  unchanged    month  listing_count listing_date  \
# 0         False      False  2021-09         147560     20210930
# 1         False      False  2021-11         134236     20211109
# 2         False      False  2021-09         147560     20210928
# 3         False      False  2021-09         147560     20210930
# 4         False      False  2021-09         147560     20210918
# ...         ...        ...      ...            ...          ...
# 220885    False      False  2021-08         133396     20210823
# 220886    False      False  2021-08         133396     20210823
# 220887    False      False  2021-08         133396     20210823
# 220888    False      False  2021-08         133396     20210823
# 220889    False      False  2021-08         133396     20210823
#
#         delisting_date
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 220885             NaN
# 220886             NaN
# 220887             NaN
# 220888             NaN
# 220889             NaN
#
# [220890 rows x 22 columns]

# %%
res_deduplicated
# Out:
#                                id        schema  \
# 0       NK-226JTDehVMSXex35EbKPmi  Organization
# 1       NK-22FBSypYXKBCkX2JoWwgrk       Company
# 2       NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 3       NK-22baaNEkbgBeZokNLmpaKd        Person
# 4       NK-22iRdVwQHXiYMCAASM93qH  Organization
# ...                           ...           ...
# 220885                wbdeb-83317   LegalEntity
# 220886                wbdeb-85420   LegalEntity
# 220887                wbdeb-90379   LegalEntity
# 220888                wbdeb-96552   LegalEntity
# 220889                wbdeb-99814   LegalEntity
#
#                                              name  \
# 0                                 BENA PROPERTIES
# 1       GRUPO MECÁNICA DEL VUELO SISTEMAS, S.A.U.
# 2                                 Michael Kuajien
# 3                              DZHAMBULAT GALIMOV
# 4                                 AL RASHID TRUST
# ...                                           ...
# 220885                               SEYDOU IDANI
# 220886            TIS CONSULTANTS COMPANY LIMITED
# 220887     EASTERN BUILDERS AND ENGINEERS LIMITED
# 220888     KWAPLAH INTERNATIONAL TRADING CO. INC.
# 220889            CLOSED JOINT STOCK CO "SHARORA"
#
#                                                   aliases  birth_date  \
# 0                                   BANNA PROPERTIES;BENA         NaN
# 1       Grupo Mecánica del Vuelo Sistemas, S.A.U.;Grup...         NaN
# 2       KUAJIAN, Michael;KUAJIEN DUER MAYOK, Michael;K...  1979-01-01
# 3                      Джанбулат Магомедтагирович Галимов  1989-01-05
# 4       AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# ...                                                   ...         ...
# 220885                                                NaN         NaN
# 220886                                                NaN         NaN
# 220887                                                NaN         NaN
# 220888                                                NaN         NaN
# 220889                                                NaN         NaN
#
#        countries                                          addresses  \
# 0             sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1          es;vn  ISAAC NEWTON 11, PARQUE TECNOLÓGICO DE MADRID,...
# 2          ke;ss                                Nairobi;South Sudan
# 3             ru                                                NaN
# 4             pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# ...          ...                                                ...
# 220885        bf                                       Burkina Faso
# 220886        th  151 TEAM BUILDING, MOO 12, NUANCHAN ROAD, KLON...
# 220887        ug                     P.O. BOX 9062, KAMPALA, Uganda
# 220888        us  425 S.W., MADISON AVENUE, SUITE U, CORVALLIS, ...
# 220889        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#        identifiers                                          sanctions phones  \
# 0              NaN  Block - Program - SDN List - Executive Order 1...    NaN
# 1              NaN  CROSS-DEBARMENT: WBG - 2021-03-02 - 2024-09-01...    NaN
# 2              NaN  GLOMAG;Program - Block - SDN List - Executive ...    NaN
# 3              NaN  террорист - Письмо Федеральной службы по финан...    NaN
# 4              NaN  Block - Program - SDN List - Unknown - 2001-09...    NaN
# ...            ...                                                ...    ...
# 220885         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220886         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220887         NaN  "Procurement Guidelines, 1.14(a)(i); 1.14(a)(ii)"    NaN
# 220888         NaN  Procurement Guidelines 1.15(a)(i) & (ii), 1.14...    NaN
# 220889         NaN                Procurement Guidelines, 1.15(a)(ii)    NaN
#
#         ...            last_seen           first_seen date_stamp new_entry  \
# 0       ...  2021-09-30 11:39:21  2021-09-30 11:39:21   20210930      True
# 1       ...  2021-07-26 11:55:45  2021-11-09 03:03:03   20211109      True
# 2       ...  2021-07-26 11:55:45  2021-09-28 03:03:19   20210928      True
# 3       ...  2021-07-26 11:55:45  2021-09-30 11:39:21   20210930      True
# 4       ...  2021-07-26 11:55:45  2021-09-18 12:23:43   20210918      True
# ...     ...                  ...                  ...        ...       ...
# 220885  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220886  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220887  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220888  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
# 220889  ...  2021-07-26 11:55:45  2021-08-23 19:57:27   20210823      True
#
#        deletion  unchanged    month  listing_count listing_date  \
# 0         False      False  2021-09         147560     20210930
# 1         False      False  2021-11         134236     20211109
# 2         False      False  2021-09         147560     20210928
# 3         False      False  2021-09         147560     20210930
# 4         False      False  2021-09         147560     20210918
# ...         ...        ...      ...            ...          ...
# 220885    False      False  2021-08         133396     20210823
# 220886    False      False  2021-08         133396     20210823
# 220887    False      False  2021-08         133396     20210823
# 220888    False      False  2021-08         133396     20210823
# 220889    False      False  2021-08         133396     20210823
#
#         delisting_date
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 220885             NaN
# 220886             NaN
# 220887             NaN
# 220888             NaN
# 220889             NaN
#
# [220890 rows x 22 columns]

# %% [markdown]
# # Descriptives and clean up

# %%
#the countries are coded as iso2 codes -> transform to iso 3
#keep both countries? could search for "ru" over regex functions
print(res_deduplicated.countries.unique())
print(res_deduplicated.schema.unique())
print(res_deduplicated.listing_date.unique())
# Out:
# ['sy' 'es;vn' 'ke;ss' ... 'be;us' 'ch;gb' 'na;sd']
# ['Organization' 'Company' 'Person' 'LegalEntity' 'Airplane' 'Vessel'
#  'PublicBody']
# ['20210930' '20211109' '20210928' '20210918' '20211229' '20211004'
#  '20210922' '20211113' '20211030' '20211220' '20211106' '20211228'
#  '20211003' '20211102' '20210927' '20211117' '20211205' '20211019'
#  '20211014' '20211005' '20211103' '20210924' '20211023' '20210923'
#  '20211022' '20210929' '20211207' '20211216' '20211202' '20211231'
#  '20211209' '20210926' '20211208' '20211224' '20211121' '20211118'
#  '20211214' '20211112' '20211001' '20211115' '20211110' '20211215'
#  '20211201' '20211123' '20211221' '20211230' '20211026' '20211227'
#  '20211223' '20211222' '20211125' '20211217' '20211127' '20210823'
#  '20211211' '20211028' '20211203' '20211116' '20211027' '20211111'
#  '20211126' '20210914' '20210907' '20211128' '20211010' '20210831'
#  '20211114' '20211226' '20211012' '20211204' '20210909' '20210916'
#  '20211013' '20211104' '20211107' '20211031' '20211213' '20211219'
#  '20211122' '20211101' '20211124' '20211130' '20211108' '20211206'
#  '20211129' '20210903' '20211218' '20211225' '20211105' '20211002'
#  '20210824' '20211119' '20210829' '20210827' '20210920' '20210826'
#  '20210825' '20211029' '20210919' '20210913' '20210917' '20210915'
#  '20211007' '20210828' '20210921' '20210908' '20210901' '20210911'
#  '20210925' '20211008' '20211009' '20211006' '20211020' '20211015'
#  '20211120' '20211210' '20210904' '20210910' '20210902' '20211212'
#  '20211024']

# %%
#get missingness
is_null = res_deduplicated.isnull().sum()
display(is_null)
# Out:
# id                     0
# schema                 0
# name                   0
# aliases           106889
# birth_date         83128
# countries          20584
# addresses         175777
# identifiers       108337
# sanctions         147674
# phones            212980
# emails            203898
# dataset                0
# last_seen              0
# first_seen             0
# date_stamp             0
# new_entry              0
# deletion               0
# unchanged              0
# month                  0
# listing_count          0
# listing_date           0
# delisting_date    220166
# dtype: int64

# %%
res_deduplicated.columns
# Out:
# Index(['id', 'schema', 'name', 'aliases', 'birth_date', 'countries',
#        'addresses', 'identifiers', 'sanctions', 'phones', 'emails', 'dataset',
#        'last_seen', 'first_seen', 'date_stamp', 'new_entry', 'deletion',
#        'unchanged', 'month', 'listing_count', 'listing_date',
#        'delisting_date'],
#       dtype='object')

# %%
res_deduplicated['new_listing_count'] = 0  # Initialize the 'listing_count' column with zeros
res_deduplicated['new_listing_count'] = res_deduplicated.groupby('month')['new_entry'].transform('nunique')
res_deduplicated
# Out:
#                                id        schema  \
# 0       NK-226JTDehVMSXex35EbKPmi  Organization
# 1       NK-22FBSypYXKBCkX2JoWwgrk       Company
# 2       NK-22HtK7WrxZ2sU3rmhz6PuZ        Person
# 3       NK-22baaNEkbgBeZokNLmpaKd        Person
# 4       NK-22iRdVwQHXiYMCAASM93qH  Organization
# ...                           ...           ...
# 220885                wbdeb-83317   LegalEntity
# 220886                wbdeb-85420   LegalEntity
# 220887                wbdeb-90379   LegalEntity
# 220888                wbdeb-96552   LegalEntity
# 220889                wbdeb-99814   LegalEntity
#
#                                              name  \
# 0                                 BENA PROPERTIES
# 1       GRUPO MECÁNICA DEL VUELO SISTEMAS, S.A.U.
# 2                                 Michael Kuajien
# 3                              DZHAMBULAT GALIMOV
# 4                                 AL RASHID TRUST
# ...                                           ...
# 220885                               SEYDOU IDANI
# 220886            TIS CONSULTANTS COMPANY LIMITED
# 220887     EASTERN BUILDERS AND ENGINEERS LIMITED
# 220888     KWAPLAH INTERNATIONAL TRADING CO. INC.
# 220889            CLOSED JOINT STOCK CO "SHARORA"
#
#                                                   aliases  birth_date  \
# 0                                   BANNA PROPERTIES;BENA         NaN
# 1       Grupo Mecánica del Vuelo Sistemas, S.A.U.;Grup...         NaN
# 2       KUAJIAN, Michael;KUAJIEN DUER MAYOK, Michael;K...  1979-01-01
# 3                      Джанбулат Магомедтагирович Галимов  1989-01-05
# 4       AL AMEEN TRUST;AL AMIN TRUST;AL AMIN WELFARE T...         NaN
# ...                                                   ...         ...
# 220885                                                NaN         NaN
# 220886                                                NaN         NaN
# 220887                                                NaN         NaN
# 220888                                                NaN         NaN
# 220889                                                NaN         NaN
#
#        countries                                          addresses  \
# 0             sy  Cham Holding Building, Daraa Highway, Sahnaya ...
# 1          es;vn  ISAAC NEWTON 11, PARQUE TECNOLÓGICO DE MADRID,...
# 2          ke;ss                                Nairobi;South Sudan
# 3             ru                                                NaN
# 4             pk  Jamia Masjid, Sulaiman Park, Begum Pura, Lahor...
# ...          ...                                                ...
# 220885        bf                                       Burkina Faso
# 220886        th  151 TEAM BUILDING, MOO 12, NUANCHAN ROAD, KLON...
# 220887        ug                     P.O. BOX 9062, KAMPALA, Uganda
# 220888        us  425 S.W., MADISON AVENUE, SUITE U, CORVALLIS, ...
# 220889        tj  KARIM DEVONA STREET 59, HISSAR RAYON, SHARORA ...
#
#        identifiers                                          sanctions phones  \
# 0              NaN  Block - Program - SDN List - Executive Order 1...    NaN
# 1              NaN  CROSS-DEBARMENT: WBG - 2021-03-02 - 2024-09-01...    NaN
# 2              NaN  GLOMAG;Program - Block - SDN List - Executive ...    NaN
# 3              NaN  террорист - Письмо Федеральной службы по финан...    NaN
# 4              NaN  Block - Program - SDN List - Unknown - 2001-09...    NaN
# ...            ...                                                ...    ...
# 220885         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220886         NaN                   Consultant Guidelines 1.25(a)(i)    NaN
# 220887         NaN  "Procurement Guidelines, 1.14(a)(i); 1.14(a)(ii)"    NaN
# 220888         NaN  Procurement Guidelines 1.15(a)(i) & (ii), 1.14...    NaN
# 220889         NaN                Procurement Guidelines, 1.15(a)(ii)    NaN
#
#         ...           first_seen date_stamp new_entry deletion unchanged  \
# 0       ...  2021-09-30 11:39:21   20210930      True    False     False
# 1       ...  2021-11-09 03:03:03   20211109      True    False     False
# 2       ...  2021-09-28 03:03:19   20210928      True    False     False
# 3       ...  2021-09-30 11:39:21   20210930      True    False     False
# 4       ...  2021-09-18 12:23:43   20210918      True    False     False
# ...     ...                  ...        ...       ...      ...       ...
# 220885  ...  2021-08-23 19:57:27   20210823      True    False     False
# 220886  ...  2021-08-23 19:57:27   20210823      True    False     False
# 220887  ...  2021-08-23 19:57:27   20210823      True    False     False
# 220888  ...  2021-08-23 19:57:27   20210823      True    False     False
# 220889  ...  2021-08-23 19:57:27   20210823      True    False     False
#
#           month  listing_count  listing_date delisting_date  new_listing_count
# 0       2021-09         147560      20210930            NaN                  1
# 1       2021-11         134236      20211109            NaN                  1
# 2       2021-09         147560      20210928            NaN                  1
# 3       2021-09         147560      20210930            NaN                  1
# 4       2021-09         147560      20210918            NaN                  1
# ...         ...            ...           ...            ...                ...
# 220885  2021-08         133396      20210823            NaN                  1
# 220886  2021-08         133396      20210823            NaN                  1
# 220887  2021-08         133396      20210823            NaN                  1
# 220888  2021-08         133396      20210823            NaN                  1
# 220889  2021-08         133396      20210823            NaN                  1
#
# [220890 rows x 23 columns]

# %%
#res_deduplicated = res_deduplicated.drop(['last_seen', 'first_seen','new_entry', 'deletion','unchanged'],axis = 1)

# %%
res_deduplicated.to_csv("default_batch1.csv")
